# %% [markdown]
# # 21. 아파트이름

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import MinMaxScaler

# 맥에서 글씨 깨짐 방지
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../data/preprocessed/20_ratio_sale_deposit.csv')
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_32574/198579563.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/preprocessed/20_ratio_sale_deposit.csv')

# %%
df.head()
# Out:
#              시군구     번지     본번   부번    아파트명   전용면적    계약년월  계약일  층  건축년도  ...  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712    8  3  1987  ...
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712   22  4  1987  ...
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  54.98  201712   28  5  1987  ...
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    3  4  1987  ...
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    8  2  1987  ...
#
#      동  구별 지가지수       공시지가 평균 매수우위지수 건물나이 30년이상50년이하      구매력지수     거래활발지수  \
# 0  개포동   75.121  6.858562e+06   88.4   30          1  48.262095  17.693929
# 1  개포동   75.121  6.858562e+06   88.4   30          1  48.262095  17.693929
# 2  개포동   75.121  6.858562e+06   88.4   30          1  48.262095  17.693929
# 3  개포동   75.461  7.322618e+06  118.0   31          1  46.647899  27.764117
# 4  개포동   75.461  7.322618e+06  118.0   31          1  46.647899  27.764117
#
#    매매가격 지수 증감률 매매 대비 전세가격 비율
# 0     1.243615        70.059
# 1     1.243615        70.059
# 2     1.243615        70.059
# 3     2.459291        69.322
# 4     2.459291        69.322
#
# [5 rows x 93 columns]

# %%
len(df['아파트명'].unique())
# Out:
# 6550

# %%
# 아파트명에서 키워드를 찾아 카테고리 열 생성
categories = ['더퍼스트', '센트럴', '파크', '포레', '메트로', '에듀', '시티']

# %%
for category in categories:
    df[category] = df['아파트명'].str.contains(category)

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ...     거래활발지수  매매가격 지수 증감률 매매 대비 전세가격 비율   더퍼스트    센트럴     파크  \
# 0        1987  ...  17.693929     1.243615     70.059000  False  False  False
# 1        1987  ...  17.693929     1.243615     70.059000  False  False  False
# 2        1987  ...  17.693929     1.243615     70.059000  False  False  False
# 3        1987  ...  27.764117     2.459291     69.322000  False  False  False
# 4        1987  ...  27.764117     2.459291     69.322000  False  False  False
# ...       ...  ...        ...          ...           ...    ...    ...    ...
# 1128089  2014  ...  12.462049    -0.641286     50.938744  False  False  False
# 1128090  2014  ...  12.462049    -0.641286     50.938744  False  False  False
# 1128091  2014  ...  13.703570    -0.607676     50.991003  False  False  False
# 1128092  2014  ...  17.287617    -0.225827     51.082553  False  False  False
# 1128093  2014  ...  17.287617    -0.225827     51.082553  False  False  False
#
#             포레    메트로     에듀     시티
# 0        False  False  False  False
# 1        False  False  False  False
# 2        False  False  False  False
# 3        False  False  False  False
# 4        False  False  False  False
# ...        ...    ...    ...    ...
# 1128089  False  False  False  False
# 1128090  False  False  False  False
# 1128091  False  False  False  False
# 1128092  False  False  False  False
# 1128093  False  False  False  False
#
# [1128094 rows x 100 columns]

# %%
# '리버'와 '레이크'를 하나의 카테고리 '리버레이크'로 보기
df['리버 or 레이크'] = df['아파트명'].str.contains('리버|레이크')

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 매매가격 지수 증감률  매매 대비 전세가격 비율   더퍼스트    센트럴     파크     포레  \
# 0        1987  ...    1.243615      70.059000  False  False  False  False
# 1        1987  ...    1.243615      70.059000  False  False  False  False
# 2        1987  ...    1.243615      70.059000  False  False  False  False
# 3        1987  ...    2.459291      69.322000  False  False  False  False
# 4        1987  ...    2.459291      69.322000  False  False  False  False
# ...       ...  ...         ...            ...    ...    ...    ...    ...
# 1128089  2014  ...   -0.641286      50.938744  False  False  False  False
# 1128090  2014  ...   -0.641286      50.938744  False  False  False  False
# 1128091  2014  ...   -0.607676      50.991003  False  False  False  False
# 1128092  2014  ...   -0.225827      51.082553  False  False  False  False
# 1128093  2014  ...   -0.225827      51.082553  False  False  False  False
#
#            메트로     에듀     시티 리버 or 레이크
# 0        False  False  False     False
# 1        False  False  False     False
# 2        False  False  False     False
# 3        False  False  False     False
# 4        False  False  False     False
# ...        ...    ...    ...       ...
# 1128089  False  False  False     False
# 1128090  False  False  False     False
# 1128091  False  False  False     False
# 1128092  False  False  False     False
# 1128093  False  False  False     False
#
# [1128094 rows x 101 columns]

# %%
# '기타' 카테고리 열 생성
df['기타'] = ~df[categories + ['리버 or 레이크']].any(axis=1)

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ... 매매 대비 전세가격 비율   더퍼스트    센트럴     파크     포레    메트로     에듀  \
# 0        1987  ...     70.059000  False  False  False  False  False  False
# 1        1987  ...     70.059000  False  False  False  False  False  False
# 2        1987  ...     70.059000  False  False  False  False  False  False
# 3        1987  ...     69.322000  False  False  False  False  False  False
# 4        1987  ...     69.322000  False  False  False  False  False  False
# ...       ...  ...           ...    ...    ...    ...    ...    ...    ...
# 1128089  2014  ...     50.938744  False  False  False  False  False  False
# 1128090  2014  ...     50.938744  False  False  False  False  False  False
# 1128091  2014  ...     50.991003  False  False  False  False  False  False
# 1128092  2014  ...     51.082553  False  False  False  False  False  False
# 1128093  2014  ...     51.082553  False  False  False  False  False  False
#
#             시티  리버 or 레이크    기타
# 0        False      False  True
# 1        False      False  True
# 2        False      False  True
# 3        False      False  True
# 4        False      False  True
# ...        ...        ...   ...
# 1128089  False      False  True
# 1128090  False      False  True
# 1128091  False      False  True
# 1128092  False      False  True
# 1128093  False      False  True
#
# [1128094 rows x 102 columns]

# %%
# '카테고리' 열을 범주형으로 변환
df['아파트 카테고리'] = df[categories + ['리버 or 레이크', '기타']].idxmax(axis=1)

# %%
df
# Out:
#                    시군구     번지     본번   부번      아파트명    전용면적    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0  1.0    개포6차우성   79.97  201801    8   2
# ...                ...    ...    ...  ...       ...     ...     ...  ...  ..
# 1128089  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202307   19  13
# 1128090  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.62  202307   25  12
# 1128091  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지  101.65  202308   27  12
# 1128092  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.94  202309    2  18
# 1128093  서울특별시 중랑구 신내동    816  816.0  0.0  신내우디안1단지   84.65  202309    4  13
#
#          건축년도  ...   더퍼스트    센트럴     파크     포레    메트로     에듀     시티 리버 or 레이크  \
# 0        1987  ...  False  False  False  False  False  False  False     False
# 1        1987  ...  False  False  False  False  False  False  False     False
# 2        1987  ...  False  False  False  False  False  False  False     False
# 3        1987  ...  False  False  False  False  False  False  False     False
# 4        1987  ...  False  False  False  False  False  False  False     False
# ...       ...  ...    ...    ...    ...    ...    ...    ...    ...       ...
# 1128089  2014  ...  False  False  False  False  False  False  False     False
# 1128090  2014  ...  False  False  False  False  False  False  False     False
# 1128091  2014  ...  False  False  False  False  False  False  False     False
# 1128092  2014  ...  False  False  False  False  False  False  False     False
# 1128093  2014  ...  False  False  False  False  False  False  False     False
#
#            기타 아파트 카테고리
# 0        True       기타
# 1        True       기타
# 2        True       기타
# 3        True       기타
# 4        True       기타
# ...       ...      ...
# 1128089  True       기타
# 1128090  True       기타
# 1128091  True       기타
# 1128092  True       기타
# 1128093  True       기타
#
# [1128094 rows x 103 columns]

# %%
# 카테고리별 평균 실거래가 계산
category_mean_target = df.groupby('아파트 카테고리')['target'].mean().reset_index()
category_mean_target = category_mean_target.rename(columns={'target': '평균 실거래가'})

# %%
category_mean_target
# Out:
#     아파트 카테고리       평균 실거래가
# 0         기타  56650.223323
# 1       더퍼스트  78270.406504
# 2  리버 or 레이크  84970.286950
# 3        메트로  34670.920635
# 4        센트럴  93529.680190
# 5         시티  57844.503143
# 6         에듀  81311.315789
# 7         파크  75491.250991
# 8         포레  94839.497214

# %%
# 그래프 그리기
plt.figure(figsize=(10, 6))
sns.barplot(x='아파트 카테고리', y='평균 실거래가', data=category_mean_target)
plt.title('각 카테고리별 평균 실거래가 비교')
plt.xlabel('카테고리')
plt.ylabel('평균 실거래가')
plt.show()

columns_to_drop = categories + ['리버 or 레이크', '기타']

# %%
columns_to_drop = categories + ['리버 or 레이크', '기타']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df['아파트 카테고리']
# Out:
# 0          기타
# 1          기타
# 2          기타
# 3          기타
# 4          기타
#            ..
# 1128089    기타
# 1128090    기타
# 1128091    기타
# 1128092    기타
# 1128093    기타
# Name: 아파트 카테고리, Length: 1128094, dtype: object

# %%
df['아파트 카테고리'].astype('category')
# Out:
# 0          기타
# 1          기타
# 2          기타
# 3          기타
# 4          기타
#            ..
# 1128089    기타
# 1128090    기타
# 1128091    기타
# 1128092    기타
# 1128093    기타
# Name: 아파트 카테고리, Length: 1128094, dtype: category
# Categories (9, object): ['기타', '더퍼스트', '리버 or 레이크', '메트로', ..., '시티', '에듀', '파크', '포레']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128094 entries, 0 to 1128093
# Data columns (total 94 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   시군구                   1128094 non-null  object
#  1   번지                    1127867 non-null  object
#  2   본번                    1128019 non-null  float64
#  3   부번                    1128019 non-null  float64
#  4   아파트명                  1125958 non-null  object
#  5   전용면적                  1128094 non-null  float64
#  6   계약년월                  1128094 non-null  int64
#  7   계약일                   1128094 non-null  int64
#  8   층                     1128094 non-null  int64
#  9   건축년도                  1128094 non-null  int64
#  10  도로명                   1128094 non-null  object
#  11  해제사유발생일               6195 non-null     float64
#  12  등기신청일자                1128094 non-null  object
#  13  거래유형                  1128094 non-null  object
#  14  중개사소재지                1128094 non-null  object
#  15  k-단지분류(아파트,주상복합등등)    250821 non-null   object
#  16  k-전화번호                251244 non-null   object
#  17  k-팩스번호                248746 non-null   object
#  18  단지소개기존clob            69136 non-null    float64
#  19  k-세대타입(분양형태)          251969 non-null   object
#  20  k-관리방식                251969 non-null   object
#  21  k-복도유형                251640 non-null   object
#  22  k-난방방식                251969 non-null   object
#  23  k-전체동수                250887 non-null   float64
#  24  k-전체세대수               251969 non-null   float64
#  25  k-건설사(시공사)            1128094 non-null  object
#  26  k-시행사                 250260 non-null   object
#  27  k-사용검사일-사용승인일         251835 non-null   object
#  28  k-연면적                 251969 non-null   float64
#  29  k-주거전용면적              251924 non-null   float64
#  30  k-관리비부과면적             251969 non-null   float64
#  31  k-전용면적별세대현황(60이하)     251924 non-null   float64
#  32  k-전용면적별세대현황(60~85이하)  251924 non-null   float64
#  33  k-85~135이하            251924 non-null   float64
#  34  k-135초과               329 non-null      float64
#  35  k-홈페이지                114571 non-null   object
#  36  k-등록일자                11708 non-null    object
#  37  k-수정일자                251924 non-null   object
#  38  고용보험관리번호              207337 non-null   object
#  39  경비비관리형태               250533 non-null   object
#  40  세대전기계약방법              242705 non-null   object
#  41  청소비관리형태               250343 non-null   object
#  42  건축면적                  251815 non-null   float64
#  43  주차대수                  251817 non-null   float64
#  44  기타/의무/임대/임의=1/2/3/4   251969 non-null   object
#  45  단지승인일                 251240 non-null   object
#  46  사용허가여부                251969 non-null   object
#  47  관리비 업로드               251969 non-null   object
#  48  좌표X                   1128094 non-null  float64
#  49  좌표Y                   1128094 non-null  float64
#  50  단지신청일                 251907 non-null   object
#  51  target                1118822 non-null  float64
#  52  is_test               1128094 non-null  int64
#  53  시군구 번지                1127867 non-null  object
#  54  좌표X,좌표Y               1128094 non-null  object
#  55  가장 가까운 거리             1128094 non-null  float64
#  56  index                 1128094 non-null  float64
#  57  역사_ID                 1128094 non-null  float64
#  58  역사명                   1128094 non-null  object
#  59  호선                    1128094 non-null  object
#  60  위도                    1128094 non-null  float64
#  61  경도                    1128094 non-null  float64
#  62  인근 지하철 역 개수           1128094 non-null  float64
#  63  가장 가까운 버스 정류장 거리      1128094 non-null  float64
#  64  가장 가까운 버스 정류장 index   1128094 non-null  float64
#  65  가장 가까운 버스 정류장 노드 ID   1128094 non-null  float64
#  66  가장 가까운 버스 정류소번호       1128094 non-null  float64
#  67  가장 가까운 버스 정류소명        1128094 non-null  object
#  68  가장 가까운 버스 정류소 타입      1128094 non-null  object
#  69  가장 가까운 버스 정류장 X좌표     1128094 non-null  float64
#  70  가장 가까운 버스 정류장 Y좌표     1128094 non-null  float64
#  71  인근 버스 정류장 개수          1128094 non-null  float64
#  72  계약년                   1128094 non-null  int64
#  73  계약월                   1128094 non-null  int64
#  74  GDP                   1128094 non-null  float64
#  75  한국은행 기준금리             1128094 non-null  float64
#  76  기대 인플레이션              1128094 non-null  float64
#  77  지가지수                  1128094 non-null  float64
#  78  아파트 인허가               1128094 non-null  float64
#  79  미분양                   1128094 non-null  float64
#  80  거래량                   1128094 non-null  float64
#  81  건설사 랭킹                1128094 non-null  float64
#  82  구                     1128094 non-null  object
#  83  동                     1128094 non-null  object
#  84  구별 지가지수               1128094 non-null  float64
#  85  공시지가 평균               1128094 non-null  float64
#  86  매수우위지수                1128094 non-null  float64
#  87  건물나이                  1128094 non-null  int64
#  88  30년이상50년이하            1128094 non-null  int64
#  89  구매력지수                 1128094 non-null  float64
#  90  거래활발지수                1128094 non-null  float64
#  91  매매가격 지수 증감률           1128094 non-null  float64
#  92  매매 대비 전세가격 비율         1128094 non-null  float64
#  93  아파트 카테고리              1128094 non-null  object
# dtypes: float64(47), int64(9), object(38)
# memory usage: 809.0+ MB

# %%
df.to_csv('../data/preprocessed/21_apart_name.csv', index=False)
