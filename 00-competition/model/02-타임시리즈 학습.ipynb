# %%
import re
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt

from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder

import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 통합 데이터 로드

# %%
total_df = pd.read_csv('../data/team/5_interest_rate.csv')
# Out:
# /tmp/ipykernel_1695424/3485981028.py:1: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   total_df = pd.read_csv('../data/team/5_interest_rate.csv')

# %%
print(total_df.shape)
print(total_df.columns)
# Out:
# (1128094, 76)
# Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도',
#        '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)',
#        'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형',
#        'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일',
#        'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)',
#        'k-전용면적별세대현황(60~85이하)', 'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자',
#        'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태', '건축면적', '주차대수',
#        '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드', '좌표X', '좌표Y',
#        '단지신청일', 'target', 'is_test', '시군구 번지', '좌표X,좌표Y', '가장 가까운 거리', 'index',
#        '역사_ID', '역사명', '호선', '위도', '경도', '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리',
#        '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호',
#        '가장 가까운 버스 정류소명', '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표',
#        '가장 가까운 버스 정류장 Y좌표', '인근 버스 정류장 개수', '계약년', '계약월', 'GDP', '한국은행 기준금리'],
#       dtype='object')

# %%
total_df.head()
# Out:
#              시군구     번지     본번   부번    아파트명   전용면적    계약년월  계약일  층  건축년도  ...  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712    8  3  1987  ...
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201712   22  4  1987  ...
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  54.98  201712   28  5  1987  ...
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    3  4  1987  ...
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성  79.97  201801    8  2  1987  ...
#
#   가장 가까운 버스 정류소번호  가장 가까운 버스 정류소명 가장 가까운 버스 정류소 타입 가장 가까운 버스 정류장 X좌표  \
# 0         23445.0         개포우성아파트             일반차로        127.057864
# 1         23445.0         개포우성아파트             일반차로        127.057864
# 2         23445.0         개포우성아파트             일반차로        127.057864
# 3         23445.0         개포우성아파트             일반차로        127.057864
# 4         23445.0         개포우성아파트             일반차로        127.057864
#
#   가장 가까운 버스 정류장 Y좌표 인근 버스 정류장 개수   계약년 계약월        GDP 한국은행 기준금리
# 0         37.476564          7.0  2017  12  1623074.1       1.5
# 1         37.476564          7.0  2017  12  1623074.1       1.5
# 2         37.476564          7.0  2017  12  1623074.1       1.5
# 3         37.476564          7.0  2018   1  1725373.4       1.5
# 4         37.476564          7.0  2018   1  1725373.4       1.5
#
# [5 rows x 76 columns]

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128094 entries, 0 to 1128093
# Data columns (total 76 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   시군구                   1128094 non-null  object
#  1   번지                    1127867 non-null  object
#  2   본번                    1128019 non-null  float64
#  3   부번                    1128019 non-null  float64
#  4   아파트명                  1125958 non-null  object
#  5   전용면적                  1128094 non-null  float64
#  6   계약년월                  1128094 non-null  int64
#  7   계약일                   1128094 non-null  int64
#  8   층                     1128094 non-null  int64
#  9   건축년도                  1128094 non-null  int64
#  10  도로명                   1128094 non-null  object
#  11  해제사유발생일               6195 non-null     float64
#  12  등기신청일자                1128094 non-null  object
#  13  거래유형                  1128094 non-null  object
#  14  중개사소재지                1128094 non-null  object
#  15  k-단지분류(아파트,주상복합등등)    250821 non-null   object
#  16  k-전화번호                251244 non-null   object
#  17  k-팩스번호                248746 non-null   object
#  18  단지소개기존clob            69136 non-null    float64
#  19  k-세대타입(분양형태)          251969 non-null   object
#  20  k-관리방식                251969 non-null   object
#  21  k-복도유형                251640 non-null   object
#  22  k-난방방식                251969 non-null   object
#  23  k-전체동수                250887 non-null   float64
#  24  k-전체세대수               251969 non-null   float64
#  25  k-건설사(시공사)            250457 non-null   object
#  26  k-시행사                 250260 non-null   object
#  27  k-사용검사일-사용승인일         251835 non-null   object
#  28  k-연면적                 251969 non-null   float64
#  29  k-주거전용면적              251924 non-null   float64
#  30  k-관리비부과면적             251969 non-null   float64
#  31  k-전용면적별세대현황(60이하)     251924 non-null   float64
#  32  k-전용면적별세대현황(60~85이하)  251924 non-null   float64
#  33  k-85~135이하            251924 non-null   float64
#  34  k-135초과               329 non-null      float64
#  35  k-홈페이지                114571 non-null   object
#  36  k-등록일자                11708 non-null    object
#  37  k-수정일자                251924 non-null   object
#  38  고용보험관리번호              207337 non-null   object
#  39  경비비관리형태               250533 non-null   object
#  40  세대전기계약방법              242705 non-null   object
#  41  청소비관리형태               250343 non-null   object
#  42  건축면적                  251815 non-null   float64
#  43  주차대수                  251817 non-null   float64
#  44  기타/의무/임대/임의=1/2/3/4   251969 non-null   object
#  45  단지승인일                 251240 non-null   object
#  46  사용허가여부                251969 non-null   object
#  47  관리비 업로드               251969 non-null   object
#  48  좌표X                   1128094 non-null  float64
#  49  좌표Y                   1128094 non-null  float64
#  50  단지신청일                 251907 non-null   object
#  51  target                1118822 non-null  float64
#  52  is_test               1128094 non-null  int64
#  53  시군구 번지                1127867 non-null  object
#  54  좌표X,좌표Y               1128094 non-null  object
#  55  가장 가까운 거리             1128094 non-null  float64
#  56  index                 1128094 non-null  float64
#  57  역사_ID                 1128094 non-null  float64
#  58  역사명                   1128094 non-null  object
#  59  호선                    1128094 non-null  object
#  60  위도                    1128094 non-null  float64
#  61  경도                    1128094 non-null  float64
#  62  인근 지하철 역 개수           1128094 non-null  float64
#  63  가장 가까운 버스 정류장 거리      1128094 non-null  float64
#  64  가장 가까운 버스 정류장 index   1128094 non-null  float64
#  65  가장 가까운 버스 정류장 노드 ID   1128094 non-null  float64
#  66  가장 가까운 버스 정류소번호       1128094 non-null  float64
#  67  가장 가까운 버스 정류소명        1128094 non-null  object
#  68  가장 가까운 버스 정류소 타입      1128094 non-null  object
#  69  가장 가까운 버스 정류장 X좌표     1128094 non-null  float64
#  70  가장 가까운 버스 정류장 Y좌표     1128094 non-null  float64
#  71  인근 버스 정류장 개수          1128094 non-null  float64
#  72  계약년                   1128094 non-null  int64
#  73  계약월                   1128094 non-null  int64
#  74  GDP                   1128094 non-null  float64
#  75  한국은행 기준금리             1128094 non-null  float64
# dtypes: float64(34), int64(7), object(35)
# memory usage: 654.1+ MB

# %% [markdown]
# ## 컬럼 삭제

# %%
# 추가로 제거가 필요한 feature 제거
total_df.drop([
    # '시군구', 
    # '번지',
    # '도로명',
    # '아파트명', 
    # 'k-건설사(시공사)',
    '본번',
    '부번',
    'k-세대타입(분양형태)', 
    '거래유형', 
    'k-시행사', 
    'k-연면적', 
    'k-주거전용면적',
    'k-관리방식',
    '해제사유발생일',
    '등기신청일자',
    '중개사소재지', 'k-단지분류(아파트,주상복합등등)', 'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-복도유형', 'k-난방방식', 'k-전체동수',
    '세대전기계약방법', '청소비관리형태', '건축면적', 'k-사용검사일-사용승인일', 'k-관리비부과면적', 'k-전용면적별세대현황(60이하)', '시군구 번지', 
    '좌표X,좌표Y', 'index', '역사_ID', '역사명', '위도', '경도',
    '가장 가까운 버스 정류장 index', '가장 가까운 버스 정류장 노드 ID', '가장 가까운 버스 정류소번호', '가장 가까운 버스 정류소명',
    '가장 가까운 버스 정류소 타입', '가장 가까운 버스 정류장 X좌표', '가장 가까운 버스 정류장 Y좌표', '호선',
    'k-전용면적별세대현황(60~85이하)', 'k-85~135이하', 'k-135초과', 'k-홈페이지', 'k-등록일자',
    'k-수정일자', '고용보험관리번호', '경비비관리형태', '기타/의무/임대/임의=1/2/3/4', '단지승인일',
    '사용허가여부', '관리비 업로드', '좌표X', '좌표Y', '단지신청일',
    '계약년', '계약월',
], axis=1, inplace=True)

display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 20)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-전체세대수', 'k-건설사(시공사)', '주차대수', 'target', 'is_test', '가장 가까운 거리',
#        '인근 지하철 역 개수', '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  k-전체세대수  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3    270.0
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3    270.0
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3    270.0
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3    270.0
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3    270.0
#
#   k-건설사(시공사)   주차대수    target  is_test    가장 가까운 거리  인근 지하철 역 개수  \
# 0       우성건설  262.0  124000.0        0  1127.738351          2.0
# 1       우성건설  262.0  123500.0        0  1127.738351          2.0
# 2       우성건설  262.0   91500.0        0  1127.738351          2.0
# 3       우성건설  262.0  130000.0        0  1127.738351          2.0
# 4       우성건설  262.0  117000.0        0  1127.738351          2.0
#
#    가장 가까운 버스 정류장 거리  인근 버스 정류장 개수        GDP  한국은행 기준금리
# 0          61.89584           7.0  1623074.1        1.5
# 1          61.89584           7.0  1623074.1        1.5
# 2          61.89584           7.0  1623074.1        1.5
# 3          61.89584           7.0  1725373.4        1.5
# 4          61.89584           7.0  1725373.4        1.5

# %% [markdown]
# ## 파생변수1 - 세대별 주차대수

# %%
total_df['세대별_주차대수'] = total_df['주차대수'] / total_df['k-전체세대수']

total_df.drop(['주차대수', 'k-전체세대수'], axis=1, inplace=True)
display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 19)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-건설사(시공사)', 'target', 'is_test', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리', '세대별_주차대수'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3
#
#   k-건설사(시공사)    target  is_test    가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  \
# 0       우성건설  124000.0        0  1127.738351          2.0          61.89584
# 1       우성건설  123500.0        0  1127.738351          2.0          61.89584
# 2       우성건설   91500.0        0  1127.738351          2.0          61.89584
# 3       우성건설  130000.0        0  1127.738351          2.0          61.89584
# 4       우성건설  117000.0        0  1127.738351          2.0          61.89584
#
#    인근 버스 정류장 개수        GDP  한국은행 기준금리  세대별_주차대수
# 0           7.0  1623074.1        1.5   0.97037
# 1           7.0  1623074.1        1.5   0.97037
# 2           7.0  1623074.1        1.5   0.97037
# 3           7.0  1725373.4        1.5   0.97037
# 4           7.0  1725373.4        1.5   0.97037

# %% [markdown]
# ### 파생변수2 - 건설사 랭크

# %%
# 동의어 사전
synonyms = {
    '삼성물산': ['삼성물산주식회사', '삼성물산(주)', '삼성물산 건설부문', '삼성물산(주) 건설부문', '삼성물산,두산건설', '삼성물산(주) 주택부문', "삼성건설", "삼성건설(주)", "삼성래미안", "삼성물산",
               "(주)삼성물산", "삼성", "삼성물산", "삼성중공업", "(주)삼성", "삼성물산, 건설부문", "삼성물산, 주택부문"],
    '현대건설': ['현대건설(주)', '현대건설주식회사', '(주)현대건설', '현대산업개발', '현대산업개발(주)', 'HDC현대산업개발', '현대bs&c', '현대BS&C', "(주)현대산업개발", "현대산업개발", 
               "주식회사 현대건설", "현대", "현대산업개발 주", "현대종합건설", "주시회사 현대건설", "현대산업개발", "현대엔지니어링", "현대힐스테이트", "주시회사, 현대건설", "현대건설, 주"],
    '대림산업': ['대림산업(주)', '대림산업주식회사', '(주)대림산업', '대림건설', '대림건설(주)', "(주)대림", "대림", "대림산업", "대림산업 (주)", "대림산업"],
    '대우건설': ['대우건설(주)', '대우푸르지오', "(주)대우", "(주)대우건설", "대우건설", "주)대우건설", "대우경남", "대우", "대우자동차판매"],
    'GS건설': ['GS건설(주)', '지에스 건설', '지에스건설주식회사', '지에스건설(주)', "(주)gs공사", "GS 건설", "GS건설", "GS건설주식회사", "GS자이 건설", "gs건설", "럭키외", "GS", "gs공사",
              'GS건설, unknown', 'GS자이, unknown', "지에스, unknown", '지에스건설'],
    "SK건설": ["(주)에스케이건설", "SK", "에스케이건설"],
    '한라건설': ['(주)한라', '한라건설', '(주)한라건설', '한라'],
    '롯데건설': ['롯데건설(주)', '롯데건설주식회사', "(주)롯데건설", "롯데건설"],
    '한화건설': ['(주)한화건설', '한화건설(주)'],
    '두산건설': ['두산건설주식회사', '두산건설(주)', "두산", "두산건설", "두산건설(주)", "두산건설주식회사"],
    '우성건설': ['우성건설(주)', '(주)우성건설', '우성건설(주)'],
    '포스코건설': ['(주)포스코건설', '포스코, 포스코A&C', '포스코', '포스코', '포스코건설, 포스코A&C'],
    'SH공사': ['sh공사', '에스에이치공사', 'SH', "SH공사", "sh 공사", "sh, 공사", "(주)에스에이치건설", "서울도시개발공사", "주택공사", "도시개발공사", "에스에이치건설"],
    '건영건설': ['(주)건영', '(주) 건영', "(주) 건영", "건영", "건영건설", "건영종합건설(주)", " (주) 건영", "건영종합건설"],
    '신동아건설': ['신동아건설(주)', '신동아 건설(주)', '신동아', '신동아건설', '신동아건설(주)', "신동아건설, unknown"],
    '계룡건설': ['계룡건설(주)', '계룡건설산업(주)'],
    '코오롱건설': ['코오롱글로벌(주)', '코오롱글로벌', '코오롱건설주식회사'],
    '성원건설': ['성원건설(주)', '(주)성원건설'],
    "금호건설": ["(주)금호", "(주)금호건설", "(주)금호산업", "금호", "금호건설", "금호건설(주)", "금호산업", "금호자이"],
    "동아건설": ["(주)동아건설산업", "동아건설", "동아건설산업(주)", "동아건설산업"],
    "동일토건": ["(주)동일토건", "동일토건"],
    "LG건설": ["엘지건설(주)", "엘지건설"],
    "한일건설" : ["한일개발"],
    "삼호건설": ["삼호건설", "삼호주택", "(주)삼호"],
    "서광산업": ["(주)서광건설산업", "서광산업"],
    "서희건설": ["(주)서희건설", "서희건설", "주식회사 서희건설", 'unknown, 서희건설'],
    "신성건설": ["(주)신성건설", "신성건설", "신성건설(주)"],
    "신창건설": ["(주)신창건설", "신창건설", "신창건설(주)->우방건설", "신창건설->우방건설"],
    "쌍용건설": ["(주)쌍용건설", "쌍용건설", "쌍용건설(주)", "쌍용건설(주)", "쌍용"],
    "우방건설": ["(주)우방", "우방", "우방건설"],
    "우리건설": ["(주)우리건설", "우리건설", "우리창우"],
    "일성건설": ["(주)일성건설", "일성건설", "(주)일성건설"],
    "임광건설": ["임광토건(주)"],
    "청구건설": ["청구", "청구주택"],
    "남광건설" : ["남광", "남광토건(주)", "남광토건"],
    "풍림건설" : ["풍림산업"],
    "중앙건설": ["(주)중앙건설", "중앙건설", "중앙건설(주)"],
    "태영건설": ["(주)태영", "(주)태영건설", "태영건설", "태영"],
    "한양건설": ["(주)한양", "(주)한양건설", "한양", "한양건설", "한양", "한양건설", "한양수자인", "한양주택 (주)", "?양건설", "한양산업개발", "한양산업개발(주", "한양주택"],
    "한진건설": ["(주)한진중공업", "한진중공업", "한진중공업(주)", "한진중공업", "한진건설(주)"],
    "한신건설": ["한신공영", "한신공영(주)"],
    "효성건설": ["(주)효성", "(주)효성건설", "효성건설", "효성중공업", "효성"],
    "KCC건설": ["KCC", "kcc건설"],
    "동부건설": ["동부건설", "동부건설(주)", "동부건설(주)외1", "동부건설외1"],
    "이수건설": ["이수건설", "이수건설(주)", "이수건설,대우엔지니어링"],
    "삼성중공업": ["삼성중공업", "삼성중공업(주)"],
    "호반건설" : ["(주)호반건설"],
    "LIG건설" : ["LIG건설", "LIG건설(주)"],
    "경남기업": ["경남기업", "경남기업(주)"],
    "경향건설": ["경향건설(주)"],
    "계룡건설": ["계룡건설산업", "계룡건설(주)", "계룡건설산업(주)"],
    "고려개발": ["고려개발", "고려개발(주)", "고려산업개발", "고려산업개발(주)", "고려개발(주)", "고려산업개발", "고려산업개발(주)"],
    "극동건설" : ["극동건설", "극동건설(주)"],
    "나산건설" : ["나산종합건설"],
    "라이프건설": ["라이프주택"],
    "신도건설": ["(주)신도종합건설", "신도종합건설"],
    "쌍용건설": ["쌍용"],
    "우림건설": ["우림건설", "우림건설(주)"],
    "유원건설": ["유원건설", "유원건설(주)", '울트라건설', '울트라건설(주)', "유원울트라", "유원"],
    "월드건설": ['월드건설', '월드건설(주)'],
    '인정건설' : ['인정건설', '인정건설(주)'],
    "흥화건설": ["흥화공업", "흥화공업(주)"],
    "한솔건설": ["한솔"],
    "한보건설": ["한보", "한보철강", "한보철강", '한보철상'],
    "고려개발": ["고려개발 "],
    "동양메이저건설": ["동양메이저(주)", "동양고속건설주식회사", "동양메이저"],
    "동일건설": ["동일토건", "동일하이빌", "동일", "동일하이빌"],
    "두산건설": ["두산", "두산중공업"],
    "미주건설": ["미주실업주식회사", "미주실업"],
    "벽산건설": ["벽산건설(주)"],
    "삼익건설": ["삼익주택(주)", "삼익주택", "삼익주택(주)", "삼익건설(주)", "unknown, 삼익건설", "청담삼익아파트"],
    "삼정건설": ["삼정기업"],
    "삼환건설": ["삼환기업", "삼환"],
    "세양건설": ["세양건설산업"],
    "신동아건설": ['신동아'],
    "양우건설": ['양우건설(주)', "양우건설사"],
    "우성건설": ["우성"],
    "우정건설": ["우정건설 주식회사", "우정건설, unknown"],
    "중앙건설": ["중앙하이츠", "중앙건설(주)"],
    "진흥건설": ["진흥기업", "진흥연립재건축조합", "진흥기업", "(주)진흥기업", "진흥기업", "진흥기업(주)", "진흥기업"],
    '풍림건설': ['풍림산업(주)', '풍림산업'],
    "신일건업": ['신일산업', '(주)신일건업'],
    "동일건설": ['동일토건', '동일'],
    '세양건설': ['세양건설산업(주)'],
    '라이프건설' : ['라이프주택'],
    '미주건설' : ['미주실업'],
    '선경건설' : ['선경'],
    "unknown" : ['(주)', '주식회사', '건설', 'nan', '박연정', '재건축조합']
}

# (주) 제거하는 함수
def remove_corporate_suffix(name):
    return name.replace('(주)', '').strip()

# 여러 구분자를 처리하는 정규 표현식 패턴
def split_builders(builders):
    pattern = re.compile(r'[\/,\s]+')
    return pattern.split(builders.strip())

# 동의어 대체 함수
def replace_synonyms(value, synonyms_dict):
    for key, values in synonyms_dict.items():
        if value in values:
            return key
    return value

# 여러 문자열을 처리하는 함수
def process_builders(builders, synonyms_dict):
    builders_list = split_builders(builders)
    processed_list = [replace_synonyms(builder, synonyms_dict) for builder in builders_list]
    return ', '.join(processed_list)


# 문자열이 아닌 값을 문자열로 변환
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(lambda x: str(x) if not isinstance(x, str) else x)

# (주) 제거
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(remove_corporate_suffix)

# 동의어 처리 및 리스트를 문자열로 변환
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].apply(lambda x: process_builders(x, synonyms))

# %%
total_df['k-건설사(시공사)'] = total_df['k-건설사(시공사)'].replace({
    'GS건설, unknown': 'GS건설',
    'GS자이, unknown': 'GS건설',
    'unknown, 삼익건설' : '삼익건설',
    'unknown, 서희건설' : '서희건설',
    '고려산업개발' : '고려개발',
    "sh, 공사" : "SH공사",
    "동일토건" : "동일건설",
    "동일하이빌" : "동일건설",
    "두산건설주식회사" : "두산건설",
    "미주실업주식회사" : "미주건설",
    "삼성물산, 건설부문" : "삼성물산",
    "삼성물산, 주택부문" : "삼성물산",
    "삼호" : "삼호건설",
    "서광건설산업" : "서광건설",
    "세양건설산업" : "세양건설",
    "신동아건설, unknown" : "신동아건설",
    "우정건설, unknown" : "우정건설",
    "주시회사, 현대건설" : "현대건설",
    "지에스, unknown" : "GS건설",
    "포스코건설, 포스코A&C" : "포스코건설",
    "현대건설, 주" : "현대건설"
})

# %%
# 1. target 컬럼값의 로그 변환
total_df["log_target"] = np.log1p(total_df["target"])

# 2. 변환된 target 값의 평균 계산
builder_mean_target = total_df.groupby("k-건설사(시공사)")["log_target"].mean()

# 3. 평균 로그 변환 가격에 따라 랭킹을 매깁니다 (값이 높을수록 높은 랭크)
builder_rankings = builder_mean_target.rank(ascending=False)

# 4. 건설사별 랭킹을 딕셔너리로 변환
builder_rankings_dict = builder_rankings.to_dict()

# 5. df에 '건설사랭크' 컬럼 추가
total_df["건설사랭크"] = total_df["k-건설사(시공사)"].map(builder_rankings_dict)
total_df = total_df.drop(columns=['log_target'])

# %%
display(total_df.shape)
display(total_df.columns)
display(total_df.head())
# Out:
# (1128094, 20)
# Index(['시군구', '번지', '아파트명', '전용면적', '계약년월', '계약일', '층', '건축년도', '도로명',
#        'k-건설사(시공사)', 'target', 'is_test', '가장 가까운 거리', '인근 지하철 역 개수',
#        '가장 가까운 버스 정류장 거리', '인근 버스 정류장 개수', 'GDP', '한국은행 기준금리', '세대별_주차대수',
#        '건설사랭크'],
#       dtype='object')
#              시군구     번지    아파트명   전용면적    계약년월  계약일  층  건축년도    도로명  \
# 0  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712    8  3  1987  언주로 3
# 1  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201712   22  4  1987  언주로 3
# 2  서울특별시 강남구 개포동  658-1  개포6차우성  54.98  201712   28  5  1987  언주로 3
# 3  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    3  4  1987  언주로 3
# 4  서울특별시 강남구 개포동  658-1  개포6차우성  79.97  201801    8  2  1987  언주로 3
#
#   k-건설사(시공사)    target  is_test    가장 가까운 거리  인근 지하철 역 개수  가장 가까운 버스 정류장 거리  \
# 0       우성건설  124000.0        0  1127.738351          2.0          61.89584
# 1       우성건설  123500.0        0  1127.738351          2.0          61.89584
# 2       우성건설   91500.0        0  1127.738351          2.0          61.89584
# 3       우성건설  130000.0        0  1127.738351          2.0          61.89584
# 4       우성건설  117000.0        0  1127.738351          2.0          61.89584
#
#    인근 버스 정류장 개수        GDP  한국은행 기준금리  세대별_주차대수  건설사랭크
# 0           7.0  1623074.1        1.5   0.97037  106.0
# 1           7.0  1623074.1        1.5   0.97037  106.0
# 2           7.0  1623074.1        1.5   0.97037  106.0
# 3           7.0  1725373.4        1.5   0.97037  106.0
# 4           7.0  1725373.4        1.5   0.97037  106.0

# %% [markdown]
# ## train과 test의 분포 맞춰주기

# %%
total_df.drop(columns=['계약일', '층', '건축년도', 'k-건설사(시공사)'], axis=1, inplace=True)
total_df = total_df.rename(columns={'가장 가까운 거리' : '최근접_지하철역_거리',
                                    '인근 지하철 역 개수' : '인근_지하철역_개수',
                                    '가장 가까운 버스 정류장 거리' : '최근접_버스정류장_거리',
                                    '인근 버스 정류장 개수' : '인근_버스정류장_개수',
                                    '한국은행 기준금리' : '기준금리'})

# %%
train_df = total_df[total_df['is_test'] == 0]
test_df = total_df[total_df['is_test'] == 1]

train_df = train_df.drop(columns=['is_test'])
test_df = test_df.drop(columns=['is_test', 'target'])
print(train_df.shape, test_df.shape)
# Out:
# (1118822, 15) (9272, 14)

# %%
# train_df = train_df[train_df['아파트명'].isin(test_df['아파트명'])]
# train_df = train_df[train_df['도로명'].isin(test_df['도로명'])]
# train_df = train_df[train_df['번지'].isin(test_df['번지'])]
# train_df = train_df[train_df['시군구'].isin(test_df['시군구'])]

# for index, row in train_df.iterrows():
#     if pd.isnull(row['아파트명']):
#         corresponding_value = test_df[test_df['아파트명'] == row['아파트명']]['아파트명'].values
#         if len(corresponding_value) > 0:
#             train_df.at[index, '아파트명'] = corresponding_value[0]

train_df.drop(columns=['시군구', '번지', '아파트명', '도로명'], axis=1, inplace=True)
test_df.drop(columns=['시군구', '번지', '아파트명', '도로명'], axis=1, inplace=True)
display(train_df.shape, test_df.shape)
# Out:
# (1118822, 11)
# (9272, 10)

# %% [markdown]
# ## 분포확인

# %% [markdown]
# ### target

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_df['target'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(np.log(train_df['target']), bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of target')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
train_df['target'] = np.log(train_df['target'])

# %% [markdown]
# ### 전용면적

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_df['전용면적'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['전용면적']), bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['전용면적_minmax'] = scaler.fit_transform(np.log(train_df['전용면적']).values.reshape(-1, 1))
test_df['전용면적_minmax'] = scaler.transform(np.log(test_df['전용면적']).values.reshape(-1, 1))

print(train_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax'],
#       dtype='object')

# %%
plt.hist(train_df['전용면적_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 전용면적_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 계약년월

# %%
plt.hist(train_df['계약년월'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 계약년월')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['계약년월_minmax'] = scaler.fit_transform(train_df['계약년월'].values.reshape(-1, 1))
test_df['계약년월_minmax'] = scaler.transform(test_df['계약년월'].values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['계약년월_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 계약년월_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax'],
#       dtype='object')

# %% [markdown]
# ### 최근접_지하철역_거리

# %%
plt.hist(train_df['최근접_지하철역_거리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['최근접_지하철역_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['최근접_지하철역_거리_minmax'] = scaler.fit_transform(np.log(train_df['최근접_지하철역_거리']).values.reshape(-1, 1))
test_df['최근접_지하철역_거리_minmax'] = scaler.transform(np.log(test_df['최근접_지하철역_거리']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['최근접_지하철역_거리_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_지하철역_거리_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax'],
#       dtype='object')

# %% [markdown]
# ### 인근_지하쳘역_개수

# %%
plt.hist(train_df['인근_지하철역_개수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log1p(train_df['인근_지하철역_개수']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-5, -4, -3, -2, -1, -0.5, 0]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['인근_지하철역_개수'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
train_df['인근_지하철역_개수_minmax'] = scaler.fit_transform(np.log1p(train_df['인근_지하철역_개수']).values.reshape(-1, 1))
test_df['인근_지하철역_개수_minmax'] = scaler.transform(np.log1p(test_df['인근_지하철역_개수']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_지하철역_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax'],
#       dtype='object')

# %% [markdown]
# ### 최근접_버스정류장_거리

# %%
plt.hist(train_df['최근접_버스정류장_거리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.sqrt(train_df['최근접_버스정류장_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리_sqrt')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(np.log(train_df['최근접_버스정류장_거리']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 최근접_버스정류장_거리_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-5, -4, -3, -2, -1, -0.5, 0]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['최근접_버스정류장_거리'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
scaler = MinMaxScaler()
train_df['최근접_버스정류장_거리_minmax'] = scaler.fit_transform(np.log1p(train_df['최근접_버스정류장_거리']).values.reshape(-1, 1))
test_df['최근접_버스정류장_거리_minmax'] = scaler.transform(np.log1p(test_df['최근접_버스정류장_거리']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_지하철역_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_지하철역_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax'],
#       dtype='object')

# %% [markdown]
# ### 인근_버스정류장_개수

# %%
plt.hist(train_df['인근_버스정류장_개수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box-Cox 변환을 위한 람다 값들
lambdas = [-3, -2, -1, -0.5, 0, 1, 2]

# Box-Cox 변환된 데이터 분포
for i, lam in enumerate(lambdas):
    transformed_data = stats.boxcox(train_df['인근_버스정류장_개수'] + 1, lmbda=lam)
    plt.subplot(3, 3, i + 2)
    plt.hist(transformed_data, bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Box-Cox Transformed (λ={lam})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.hist(np.log1p(train_df['인근_버스정류장_개수']), edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수_log')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['인근_버스정류장_개수_minmax'] = scaler.fit_transform(np.log1p(train_df['인근_버스정류장_개수']).values.reshape(-1, 1))
test_df['인근_버스정류장_개수_minmax'] = scaler.transform(np.log1p(test_df['인근_버스정류장_개수']).values.reshape(-1, 1))

print(train_df.columns)
plt.hist(train_df['인근_버스정류장_개수_minmax'], bins=10, edgecolor='k', alpha=0.7)
plt.title('Distribution of 인근_버스정류장_개수_minmax')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %% [markdown]
# ### GDP

# %%
plt.hist(train_df['GDP'], edgecolor='k', alpha=0.7)
plt.title('Distribution of GDP')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 기준금리

# %%
plt.hist(train_df['기준금리'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 기준금리')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
train_df['기준금리'].value_counts()
# Out:
# 기준금리
# 1.50    222528
# 1.25    197841
# 2.00    129110
# 2.50    110503
# 0.50     92302
# 5.00     75066
# 1.75     63335
# 3.25     49756
# 2.75     47276
# 2.25     31690
# 4.50     26577
# 3.00     23047
# 3.50     17548
# 0.75     17018
# 4.75      5735
# 5.25      4223
# 1.00      2609
# 4.25      1496
# 4.00      1162
# Name: count, dtype: int64

# %% [markdown]
# ### 세대별_주차대수

# %%
plt.hist(train_df['세대별_주차대수'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 세대별_주차대수')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 건설사랭크

# %%
plt.hist(train_df['건설사랭크'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 건설사랭크')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler()
train_df['건설사랭크'] = scaler.fit_transform(np.log1p(train_df['건설사랭크']).values.reshape(-1, 1))
test_df['건설사랭크'] = scaler.transform(np.log1p(test_df['건설사랭크']).values.reshape(-1, 1))

print(train_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
plt.hist(train_df['건설사랭크'], edgecolor='k', alpha=0.7)
plt.title('Distribution of 건설사랭크')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
for column in train_df.columns:
    plt.figure(figsize=(10, 6))
    
    if pd.api.types.is_numeric_dtype(train_df[column]):
        # 연속형 변수일 경우 히스토그램
        plt.hist(train_df[column], bins=10, edgecolor='k', alpha=0.7)
        plt.title(f'{column}의 분포도')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        
    else:
        # 범주형 변수일 경우 막대 그래프
        train_df[column].value_counts().plot(kind='bar', edgecolor='k', alpha=0.7)
        plt.title(f'{column}의 분포도')
        plt.xlabel(column)
        plt.ylabel('Frequency')
    
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Training

# %%
display(train_df.columns)
display(test_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')
# Index(['전용면적', '계약년월', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리',
#        '인근_버스정류장_개수', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
display(train_df.shape, test_df.shape)
# Out:
# (1118822, 17)
# (9272, 16)

# %%
train_X = train_df.drop(['target', '최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리', '인근_버스정류장_개수'], axis=1)
train_y = train_df[['target']]

display(train_X.columns)
# Out:
# Index(['전용면적', '계약년월', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %%
test_df.drop(columns=['최근접_지하철역_거리', '인근_지하철역_개수', '최근접_버스정류장_거리', '인근_버스정류장_개수'], axis=1, inplace=True)
display(test_df.columns)
# Out:
# Index(['전용면적', '계약년월', 'GDP', '기준금리', '세대별_주차대수', '건설사랭크', '전용면적_minmax',
#        '계약년월_minmax', '최근접_지하철역_거리_minmax', '인근_지하철역_개수_minmax',
#        '최근접_버스정류장_거리_minmax', '인근_버스정류장_개수_minmax'],
#       dtype='object')

# %% [markdown]
# ### n개월씩 나눠서 학습

# %%
offset = 6
freq = f'{offset}MS'

train_df['계약년월'] = pd.to_datetime(train_df['계약년월'], format='%Y%m')

min_date = train_df['계약년월'].min()
max_date = train_df['계약년월'].max()
months_range = pd.date_range(start=min_date, end=max_date, freq=freq)

# 모델 파라미터 설정
params = {
    'n_estimators': 100000,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'metric_freq': 20,
    'device': 'gpu',
    'verbosity': 0
}

models = []
for start_date in months_range:
    end_date = start_date + pd.DateOffset(months=6)
    
    train_period = (train_df['계약년월'] >= start_date) & (train_df['계약년월'] < end_date)
    X_train = train_X[train_period]
    y_train = train_y[train_period]
    
    valid_period = (train_df['계약년월'] >= end_date) & (train_df['계약년월'] < end_date + pd.DateOffset(months=6))
    X_valid = train_X[valid_period]
    y_valid = train_y[valid_period]
    
    if len(X_train) == 0 or len(X_valid) == 0:
        continue
    
    print(f"Training period: {min_date.strftime('%Y-%m')} to {end_date.strftime('%Y-%m')}")
    print(f"Validation period: {end_date.strftime('%Y-%m')} to {(end_date + pd.DateOffset(months=6)).strftime('%Y-%m')}")

    model = lgb.LGBMRegressor(**params)
    
    model.fit(
        X_train, y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=60), lgb.log_evaluation(period=10, show_stdv=True)]
    )
    
    models.append(model)
    print(f"Training from {start_date} to {end_date} finished.")
# Out:
# Training period: 2007-01 to 2007-07
# Validation period: 2007-07 to 2008-01
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.394682	valid_1's rmse: 0.38735
# [20]	training's rmse: 0.339421	valid_1's rmse: 0.331346
# [30]	training's rmse: 0.318165	valid_1's rmse: 0.312366
# [40]	training's rmse: 0.305223	valid_1's rmse: 0.302787
# [50]	training's rmse: 0.294879	valid_1's rmse: 0.294414
# [60]	training's rmse: 0.285133	valid_1's rmse: 0.286975
# [70]	training's rmse: 0.278088	valid_1's rmse: 0.281783
# [80]	training's rmse: 0.272045	valid_1's rmse: 0.27763
# [90]	training's rmse: 0.267042	valid_1's rmse: 0.274049
# [100]	training's rmse: 0.261654	valid_1's rmse: 0.270138
# [110]	training's rmse: 0.256407	valid_1's rmse: 0.266349
# [120]	training's rmse: 0.252171	valid_1's rmse: 0.263618
# [130]	training's rmse: 0.248211	valid_1's rmse: 0.261259
# [140]	training's rmse: 0.24483	valid_1's rmse: 0.258786
# [150]	training's rmse: 0.241793	valid_1's rmse: 0.257441
# [160]	training's rmse: 0.238807	valid_1's rmse: 0.255359
# [170]	training's rmse: 0.23524	valid_1's rmse: 0.25379
# [180]	training's rmse: 0.232266	valid_1's rmse: 0.252311
# [190]	training's rmse: 0.22955	valid_1's rmse: 0.250952
# [200]	training's rmse: 0.227263	valid_1's rmse: 0.249762
# [210]	training's rmse: 0.224001	valid_1's rmse: 0.247745
# [220]	training's rmse: 0.221244	valid_1's rmse: 0.246336
# [230]	training's rmse: 0.218731	valid_1's rmse: 0.244724
# [240]	training's rmse: 0.215976	valid_1's rmse: 0.24346
# [250]	training's rmse: 0.213323	valid_1's rmse: 0.241864
# [260]	training's rmse: 0.210523	valid_1's rmse: 0.240329
# [270]	training's rmse: 0.208852	valid_1's rmse: 0.239784
# [280]	training's rmse: 0.206539	valid_1's rmse: 0.238237
# [290]	training's rmse: 0.204696	valid_1's rmse: 0.237108
# [300]	training's rmse: 0.203169	valid_1's rmse: 0.236314
# [310]	training's rmse: 0.201248	valid_1's rmse: 0.235062
# [320]	training's rmse: 0.199934	valid_1's rmse: 0.234292
# [330]	training's rmse: 0.198001	valid_1's rmse: 0.23303
# [340]	training's rmse: 0.196477	valid_1's rmse: 0.232257
# [350]	training's rmse: 0.195112	valid_1's rmse: 0.231362
# [360]	training's rmse: 0.193577	valid_1's rmse: 0.230444
# [370]	training's rmse: 0.191689	valid_1's rmse: 0.229569
# [380]	training's rmse: 0.189688	valid_1's rmse: 0.228459
# [390]	training's rmse: 0.188023	valid_1's rmse: 0.227688
# [400]	training's rmse: 0.186456	valid_1's rmse: 0.226865
# [410]	training's rmse: 0.184886	valid_1's rmse: 0.226209
# [420]	training's rmse: 0.183205	valid_1's rmse: 0.225449
# [430]	training's rmse: 0.181987	valid_1's rmse: 0.224789
# [440]	training's rmse: 0.18074	valid_1's rmse: 0.224136
# [450]	training's rmse: 0.179612	valid_1's rmse: 0.223699
# [460]	training's rmse: 0.178359	valid_1's rmse: 0.223194
# [470]	training's rmse: 0.176968	valid_1's rmse: 0.222875
# [480]	training's rmse: 0.17586	valid_1's rmse: 0.222365
# [490]	training's rmse: 0.174659	valid_1's rmse: 0.221925
# [500]	training's rmse: 0.173709	valid_1's rmse: 0.221517
# [510]	training's rmse: 0.17272	valid_1's rmse: 0.221033
# [520]	training's rmse: 0.171873	valid_1's rmse: 0.220595
# [530]	training's rmse: 0.170495	valid_1's rmse: 0.22
# [540]	training's rmse: 0.169073	valid_1's rmse: 0.219368
# [550]	training's rmse: 0.167922	valid_1's rmse: 0.219005
# [560]	training's rmse: 0.16697	valid_1's rmse: 0.218615
# [570]	training's rmse: 0.166	valid_1's rmse: 0.218095
# [580]	training's rmse: 0.164612	valid_1's rmse: 0.217537
# [590]	training's rmse: 0.163699	valid_1's rmse: 0.216949
# [600]	training's rmse: 0.162667	valid_1's rmse: 0.216409
# [610]	training's rmse: 0.161445	valid_1's rmse: 0.215928
# [620]	training's rmse: 0.160308	valid_1's rmse: 0.215403
# [630]	training's rmse: 0.159166	valid_1's rmse: 0.214963
# [640]	training's rmse: 0.158349	valid_1's rmse: 0.214787
# [650]	training's rmse: 0.15739	valid_1's rmse: 0.214609
# [660]	training's rmse: 0.156648	valid_1's rmse: 0.214497
# [670]	training's rmse: 0.155653	valid_1's rmse: 0.214203
# [680]	training's rmse: 0.154619	valid_1's rmse: 0.214124
# [690]	training's rmse: 0.153615	valid_1's rmse: 0.214076
# [700]	training's rmse: 0.152938	valid_1's rmse: 0.213879
# [710]	training's rmse: 0.152346	valid_1's rmse: 0.213822
# [720]	training's rmse: 0.151535	valid_1's rmse: 0.213497
# [730]	training's rmse: 0.150665	valid_1's rmse: 0.213091
# [740]	training's rmse: 0.14999	valid_1's rmse: 0.212916
# [750]	training's rmse: 0.149212	valid_1's rmse: 0.212692
# [760]	training's rmse: 0.148596	valid_1's rmse: 0.212509
# [770]	training's rmse: 0.147903	valid_1's rmse: 0.212263
# [780]	training's rmse: 0.147069	valid_1's rmse: 0.212073
# [790]	training's rmse: 0.146258	valid_1's rmse: 0.211842
# [800]	training's rmse: 0.145526	valid_1's rmse: 0.211727
# [810]	training's rmse: 0.144892	valid_1's rmse: 0.211649
# [820]	training's rmse: 0.144188	valid_1's rmse: 0.211348
# [830]	training's rmse: 0.143392	valid_1's rmse: 0.211059
# [840]	training's rmse: 0.142946	valid_1's rmse: 0.210993
# [850]	training's rmse: 0.142138	valid_1's rmse: 0.210584
# [860]	training's rmse: 0.141338	valid_1's rmse: 0.210273
# [870]	training's rmse: 0.140584	valid_1's rmse: 0.210081
# [880]	training's rmse: 0.139805	valid_1's rmse: 0.209747
# [890]	training's rmse: 0.139286	valid_1's rmse: 0.20952
# [900]	training's rmse: 0.138642	valid_1's rmse: 0.209397
# [910]	training's rmse: 0.137924	valid_1's rmse: 0.209112
# [920]	training's rmse: 0.137118	valid_1's rmse: 0.208668
# [930]	training's rmse: 0.136549	valid_1's rmse: 0.208441
# [940]	training's rmse: 0.136129	valid_1's rmse: 0.208349
# [950]	training's rmse: 0.135521	valid_1's rmse: 0.208127
# [960]	training's rmse: 0.134707	valid_1's rmse: 0.207822
# [970]	training's rmse: 0.134197	valid_1's rmse: 0.207697
# [980]	training's rmse: 0.133613	valid_1's rmse: 0.207427
# [990]	training's rmse: 0.132913	valid_1's rmse: 0.207223
# [1000]	training's rmse: 0.132244	valid_1's rmse: 0.206991
# [1010]	training's rmse: 0.131613	valid_1's rmse: 0.206784
# [1020]	training's rmse: 0.130972	valid_1's rmse: 0.206588
# [1030]	training's rmse: 0.13052	valid_1's rmse: 0.206411
# [1040]	training's rmse: 0.129897	valid_1's rmse: 0.206159
# [1050]	training's rmse: 0.129492	valid_1's rmse: 0.20606
# [1060]	training's rmse: 0.128989	valid_1's rmse: 0.205892
# [1070]	training's rmse: 0.128587	valid_1's rmse: 0.205862
# [1080]	training's rmse: 0.128025	valid_1's rmse: 0.20581
# [1090]	training's rmse: 0.127576	valid_1's rmse: 0.205661
# [1100]	training's rmse: 0.127011	valid_1's rmse: 0.205585
# [1110]	training's rmse: 0.12655	valid_1's rmse: 0.205409
# [1120]	training's rmse: 0.126044	valid_1's rmse: 0.20532
# [1130]	training's rmse: 0.125649	valid_1's rmse: 0.205233
# [1140]	training's rmse: 0.125058	valid_1's rmse: 0.205089
# [1150]	training's rmse: 0.124611	valid_1's rmse: 0.20494
# [1160]	training's rmse: 0.124192	valid_1's rmse: 0.204807
# [1170]	training's rmse: 0.123795	valid_1's rmse: 0.204761
# [1180]	training's rmse: 0.123346	valid_1's rmse: 0.204632
# [1190]	training's rmse: 0.122959	valid_1's rmse: 0.204463
# [1200]	training's rmse: 0.122549	valid_1's rmse: 0.204308
# [1210]	training's rmse: 0.122216	valid_1's rmse: 0.204188
# [1220]	training's rmse: 0.121874	valid_1's rmse: 0.204166
# [1230]	training's rmse: 0.1214	valid_1's rmse: 0.204047
# [1240]	training's rmse: 0.120899	valid_1's rmse: 0.203946
# [1250]	training's rmse: 0.12047	valid_1's rmse: 0.203778
# [1260]	training's rmse: 0.120113	valid_1's rmse: 0.20374
# [1270]	training's rmse: 0.11972	valid_1's rmse: 0.203634
# [1280]	training's rmse: 0.119288	valid_1's rmse: 0.203697
# [1290]	training's rmse: 0.118942	valid_1's rmse: 0.20354
# [1300]	training's rmse: 0.118599	valid_1's rmse: 0.203422
# [1310]	training's rmse: 0.118213	valid_1's rmse: 0.203279
# [1320]	training's rmse: 0.117852	valid_1's rmse: 0.203243
# [1330]	training's rmse: 0.117505	valid_1's rmse: 0.203204
# [1340]	training's rmse: 0.117012	valid_1's rmse: 0.203058
# [1350]	training's rmse: 0.116737	valid_1's rmse: 0.202974
# [1360]	training's rmse: 0.116154	valid_1's rmse: 0.2028
# [1370]	training's rmse: 0.115667	valid_1's rmse: 0.202704
# [1380]	training's rmse: 0.115324	valid_1's rmse: 0.202603
# [1390]	training's rmse: 0.114993	valid_1's rmse: 0.202469
# [1400]	training's rmse: 0.114471	valid_1's rmse: 0.202292
# [1410]	training's rmse: 0.114258	valid_1's rmse: 0.202303
# [1420]	training's rmse: 0.113971	valid_1's rmse: 0.202216
# [1430]	training's rmse: 0.113515	valid_1's rmse: 0.201989
# [1440]	training's rmse: 0.113117	valid_1's rmse: 0.201922
# [1450]	training's rmse: 0.112765	valid_1's rmse: 0.201879
# [1460]	training's rmse: 0.112429	valid_1's rmse: 0.201827
# [1470]	training's rmse: 0.112056	valid_1's rmse: 0.201735
# [1480]	training's rmse: 0.111689	valid_1's rmse: 0.201639
# [1490]	training's rmse: 0.111379	valid_1's rmse: 0.201547
# [1500]	training's rmse: 0.111051	valid_1's rmse: 0.201566
# [1510]	training's rmse: 0.110697	valid_1's rmse: 0.201485
# [1520]	training's rmse: 0.110295	valid_1's rmse: 0.2014
# [1530]	training's rmse: 0.109951	valid_1's rmse: 0.201251
# [1540]	training's rmse: 0.109586	valid_1's rmse: 0.201218
# [1550]	training's rmse: 0.109209	valid_1's rmse: 0.201159
# [1560]	training's rmse: 0.108907	valid_1's rmse: 0.2012
# [1570]	training's rmse: 0.108632	valid_1's rmse: 0.201184
# [1580]	training's rmse: 0.108371	valid_1's rmse: 0.201134
# [1590]	training's rmse: 0.108018	valid_1's rmse: 0.201086
# [1600]	training's rmse: 0.107696	valid_1's rmse: 0.201054
# [1610]	training's rmse: 0.107434	valid_1's rmse: 0.201008
# [1620]	training's rmse: 0.107193	valid_1's rmse: 0.200988
# [1630]	training's rmse: 0.106927	valid_1's rmse: 0.200993
# [1640]	training's rmse: 0.10662	valid_1's rmse: 0.200912
# [1650]	training's rmse: 0.106282	valid_1's rmse: 0.200778
# [1660]	training's rmse: 0.105971	valid_1's rmse: 0.200709
# [1670]	training's rmse: 0.10571	valid_1's rmse: 0.200665
# [1680]	training's rmse: 0.105454	valid_1's rmse: 0.200624
# [1690]	training's rmse: 0.105187	valid_1's rmse: 0.200567
# [1700]	training's rmse: 0.104825	valid_1's rmse: 0.200501
# [1710]	training's rmse: 0.104593	valid_1's rmse: 0.2005
# [1720]	training's rmse: 0.104319	valid_1's rmse: 0.200486
# [1730]	training's rmse: 0.104097	valid_1's rmse: 0.200436
# [1740]	training's rmse: 0.103942	valid_1's rmse: 0.200424
# [1750]	training's rmse: 0.103642	valid_1's rmse: 0.200353
# [1760]	training's rmse: 0.103282	valid_1's rmse: 0.200359
# [1770]	training's rmse: 0.103058	valid_1's rmse: 0.200339
# [1780]	training's rmse: 0.102886	valid_1's rmse: 0.200326
# [1790]	training's rmse: 0.102545	valid_1's rmse: 0.200312
# [1800]	training's rmse: 0.102282	valid_1's rmse: 0.20033
# [1810]	training's rmse: 0.102101	valid_1's rmse: 0.200321
# [1820]	training's rmse: 0.101819	valid_1's rmse: 0.200223
# [1830]	training's rmse: 0.101518	valid_1's rmse: 0.200162
# [1840]	training's rmse: 0.101248	valid_1's rmse: 0.200131
# [1850]	training's rmse: 0.101027	valid_1's rmse: 0.200099
# [1860]	training's rmse: 0.100817	valid_1's rmse: 0.200022
# [1870]	training's rmse: 0.100616	valid_1's rmse: 0.2
# [1880]	training's rmse: 0.10039	valid_1's rmse: 0.199959
# [1890]	training's rmse: 0.100137	valid_1's rmse: 0.199899
# [1900]	training's rmse: 0.0999542	valid_1's rmse: 0.199871
# [1910]	training's rmse: 0.0997169	valid_1's rmse: 0.199894
# [1920]	training's rmse: 0.0994229	valid_1's rmse: 0.199846
# [1930]	training's rmse: 0.099252	valid_1's rmse: 0.199869
# [1940]	training's rmse: 0.0989686	valid_1's rmse: 0.199781
# [1950]	training's rmse: 0.0987646	valid_1's rmse: 0.199726
# [1960]	training's rmse: 0.0985811	valid_1's rmse: 0.199715
# [1970]	training's rmse: 0.0983611	valid_1's rmse: 0.199707
# [1980]	training's rmse: 0.0981271	valid_1's rmse: 0.199644
# [1990]	training's rmse: 0.0978705	valid_1's rmse: 0.199604
# [2000]	training's rmse: 0.0976411	valid_1's rmse: 0.199568
# [2010]	training's rmse: 0.0974456	valid_1's rmse: 0.199534
# [2020]	training's rmse: 0.0971922	valid_1's rmse: 0.199523
# [2030]	training's rmse: 0.0969742	valid_1's rmse: 0.199455
# [2040]	training's rmse: 0.0967493	valid_1's rmse: 0.199424
# [2050]	training's rmse: 0.0965813	valid_1's rmse: 0.199418
# [2060]	training's rmse: 0.0963042	valid_1's rmse: 0.199375
# [2070]	training's rmse: 0.0960503	valid_1's rmse: 0.199343
# [2080]	training's rmse: 0.0957354	valid_1's rmse: 0.199288
# [2090]	training's rmse: 0.0954773	valid_1's rmse: 0.199233
# [2100]	training's rmse: 0.0952343	valid_1's rmse: 0.199267
# [2110]	training's rmse: 0.0949781	valid_1's rmse: 0.199227
# [2120]	training's rmse: 0.0948456	valid_1's rmse: 0.199173
# [2130]	training's rmse: 0.0946805	valid_1's rmse: 0.199128
# [2140]	training's rmse: 0.0944979	valid_1's rmse: 0.199118
# [2150]	training's rmse: 0.0943148	valid_1's rmse: 0.199108
# [2160]	training's rmse: 0.094013	valid_1's rmse: 0.199073
# [2170]	training's rmse: 0.093815	valid_1's rmse: 0.199075
# [2180]	training's rmse: 0.0936238	valid_1's rmse: 0.199043
# [2190]	training's rmse: 0.0934241	valid_1's rmse: 0.199001
# [2200]	training's rmse: 0.0932201	valid_1's rmse: 0.198964
# [2210]	training's rmse: 0.0930602	valid_1's rmse: 0.198977
# [2220]	training's rmse: 0.0928822	valid_1's rmse: 0.198939
# [2230]	training's rmse: 0.0927178	valid_1's rmse: 0.198953
# [2240]	training's rmse: 0.0924943	valid_1's rmse: 0.198862
# [2250]	training's rmse: 0.0923783	valid_1's rmse: 0.198848
# [2260]	training's rmse: 0.0921217	valid_1's rmse: 0.198769
# [2270]	training's rmse: 0.0918981	valid_1's rmse: 0.1987
# [2280]	training's rmse: 0.0916808	valid_1's rmse: 0.198677
# [2290]	training's rmse: 0.0915226	valid_1's rmse: 0.198652
# [2300]	training's rmse: 0.0913782	valid_1's rmse: 0.198672
# [2310]	training's rmse: 0.0912089	valid_1's rmse: 0.198624
# [2320]	training's rmse: 0.0910516	valid_1's rmse: 0.198649
# [2330]	training's rmse: 0.0908985	valid_1's rmse: 0.198616
# [2340]	training's rmse: 0.0907259	valid_1's rmse: 0.198582
# [2350]	training's rmse: 0.0905167	valid_1's rmse: 0.198582
# [2360]	training's rmse: 0.0903318	valid_1's rmse: 0.19858
# [2370]	training's rmse: 0.0901889	valid_1's rmse: 0.198626
# [2380]	training's rmse: 0.0900073	valid_1's rmse: 0.198616
# [2390]	training's rmse: 0.0898178	valid_1's rmse: 0.198577
# [2400]	training's rmse: 0.089657	valid_1's rmse: 0.198541
# [2410]	training's rmse: 0.089533	valid_1's rmse: 0.198546
# [2420]	training's rmse: 0.0893234	valid_1's rmse: 0.198508
# [2430]	training's rmse: 0.0891469	valid_1's rmse: 0.19858
# [2440]	training's rmse: 0.0890165	valid_1's rmse: 0.198575
# [2450]	training's rmse: 0.0888468	valid_1's rmse: 0.198617
# [2460]	training's rmse: 0.0886688	valid_1's rmse: 0.198601
# [2470]	training's rmse: 0.0884955	valid_1's rmse: 0.19866
# [2480]	training's rmse: 0.0883304	valid_1's rmse: 0.198688
# Early stopping, best iteration is:
# [2421]	training's rmse: 0.089318	valid_1's rmse: 0.198507
# Training from 2007-01-01 00:00:00 to 2007-07-01 00:00:00 finished.
# Training period: 2007-01 to 2008-01
# Validation period: 2008-01 to 2008-07
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.36977	valid_1's rmse: 0.351589
# [20]	training's rmse: 0.31716	valid_1's rmse: 0.316924
# [30]	training's rmse: 0.299248	valid_1's rmse: 0.304207
# [40]	training's rmse: 0.287834	valid_1's rmse: 0.296115
# [50]	training's rmse: 0.27846	valid_1's rmse: 0.289927
# [60]	training's rmse: 0.270442	valid_1's rmse: 0.283834
# [70]	training's rmse: 0.264092	valid_1's rmse: 0.278468
# [80]	training's rmse: 0.258844	valid_1's rmse: 0.274786
# [90]	training's rmse: 0.253621	valid_1's rmse: 0.271272
# [100]	training's rmse: 0.249258	valid_1's rmse: 0.267976
# [110]	training's rmse: 0.244628	valid_1's rmse: 0.264513
# [120]	training's rmse: 0.240584	valid_1's rmse: 0.261601
# [130]	training's rmse: 0.23621	valid_1's rmse: 0.258626
# [140]	training's rmse: 0.232728	valid_1's rmse: 0.25624
# [150]	training's rmse: 0.228728	valid_1's rmse: 0.253476
# [160]	training's rmse: 0.225348	valid_1's rmse: 0.251211
# [170]	training's rmse: 0.22234	valid_1's rmse: 0.249317
# [180]	training's rmse: 0.21929	valid_1's rmse: 0.247284
# [190]	training's rmse: 0.216638	valid_1's rmse: 0.245631
# [200]	training's rmse: 0.213819	valid_1's rmse: 0.243877
# [210]	training's rmse: 0.211013	valid_1's rmse: 0.242191
# [220]	training's rmse: 0.208355	valid_1's rmse: 0.240483
# [230]	training's rmse: 0.205666	valid_1's rmse: 0.238766
# [240]	training's rmse: 0.203201	valid_1's rmse: 0.237307
# [250]	training's rmse: 0.201078	valid_1's rmse: 0.235959
# [260]	training's rmse: 0.199106	valid_1's rmse: 0.234733
# [270]	training's rmse: 0.196913	valid_1's rmse: 0.233462
# [280]	training's rmse: 0.194505	valid_1's rmse: 0.231852
# [290]	training's rmse: 0.192772	valid_1's rmse: 0.230755
# [300]	training's rmse: 0.190507	valid_1's rmse: 0.229332
# [310]	training's rmse: 0.188622	valid_1's rmse: 0.228357
# [320]	training's rmse: 0.186537	valid_1's rmse: 0.22727
# [330]	training's rmse: 0.185025	valid_1's rmse: 0.226548
# [340]	training's rmse: 0.182975	valid_1's rmse: 0.22558
# [350]	training's rmse: 0.181266	valid_1's rmse: 0.224609
# [360]	training's rmse: 0.179942	valid_1's rmse: 0.223931
# [370]	training's rmse: 0.178609	valid_1's rmse: 0.223242
# [380]	training's rmse: 0.177352	valid_1's rmse: 0.222525
# [390]	training's rmse: 0.175872	valid_1's rmse: 0.221797
# [400]	training's rmse: 0.174384	valid_1's rmse: 0.221015
# [410]	training's rmse: 0.173278	valid_1's rmse: 0.220529
# [420]	training's rmse: 0.171654	valid_1's rmse: 0.219708
# [430]	training's rmse: 0.170517	valid_1's rmse: 0.218975
# [440]	training's rmse: 0.169197	valid_1's rmse: 0.218374
# [450]	training's rmse: 0.168162	valid_1's rmse: 0.217827
# [460]	training's rmse: 0.167134	valid_1's rmse: 0.217321
# [470]	training's rmse: 0.165982	valid_1's rmse: 0.216869
# [480]	training's rmse: 0.164458	valid_1's rmse: 0.21621
# [490]	training's rmse: 0.163283	valid_1's rmse: 0.215687
# [500]	training's rmse: 0.162003	valid_1's rmse: 0.215129
# [510]	training's rmse: 0.160909	valid_1's rmse: 0.21453
# [520]	training's rmse: 0.1599	valid_1's rmse: 0.214106
# [530]	training's rmse: 0.158841	valid_1's rmse: 0.213485
# [540]	training's rmse: 0.157925	valid_1's rmse: 0.212997
# [550]	training's rmse: 0.157079	valid_1's rmse: 0.212577
# [560]	training's rmse: 0.156138	valid_1's rmse: 0.212161
# [570]	training's rmse: 0.155173	valid_1's rmse: 0.211807
# [580]	training's rmse: 0.154185	valid_1's rmse: 0.211293
# [590]	training's rmse: 0.153091	valid_1's rmse: 0.210768
# [600]	training's rmse: 0.152233	valid_1's rmse: 0.210383
# [610]	training's rmse: 0.151168	valid_1's rmse: 0.210036
# [620]	training's rmse: 0.15028	valid_1's rmse: 0.209597
# [630]	training's rmse: 0.149583	valid_1's rmse: 0.209239
# [640]	training's rmse: 0.148844	valid_1's rmse: 0.208935
# [650]	training's rmse: 0.147895	valid_1's rmse: 0.208498
# [660]	training's rmse: 0.147082	valid_1's rmse: 0.208144
# [670]	training's rmse: 0.146607	valid_1's rmse: 0.207921
# [680]	training's rmse: 0.145763	valid_1's rmse: 0.207656
# [690]	training's rmse: 0.145186	valid_1's rmse: 0.207416
# [700]	training's rmse: 0.144274	valid_1's rmse: 0.207088
# [710]	training's rmse: 0.143566	valid_1's rmse: 0.206818
# [720]	training's rmse: 0.142601	valid_1's rmse: 0.206412
# [730]	training's rmse: 0.141879	valid_1's rmse: 0.206198
# [740]	training's rmse: 0.141245	valid_1's rmse: 0.20597
# [750]	training's rmse: 0.140334	valid_1's rmse: 0.205732
# [760]	training's rmse: 0.139514	valid_1's rmse: 0.205418
# [770]	training's rmse: 0.138857	valid_1's rmse: 0.205274
# [780]	training's rmse: 0.138264	valid_1's rmse: 0.205067
# [790]	training's rmse: 0.137532	valid_1's rmse: 0.204759
# [800]	training's rmse: 0.136832	valid_1's rmse: 0.204547
# [810]	training's rmse: 0.136198	valid_1's rmse: 0.2043
# [820]	training's rmse: 0.135478	valid_1's rmse: 0.204062
# [830]	training's rmse: 0.134795	valid_1's rmse: 0.203846
# [840]	training's rmse: 0.134198	valid_1's rmse: 0.203683
# [850]	training's rmse: 0.133578	valid_1's rmse: 0.203375
# [860]	training's rmse: 0.132957	valid_1's rmse: 0.203169
# [870]	training's rmse: 0.132292	valid_1's rmse: 0.202916
# [880]	training's rmse: 0.13177	valid_1's rmse: 0.202774
# [890]	training's rmse: 0.131212	valid_1's rmse: 0.202542
# [900]	training's rmse: 0.13077	valid_1's rmse: 0.202312
# [910]	training's rmse: 0.130228	valid_1's rmse: 0.202189
# [920]	training's rmse: 0.129675	valid_1's rmse: 0.201996
# [930]	training's rmse: 0.129035	valid_1's rmse: 0.201698
# [940]	training's rmse: 0.128482	valid_1's rmse: 0.201444
# [950]	training's rmse: 0.127961	valid_1's rmse: 0.201242
# [960]	training's rmse: 0.127267	valid_1's rmse: 0.201006
# [970]	training's rmse: 0.126747	valid_1's rmse: 0.200732
# [980]	training's rmse: 0.12618	valid_1's rmse: 0.200546
# [990]	training's rmse: 0.125477	valid_1's rmse: 0.200203
# [1000]	training's rmse: 0.124919	valid_1's rmse: 0.199993
# [1010]	training's rmse: 0.124379	valid_1's rmse: 0.199739
# [1020]	training's rmse: 0.123809	valid_1's rmse: 0.199513
# [1030]	training's rmse: 0.123124	valid_1's rmse: 0.199317
# [1040]	training's rmse: 0.122739	valid_1's rmse: 0.199137
# [1050]	training's rmse: 0.122443	valid_1's rmse: 0.199029
# [1060]	training's rmse: 0.121967	valid_1's rmse: 0.198896
# [1070]	training's rmse: 0.121557	valid_1's rmse: 0.198699
# [1080]	training's rmse: 0.121161	valid_1's rmse: 0.198559
# [1090]	training's rmse: 0.120725	valid_1's rmse: 0.198455
# [1100]	training's rmse: 0.120262	valid_1's rmse: 0.198293
# [1110]	training's rmse: 0.119886	valid_1's rmse: 0.19816
# [1120]	training's rmse: 0.119622	valid_1's rmse: 0.198062
# [1130]	training's rmse: 0.119152	valid_1's rmse: 0.197904
# [1140]	training's rmse: 0.118863	valid_1's rmse: 0.197811
# [1150]	training's rmse: 0.118388	valid_1's rmse: 0.19774
# [1160]	training's rmse: 0.117993	valid_1's rmse: 0.197603
# [1170]	training's rmse: 0.117659	valid_1's rmse: 0.197513
# [1180]	training's rmse: 0.117299	valid_1's rmse: 0.197387
# [1190]	training's rmse: 0.116993	valid_1's rmse: 0.197311
# [1200]	training's rmse: 0.116656	valid_1's rmse: 0.197221
# [1210]	training's rmse: 0.116385	valid_1's rmse: 0.197139
# [1220]	training's rmse: 0.116077	valid_1's rmse: 0.197052
# [1230]	training's rmse: 0.115767	valid_1's rmse: 0.196977
# [1240]	training's rmse: 0.115391	valid_1's rmse: 0.196856
# [1250]	training's rmse: 0.114888	valid_1's rmse: 0.196643
# [1260]	training's rmse: 0.114519	valid_1's rmse: 0.196513
# [1270]	training's rmse: 0.11422	valid_1's rmse: 0.196414
# [1280]	training's rmse: 0.113792	valid_1's rmse: 0.196276
# [1290]	training's rmse: 0.113337	valid_1's rmse: 0.196132
# [1300]	training's rmse: 0.112907	valid_1's rmse: 0.195995
# [1310]	training's rmse: 0.112477	valid_1's rmse: 0.195892
# [1320]	training's rmse: 0.112169	valid_1's rmse: 0.19582
# [1330]	training's rmse: 0.111693	valid_1's rmse: 0.195722
# [1340]	training's rmse: 0.111314	valid_1's rmse: 0.195669
# [1350]	training's rmse: 0.110939	valid_1's rmse: 0.19557
# [1360]	training's rmse: 0.110721	valid_1's rmse: 0.195506
# [1370]	training's rmse: 0.110312	valid_1's rmse: 0.195434
# [1380]	training's rmse: 0.109946	valid_1's rmse: 0.195304
# [1390]	training's rmse: 0.109651	valid_1's rmse: 0.195234
# [1400]	training's rmse: 0.109278	valid_1's rmse: 0.195133
# [1410]	training's rmse: 0.108956	valid_1's rmse: 0.195038
# [1420]	training's rmse: 0.108491	valid_1's rmse: 0.194914
# [1430]	training's rmse: 0.108156	valid_1's rmse: 0.194833
# [1440]	training's rmse: 0.107742	valid_1's rmse: 0.194704
# [1450]	training's rmse: 0.10745	valid_1's rmse: 0.194613
# [1460]	training's rmse: 0.107192	valid_1's rmse: 0.194531
# [1470]	training's rmse: 0.106878	valid_1's rmse: 0.194485
# [1480]	training's rmse: 0.106571	valid_1's rmse: 0.194399
# [1490]	training's rmse: 0.10629	valid_1's rmse: 0.194357
# [1500]	training's rmse: 0.105955	valid_1's rmse: 0.194307
# [1510]	training's rmse: 0.105698	valid_1's rmse: 0.1943
# [1520]	training's rmse: 0.105343	valid_1's rmse: 0.194189
# [1530]	training's rmse: 0.105132	valid_1's rmse: 0.194115
# [1540]	training's rmse: 0.104872	valid_1's rmse: 0.19404
# [1550]	training's rmse: 0.104574	valid_1's rmse: 0.193899
# [1560]	training's rmse: 0.104316	valid_1's rmse: 0.193862
# [1570]	training's rmse: 0.104022	valid_1's rmse: 0.193783
# [1580]	training's rmse: 0.103723	valid_1's rmse: 0.193725
# [1590]	training's rmse: 0.103381	valid_1's rmse: 0.193678
# [1600]	training's rmse: 0.103105	valid_1's rmse: 0.193636
# [1610]	training's rmse: 0.102696	valid_1's rmse: 0.19354
# [1620]	training's rmse: 0.102384	valid_1's rmse: 0.193468
# [1630]	training's rmse: 0.102154	valid_1's rmse: 0.193428
# [1640]	training's rmse: 0.101906	valid_1's rmse: 0.193346
# [1650]	training's rmse: 0.101613	valid_1's rmse: 0.193257
# [1660]	training's rmse: 0.101451	valid_1's rmse: 0.193246
# [1670]	training's rmse: 0.101195	valid_1's rmse: 0.193196
# [1680]	training's rmse: 0.100998	valid_1's rmse: 0.193141
# [1690]	training's rmse: 0.100722	valid_1's rmse: 0.193082
# [1700]	training's rmse: 0.100493	valid_1's rmse: 0.193063
# [1710]	training's rmse: 0.100324	valid_1's rmse: 0.193013
# [1720]	training's rmse: 0.100119	valid_1's rmse: 0.192953
# [1730]	training's rmse: 0.0998739	valid_1's rmse: 0.192845
# [1740]	training's rmse: 0.0996749	valid_1's rmse: 0.192809
# [1750]	training's rmse: 0.0994513	valid_1's rmse: 0.192748
# [1760]	training's rmse: 0.0992318	valid_1's rmse: 0.192711
# [1770]	training's rmse: 0.0990745	valid_1's rmse: 0.192684
# [1780]	training's rmse: 0.0988617	valid_1's rmse: 0.192644
# [1790]	training's rmse: 0.0986726	valid_1's rmse: 0.192591
# [1800]	training's rmse: 0.0984922	valid_1's rmse: 0.192519
# [1810]	training's rmse: 0.0983324	valid_1's rmse: 0.192479
# [1820]	training's rmse: 0.0981299	valid_1's rmse: 0.192432
# [1830]	training's rmse: 0.097976	valid_1's rmse: 0.192381
# [1840]	training's rmse: 0.0977361	valid_1's rmse: 0.192338
# [1850]	training's rmse: 0.0975212	valid_1's rmse: 0.192309
# [1860]	training's rmse: 0.0973403	valid_1's rmse: 0.192265
# [1870]	training's rmse: 0.0970857	valid_1's rmse: 0.192191
# [1880]	training's rmse: 0.0968577	valid_1's rmse: 0.192146
# [1890]	training's rmse: 0.0966926	valid_1's rmse: 0.192178
# [1900]	training's rmse: 0.0964865	valid_1's rmse: 0.192154
# [1910]	training's rmse: 0.096236	valid_1's rmse: 0.192122
# [1920]	training's rmse: 0.0960083	valid_1's rmse: 0.192135
# [1930]	training's rmse: 0.0958407	valid_1's rmse: 0.192092
# [1940]	training's rmse: 0.0956225	valid_1's rmse: 0.192068
# [1950]	training's rmse: 0.0954536	valid_1's rmse: 0.192055
# [1960]	training's rmse: 0.0953211	valid_1's rmse: 0.192023
# [1970]	training's rmse: 0.0951615	valid_1's rmse: 0.19195
# [1980]	training's rmse: 0.0949442	valid_1's rmse: 0.191894
# [1990]	training's rmse: 0.0947504	valid_1's rmse: 0.191878
# [2000]	training's rmse: 0.0945432	valid_1's rmse: 0.191884
# [2010]	training's rmse: 0.0943807	valid_1's rmse: 0.191861
# [2020]	training's rmse: 0.0942703	valid_1's rmse: 0.191849
# [2030]	training's rmse: 0.0941179	valid_1's rmse: 0.191786
# [2040]	training's rmse: 0.0940018	valid_1's rmse: 0.191766
# [2050]	training's rmse: 0.0937346	valid_1's rmse: 0.191704
# [2060]	training's rmse: 0.093583	valid_1's rmse: 0.191677
# [2070]	training's rmse: 0.0933692	valid_1's rmse: 0.191667
# [2080]	training's rmse: 0.0932556	valid_1's rmse: 0.191663
# [2090]	training's rmse: 0.0930563	valid_1's rmse: 0.191676
# [2100]	training's rmse: 0.0928591	valid_1's rmse: 0.191645
# [2110]	training's rmse: 0.0926915	valid_1's rmse: 0.19167
# [2120]	training's rmse: 0.0924732	valid_1's rmse: 0.191629
# [2130]	training's rmse: 0.0923316	valid_1's rmse: 0.191599
# [2140]	training's rmse: 0.0921907	valid_1's rmse: 0.191565
# [2150]	training's rmse: 0.0920158	valid_1's rmse: 0.191579
# [2160]	training's rmse: 0.091862	valid_1's rmse: 0.191549
# [2170]	training's rmse: 0.0916764	valid_1's rmse: 0.191541
# [2180]	training's rmse: 0.0915259	valid_1's rmse: 0.191566
# [2190]	training's rmse: 0.0914034	valid_1's rmse: 0.19153
# [2200]	training's rmse: 0.0912408	valid_1's rmse: 0.191507
# [2210]	training's rmse: 0.0909846	valid_1's rmse: 0.191477
# [2220]	training's rmse: 0.0908555	valid_1's rmse: 0.191444
# [2230]	training's rmse: 0.0906854	valid_1's rmse: 0.191396
# [2240]	training's rmse: 0.0905247	valid_1's rmse: 0.191376
# [2250]	training's rmse: 0.0903674	valid_1's rmse: 0.191344
# [2260]	training's rmse: 0.0901693	valid_1's rmse: 0.191392
# [2270]	training's rmse: 0.0899475	valid_1's rmse: 0.19137
# [2280]	training's rmse: 0.089815	valid_1's rmse: 0.191359
# [2290]	training's rmse: 0.0896457	valid_1's rmse: 0.191329
# [2300]	training's rmse: 0.0895009	valid_1's rmse: 0.191335
# [2310]	training's rmse: 0.0893566	valid_1's rmse: 0.191327
# [2320]	training's rmse: 0.0892151	valid_1's rmse: 0.191298
# [2330]	training's rmse: 0.0890516	valid_1's rmse: 0.191243
# [2340]	training's rmse: 0.0888963	valid_1's rmse: 0.191236
# [2350]	training's rmse: 0.0887527	valid_1's rmse: 0.191245
# [2360]	training's rmse: 0.0885862	valid_1's rmse: 0.191206
# [2370]	training's rmse: 0.0884199	valid_1's rmse: 0.191167
# [2380]	training's rmse: 0.0882553	valid_1's rmse: 0.191175
# [2390]	training's rmse: 0.0881087	valid_1's rmse: 0.191191
# [2400]	training's rmse: 0.0879781	valid_1's rmse: 0.191172
# [2410]	training's rmse: 0.0878258	valid_1's rmse: 0.19113
# [2420]	training's rmse: 0.0876717	valid_1's rmse: 0.191104
# [2430]	training's rmse: 0.0875229	valid_1's rmse: 0.191106
# [2440]	training's rmse: 0.087345	valid_1's rmse: 0.191076
# [2450]	training's rmse: 0.0872279	valid_1's rmse: 0.191067
# [2460]	training's rmse: 0.0870594	valid_1's rmse: 0.191049
# [2470]	training's rmse: 0.0868857	valid_1's rmse: 0.191071
# [2480]	training's rmse: 0.0867222	valid_1's rmse: 0.191067
# [2490]	training's rmse: 0.0865894	valid_1's rmse: 0.191054
# [2500]	training's rmse: 0.0863888	valid_1's rmse: 0.191034
# [2510]	training's rmse: 0.0862242	valid_1's rmse: 0.191034
# [2520]	training's rmse: 0.0861042	valid_1's rmse: 0.191035
# [2530]	training's rmse: 0.0859576	valid_1's rmse: 0.191023
# [2540]	training's rmse: 0.0858134	valid_1's rmse: 0.190994
# [2550]	training's rmse: 0.0857084	valid_1's rmse: 0.190951
# [2560]	training's rmse: 0.0856112	valid_1's rmse: 0.190956
# [2570]	training's rmse: 0.0854645	valid_1's rmse: 0.190961
# [2580]	training's rmse: 0.0853548	valid_1's rmse: 0.190956
# [2590]	training's rmse: 0.0852173	valid_1's rmse: 0.190963
# [2600]	training's rmse: 0.0851087	valid_1's rmse: 0.190946
# [2610]	training's rmse: 0.0849363	valid_1's rmse: 0.190928
# [2620]	training's rmse: 0.084781	valid_1's rmse: 0.1909
# [2630]	training's rmse: 0.0846438	valid_1's rmse: 0.190851
# [2640]	training's rmse: 0.0845233	valid_1's rmse: 0.190858
# [2650]	training's rmse: 0.0843992	valid_1's rmse: 0.190816
# [2660]	training's rmse: 0.0842965	valid_1's rmse: 0.190791
# [2670]	training's rmse: 0.0841325	valid_1's rmse: 0.19078
# [2680]	training's rmse: 0.0840089	valid_1's rmse: 0.190776
# [2690]	training's rmse: 0.0838842	valid_1's rmse: 0.19076
# [2700]	training's rmse: 0.0837912	valid_1's rmse: 0.190727
# [2710]	training's rmse: 0.083676	valid_1's rmse: 0.190721
# [2720]	training's rmse: 0.0835098	valid_1's rmse: 0.190706
# [2730]	training's rmse: 0.0833595	valid_1's rmse: 0.190676
# [2740]	training's rmse: 0.0832095	valid_1's rmse: 0.190633
# [2750]	training's rmse: 0.0830593	valid_1's rmse: 0.190599
# [2760]	training's rmse: 0.0829284	valid_1's rmse: 0.190557
# [2770]	training's rmse: 0.0828515	valid_1's rmse: 0.190564
# [2780]	training's rmse: 0.0827378	valid_1's rmse: 0.190556
# [2790]	training's rmse: 0.0826269	valid_1's rmse: 0.190531
# [2800]	training's rmse: 0.0825035	valid_1's rmse: 0.190517
# [2810]	training's rmse: 0.0823693	valid_1's rmse: 0.190522
# [2820]	training's rmse: 0.0822652	valid_1's rmse: 0.190509
# [2830]	training's rmse: 0.0821634	valid_1's rmse: 0.190479
# [2840]	training's rmse: 0.0820071	valid_1's rmse: 0.190485
# [2850]	training's rmse: 0.0818735	valid_1's rmse: 0.190475
# [2860]	training's rmse: 0.0817482	valid_1's rmse: 0.190485
# [2870]	training's rmse: 0.0816023	valid_1's rmse: 0.190497
# [2880]	training's rmse: 0.0814886	valid_1's rmse: 0.190477
# [2890]	training's rmse: 0.0813509	valid_1's rmse: 0.190457
# [2900]	training's rmse: 0.0812066	valid_1's rmse: 0.190451
# [2910]	training's rmse: 0.0811049	valid_1's rmse: 0.190425
# [2920]	training's rmse: 0.0809909	valid_1's rmse: 0.190402
# [2930]	training's rmse: 0.0808907	valid_1's rmse: 0.190391
# [2940]	training's rmse: 0.0808077	valid_1's rmse: 0.190378
# [2950]	training's rmse: 0.0806906	valid_1's rmse: 0.190377
# [2960]	training's rmse: 0.0805912	valid_1's rmse: 0.190389
# [2970]	training's rmse: 0.0805096	valid_1's rmse: 0.190387
# [2980]	training's rmse: 0.0804328	valid_1's rmse: 0.190391
# [2990]	training's rmse: 0.0803285	valid_1's rmse: 0.1904
# [3000]	training's rmse: 0.0802276	valid_1's rmse: 0.190413
# Early stopping, best iteration is:
# [2948]	training's rmse: 0.0807173	valid_1's rmse: 0.190357
# Training from 2007-07-01 00:00:00 to 2008-01-01 00:00:00 finished.
# Training period: 2007-01 to 2008-07
# Validation period: 2008-07 to 2009-01
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.337373	valid_1's rmse: 0.386669
# [20]	training's rmse: 0.295656	valid_1's rmse: 0.345566
# [30]	training's rmse: 0.27981	valid_1's rmse: 0.332006
# [40]	training's rmse: 0.269403	valid_1's rmse: 0.325988
# [50]	training's rmse: 0.260374	valid_1's rmse: 0.318666
# [60]	training's rmse: 0.253788	valid_1's rmse: 0.314556
# [70]	training's rmse: 0.247196	valid_1's rmse: 0.309841
# [80]	training's rmse: 0.241955	valid_1's rmse: 0.306411
# [90]	training's rmse: 0.23642	valid_1's rmse: 0.30242
# [100]	training's rmse: 0.23216	valid_1's rmse: 0.299848
# [110]	training's rmse: 0.228498	valid_1's rmse: 0.297576
# [120]	training's rmse: 0.224893	valid_1's rmse: 0.295877
# [130]	training's rmse: 0.221212	valid_1's rmse: 0.293366
# [140]	training's rmse: 0.217414	valid_1's rmse: 0.291235
# [150]	training's rmse: 0.214317	valid_1's rmse: 0.289426
# [160]	training's rmse: 0.211292	valid_1's rmse: 0.287816
# [170]	training's rmse: 0.207587	valid_1's rmse: 0.285545
# [180]	training's rmse: 0.204495	valid_1's rmse: 0.283834
# [190]	training's rmse: 0.202035	valid_1's rmse: 0.28259
# [200]	training's rmse: 0.199575	valid_1's rmse: 0.281382
# [210]	training's rmse: 0.197455	valid_1's rmse: 0.280267
# [220]	training's rmse: 0.195551	valid_1's rmse: 0.27945
# [230]	training's rmse: 0.193666	valid_1's rmse: 0.278361
# [240]	training's rmse: 0.191952	valid_1's rmse: 0.277959
# [250]	training's rmse: 0.190125	valid_1's rmse: 0.276993
# [260]	training's rmse: 0.18837	valid_1's rmse: 0.276263
# [270]	training's rmse: 0.186603	valid_1's rmse: 0.275428
# [280]	training's rmse: 0.18509	valid_1's rmse: 0.274837
# [290]	training's rmse: 0.183277	valid_1's rmse: 0.274166
# [300]	training's rmse: 0.182229	valid_1's rmse: 0.273604
# [310]	training's rmse: 0.180913	valid_1's rmse: 0.272958
# [320]	training's rmse: 0.179171	valid_1's rmse: 0.272062
# [330]	training's rmse: 0.177933	valid_1's rmse: 0.271688
# [340]	training's rmse: 0.176833	valid_1's rmse: 0.271342
# [350]	training's rmse: 0.175824	valid_1's rmse: 0.270979
# [360]	training's rmse: 0.174602	valid_1's rmse: 0.270651
# [370]	training's rmse: 0.173561	valid_1's rmse: 0.270341
# [380]	training's rmse: 0.171975	valid_1's rmse: 0.269683
# [390]	training's rmse: 0.170496	valid_1's rmse: 0.269219
# [400]	training's rmse: 0.16952	valid_1's rmse: 0.268549
# [410]	training's rmse: 0.168543	valid_1's rmse: 0.268135
# [420]	training's rmse: 0.167141	valid_1's rmse: 0.267663
# [430]	training's rmse: 0.166106	valid_1's rmse: 0.267423
# [440]	training's rmse: 0.164816	valid_1's rmse: 0.266924
# [450]	training's rmse: 0.163847	valid_1's rmse: 0.266466
# [460]	training's rmse: 0.163036	valid_1's rmse: 0.266132
# [470]	training's rmse: 0.161873	valid_1's rmse: 0.26562
# [480]	training's rmse: 0.160908	valid_1's rmse: 0.265393
# [490]	training's rmse: 0.159957	valid_1's rmse: 0.264972
# [500]	training's rmse: 0.159035	valid_1's rmse: 0.264677
# [510]	training's rmse: 0.158079	valid_1's rmse: 0.264469
# [520]	training's rmse: 0.157268	valid_1's rmse: 0.264365
# [530]	training's rmse: 0.156275	valid_1's rmse: 0.264023
# [540]	training's rmse: 0.155208	valid_1's rmse: 0.263656
# [550]	training's rmse: 0.154194	valid_1's rmse: 0.263373
# [560]	training's rmse: 0.153093	valid_1's rmse: 0.263023
# [570]	training's rmse: 0.152115	valid_1's rmse: 0.262747
# [580]	training's rmse: 0.15133	valid_1's rmse: 0.262605
# [590]	training's rmse: 0.150664	valid_1's rmse: 0.26232
# [600]	training's rmse: 0.149915	valid_1's rmse: 0.262075
# [610]	training's rmse: 0.148986	valid_1's rmse: 0.261731
# [620]	training's rmse: 0.148002	valid_1's rmse: 0.261642
# [630]	training's rmse: 0.147177	valid_1's rmse: 0.261444
# [640]	training's rmse: 0.146342	valid_1's rmse: 0.261149
# [650]	training's rmse: 0.145494	valid_1's rmse: 0.260954
# [660]	training's rmse: 0.144704	valid_1's rmse: 0.260724
# [670]	training's rmse: 0.143883	valid_1's rmse: 0.260553
# [680]	training's rmse: 0.143139	valid_1's rmse: 0.260336
# [690]	training's rmse: 0.142549	valid_1's rmse: 0.260213
# [700]	training's rmse: 0.141757	valid_1's rmse: 0.259991
# [710]	training's rmse: 0.141027	valid_1's rmse: 0.259758
# [720]	training's rmse: 0.140489	valid_1's rmse: 0.25928
# [730]	training's rmse: 0.139866	valid_1's rmse: 0.259234
# [740]	training's rmse: 0.139039	valid_1's rmse: 0.258977
# [750]	training's rmse: 0.138395	valid_1's rmse: 0.258774
# [760]	training's rmse: 0.13778	valid_1's rmse: 0.258528
# [770]	training's rmse: 0.137223	valid_1's rmse: 0.258348
# [780]	training's rmse: 0.136646	valid_1's rmse: 0.258194
# [790]	training's rmse: 0.135953	valid_1's rmse: 0.257945
# [800]	training's rmse: 0.135362	valid_1's rmse: 0.257717
# [810]	training's rmse: 0.134962	valid_1's rmse: 0.257651
# [820]	training's rmse: 0.134299	valid_1's rmse: 0.2574
# [830]	training's rmse: 0.133752	valid_1's rmse: 0.257294
# [840]	training's rmse: 0.133139	valid_1's rmse: 0.256898
# [850]	training's rmse: 0.132632	valid_1's rmse: 0.256781
# [860]	training's rmse: 0.132121	valid_1's rmse: 0.256597
# [870]	training's rmse: 0.131579	valid_1's rmse: 0.256541
# [880]	training's rmse: 0.131097	valid_1's rmse: 0.256481
# [890]	training's rmse: 0.13064	valid_1's rmse: 0.25639
# [900]	training's rmse: 0.13016	valid_1's rmse: 0.256276
# [910]	training's rmse: 0.12965	valid_1's rmse: 0.256108
# [920]	training's rmse: 0.129141	valid_1's rmse: 0.256056
# [930]	training's rmse: 0.128694	valid_1's rmse: 0.25604
# [940]	training's rmse: 0.12826	valid_1's rmse: 0.255981
# [950]	training's rmse: 0.127775	valid_1's rmse: 0.255831
# [960]	training's rmse: 0.127283	valid_1's rmse: 0.255771
# [970]	training's rmse: 0.126874	valid_1's rmse: 0.255675
# [980]	training's rmse: 0.126375	valid_1's rmse: 0.255608
# [990]	training's rmse: 0.125828	valid_1's rmse: 0.255512
# [1000]	training's rmse: 0.125472	valid_1's rmse: 0.255487
# [1010]	training's rmse: 0.125112	valid_1's rmse: 0.255411
# [1020]	training's rmse: 0.12472	valid_1's rmse: 0.255313
# [1030]	training's rmse: 0.12439	valid_1's rmse: 0.255282
# [1040]	training's rmse: 0.123923	valid_1's rmse: 0.255201
# [1050]	training's rmse: 0.123527	valid_1's rmse: 0.255124
# [1060]	training's rmse: 0.123173	valid_1's rmse: 0.25496
# [1070]	training's rmse: 0.122829	valid_1's rmse: 0.254952
# [1080]	training's rmse: 0.122373	valid_1's rmse: 0.254853
# [1090]	training's rmse: 0.121998	valid_1's rmse: 0.254723
# [1100]	training's rmse: 0.121529	valid_1's rmse: 0.254564
# [1110]	training's rmse: 0.121074	valid_1's rmse: 0.254504
# [1120]	training's rmse: 0.120656	valid_1's rmse: 0.254389
# [1130]	training's rmse: 0.12044	valid_1's rmse: 0.254391
# [1140]	training's rmse: 0.120116	valid_1's rmse: 0.254368
# [1150]	training's rmse: 0.119816	valid_1's rmse: 0.254343
# [1160]	training's rmse: 0.119496	valid_1's rmse: 0.254376
# [1170]	training's rmse: 0.119044	valid_1's rmse: 0.25427
# [1180]	training's rmse: 0.118721	valid_1's rmse: 0.254186
# [1190]	training's rmse: 0.118296	valid_1's rmse: 0.254279
# [1200]	training's rmse: 0.118029	valid_1's rmse: 0.254313
# [1210]	training's rmse: 0.117647	valid_1's rmse: 0.254309
# [1220]	training's rmse: 0.1173	valid_1's rmse: 0.254285
# [1230]	training's rmse: 0.11705	valid_1's rmse: 0.254215
# [1240]	training's rmse: 0.116754	valid_1's rmse: 0.254254
# Early stopping, best iteration is:
# [1183]	training's rmse: 0.118568	valid_1's rmse: 0.254165
# Training from 2008-01-01 00:00:00 to 2008-07-01 00:00:00 finished.
# Training period: 2007-01 to 2009-01
# Validation period: 2009-01 to 2009-07
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.361722	valid_1's rmse: 0.393256
# [20]	training's rmse: 0.31055	valid_1's rmse: 0.340688
# [30]	training's rmse: 0.287463	valid_1's rmse: 0.319478
# [40]	training's rmse: 0.271625	valid_1's rmse: 0.308543
# [50]	training's rmse: 0.262023	valid_1's rmse: 0.302493
# [60]	training's rmse: 0.253413	valid_1's rmse: 0.297217
# [70]	training's rmse: 0.247273	valid_1's rmse: 0.293952
# [80]	training's rmse: 0.241385	valid_1's rmse: 0.29093
# [90]	training's rmse: 0.235992	valid_1's rmse: 0.287267
# [100]	training's rmse: 0.230457	valid_1's rmse: 0.283782
# [110]	training's rmse: 0.225446	valid_1's rmse: 0.28187
# [120]	training's rmse: 0.221272	valid_1's rmse: 0.279153
# [130]	training's rmse: 0.217867	valid_1's rmse: 0.278236
# [140]	training's rmse: 0.214685	valid_1's rmse: 0.277249
# [150]	training's rmse: 0.210774	valid_1's rmse: 0.275574
# [160]	training's rmse: 0.207896	valid_1's rmse: 0.274385
# [170]	training's rmse: 0.205013	valid_1's rmse: 0.272433
# [180]	training's rmse: 0.202263	valid_1's rmse: 0.270468
# [190]	training's rmse: 0.199527	valid_1's rmse: 0.268956
# [200]	training's rmse: 0.196997	valid_1's rmse: 0.267993
# [210]	training's rmse: 0.194284	valid_1's rmse: 0.267143
# [220]	training's rmse: 0.191926	valid_1's rmse: 0.266515
# [230]	training's rmse: 0.189684	valid_1's rmse: 0.265811
# [240]	training's rmse: 0.187714	valid_1's rmse: 0.265236
# [250]	training's rmse: 0.185677	valid_1's rmse: 0.264681
# [260]	training's rmse: 0.183386	valid_1's rmse: 0.263491
# [270]	training's rmse: 0.181365	valid_1's rmse: 0.262504
# [280]	training's rmse: 0.17942	valid_1's rmse: 0.261968
# [290]	training's rmse: 0.177524	valid_1's rmse: 0.261275
# [300]	training's rmse: 0.175833	valid_1's rmse: 0.26041
# [310]	training's rmse: 0.174185	valid_1's rmse: 0.260144
# [320]	training's rmse: 0.172382	valid_1's rmse: 0.259529
# [330]	training's rmse: 0.170778	valid_1's rmse: 0.259292
# [340]	training's rmse: 0.169107	valid_1's rmse: 0.258833
# [350]	training's rmse: 0.167222	valid_1's rmse: 0.258593
# [360]	training's rmse: 0.165896	valid_1's rmse: 0.258466
# [370]	training's rmse: 0.164436	valid_1's rmse: 0.258136
# [380]	training's rmse: 0.163266	valid_1's rmse: 0.257799
# [390]	training's rmse: 0.16189	valid_1's rmse: 0.257387
# [400]	training's rmse: 0.160235	valid_1's rmse: 0.256724
# [410]	training's rmse: 0.158522	valid_1's rmse: 0.255761
# [420]	training's rmse: 0.15715	valid_1's rmse: 0.255186
# [430]	training's rmse: 0.155558	valid_1's rmse: 0.254853
# [440]	training's rmse: 0.154474	valid_1's rmse: 0.254493
# [450]	training's rmse: 0.152867	valid_1's rmse: 0.254139
# [460]	training's rmse: 0.151778	valid_1's rmse: 0.253741
# [470]	training's rmse: 0.150593	valid_1's rmse: 0.253429
# [480]	training's rmse: 0.149613	valid_1's rmse: 0.253419
# [490]	training's rmse: 0.148618	valid_1's rmse: 0.253165
# [500]	training's rmse: 0.147553	valid_1's rmse: 0.253051
# [510]	training's rmse: 0.146531	valid_1's rmse: 0.252883
# [520]	training's rmse: 0.145536	valid_1's rmse: 0.252887
# [530]	training's rmse: 0.144606	valid_1's rmse: 0.252551
# [540]	training's rmse: 0.143455	valid_1's rmse: 0.252268
# [550]	training's rmse: 0.142394	valid_1's rmse: 0.252177
# [560]	training's rmse: 0.14126	valid_1's rmse: 0.251976
# [570]	training's rmse: 0.140316	valid_1's rmse: 0.251976
# [580]	training's rmse: 0.139443	valid_1's rmse: 0.251716
# [590]	training's rmse: 0.138606	valid_1's rmse: 0.251584
# [600]	training's rmse: 0.137741	valid_1's rmse: 0.251533
# [610]	training's rmse: 0.136879	valid_1's rmse: 0.251341
# [620]	training's rmse: 0.135836	valid_1's rmse: 0.251307
# [630]	training's rmse: 0.134906	valid_1's rmse: 0.251081
# [640]	training's rmse: 0.13399	valid_1's rmse: 0.251046
# [650]	training's rmse: 0.133148	valid_1's rmse: 0.250978
# [660]	training's rmse: 0.132264	valid_1's rmse: 0.250745
# [670]	training's rmse: 0.131438	valid_1's rmse: 0.250614
# [680]	training's rmse: 0.13074	valid_1's rmse: 0.250438
# [690]	training's rmse: 0.130065	valid_1's rmse: 0.250207
# [700]	training's rmse: 0.129387	valid_1's rmse: 0.250134
# [710]	training's rmse: 0.128532	valid_1's rmse: 0.250003
# [720]	training's rmse: 0.12786	valid_1's rmse: 0.249845
# [730]	training's rmse: 0.127157	valid_1's rmse: 0.249526
# [740]	training's rmse: 0.126305	valid_1's rmse: 0.249337
# [750]	training's rmse: 0.125572	valid_1's rmse: 0.249305
# [760]	training's rmse: 0.124619	valid_1's rmse: 0.249034
# [770]	training's rmse: 0.123809	valid_1's rmse: 0.248903
# [780]	training's rmse: 0.123279	valid_1's rmse: 0.248903
# [790]	training's rmse: 0.122662	valid_1's rmse: 0.248905
# [800]	training's rmse: 0.12198	valid_1's rmse: 0.248754
# [810]	training's rmse: 0.121298	valid_1's rmse: 0.248532
# [820]	training's rmse: 0.120778	valid_1's rmse: 0.248323
# [830]	training's rmse: 0.12011	valid_1's rmse: 0.248278
# [840]	training's rmse: 0.11939	valid_1's rmse: 0.248164
# [850]	training's rmse: 0.118758	valid_1's rmse: 0.248048
# [860]	training's rmse: 0.118352	valid_1's rmse: 0.247895
# [870]	training's rmse: 0.11768	valid_1's rmse: 0.247719
# [880]	training's rmse: 0.117213	valid_1's rmse: 0.24777
# [890]	training's rmse: 0.11637	valid_1's rmse: 0.24768
# [900]	training's rmse: 0.115846	valid_1's rmse: 0.247713
# [910]	training's rmse: 0.115004	valid_1's rmse: 0.247632
# [920]	training's rmse: 0.114308	valid_1's rmse: 0.247643
# [930]	training's rmse: 0.113791	valid_1's rmse: 0.247549
# [940]	training's rmse: 0.113295	valid_1's rmse: 0.247361
# [950]	training's rmse: 0.112734	valid_1's rmse: 0.247262
# [960]	training's rmse: 0.11217	valid_1's rmse: 0.247281
# [970]	training's rmse: 0.11185	valid_1's rmse: 0.247311
# [980]	training's rmse: 0.111288	valid_1's rmse: 0.247265
# [990]	training's rmse: 0.110758	valid_1's rmse: 0.24716
# [1000]	training's rmse: 0.110233	valid_1's rmse: 0.24706
# [1010]	training's rmse: 0.109769	valid_1's rmse: 0.247125
# [1020]	training's rmse: 0.109328	valid_1's rmse: 0.247093
# [1030]	training's rmse: 0.108862	valid_1's rmse: 0.246871
# [1040]	training's rmse: 0.108436	valid_1's rmse: 0.246793
# [1050]	training's rmse: 0.107974	valid_1's rmse: 0.246672
# [1060]	training's rmse: 0.107505	valid_1's rmse: 0.246656
# [1070]	training's rmse: 0.106999	valid_1's rmse: 0.24663
# [1080]	training's rmse: 0.106566	valid_1's rmse: 0.24654
# [1090]	training's rmse: 0.106239	valid_1's rmse: 0.246539
# [1100]	training's rmse: 0.105747	valid_1's rmse: 0.2465
# [1110]	training's rmse: 0.105245	valid_1's rmse: 0.246444
# [1120]	training's rmse: 0.104727	valid_1's rmse: 0.246348
# [1130]	training's rmse: 0.104325	valid_1's rmse: 0.246293
# [1140]	training's rmse: 0.10395	valid_1's rmse: 0.246198
# [1150]	training's rmse: 0.103516	valid_1's rmse: 0.246293
# [1160]	training's rmse: 0.10298	valid_1's rmse: 0.24625
# [1170]	training's rmse: 0.102535	valid_1's rmse: 0.246235
# [1180]	training's rmse: 0.102182	valid_1's rmse: 0.24623
# [1190]	training's rmse: 0.101804	valid_1's rmse: 0.246173
# [1200]	training's rmse: 0.101386	valid_1's rmse: 0.246051
# [1210]	training's rmse: 0.100994	valid_1's rmse: 0.245927
# [1220]	training's rmse: 0.100717	valid_1's rmse: 0.245743
# [1230]	training's rmse: 0.100371	valid_1's rmse: 0.245646
# [1240]	training's rmse: 0.100085	valid_1's rmse: 0.245758
# [1250]	training's rmse: 0.0997103	valid_1's rmse: 0.245742
# [1260]	training's rmse: 0.0993394	valid_1's rmse: 0.24576
# [1270]	training's rmse: 0.0989971	valid_1's rmse: 0.245667
# [1280]	training's rmse: 0.0985794	valid_1's rmse: 0.245664
# [1290]	training's rmse: 0.0981732	valid_1's rmse: 0.245603
# [1300]	training's rmse: 0.0978129	valid_1's rmse: 0.245589
# [1310]	training's rmse: 0.0973234	valid_1's rmse: 0.245538
# [1320]	training's rmse: 0.0970146	valid_1's rmse: 0.245562
# [1330]	training's rmse: 0.0966262	valid_1's rmse: 0.24554
# [1340]	training's rmse: 0.0963198	valid_1's rmse: 0.245724
# [1350]	training's rmse: 0.0959392	valid_1's rmse: 0.245679
# [1360]	training's rmse: 0.0956157	valid_1's rmse: 0.245614
# [1370]	training's rmse: 0.0953503	valid_1's rmse: 0.245529
# [1380]	training's rmse: 0.095007	valid_1's rmse: 0.245518
# [1390]	training's rmse: 0.0947805	valid_1's rmse: 0.24557
# [1400]	training's rmse: 0.0944794	valid_1's rmse: 0.245475
# [1410]	training's rmse: 0.0942436	valid_1's rmse: 0.245382
# [1420]	training's rmse: 0.0940196	valid_1's rmse: 0.245274
# [1430]	training's rmse: 0.0937359	valid_1's rmse: 0.2453
# [1440]	training's rmse: 0.0934425	valid_1's rmse: 0.245312
# ...
# [1520]	training's rmse: 0.0950223	valid_1's rmse: 0.265465
# [1530]	training's rmse: 0.0946184	valid_1's rmse: 0.265194
# [1540]	training's rmse: 0.0942824	valid_1's rmse: 0.26524
# [1550]	training's rmse: 0.0938332	valid_1's rmse: 0.265094
# [1560]	training's rmse: 0.0933859	valid_1's rmse: 0.265037
# [1570]	training's rmse: 0.0930344	valid_1's rmse: 0.264908
# [1580]	training's rmse: 0.092749	valid_1's rmse: 0.264997
# [1590]	training's rmse: 0.0922837	valid_1's rmse: 0.264893
# [1600]	training's rmse: 0.091922	valid_1's rmse: 0.264919
# [1610]	training's rmse: 0.0917065	valid_1's rmse: 0.264782
# [1620]	training's rmse: 0.0914051	valid_1's rmse: 0.264562
# [1630]	training's rmse: 0.0911427	valid_1's rmse: 0.264515
# [1640]	training's rmse: 0.0908928	valid_1's rmse: 0.264423
# [1650]	training's rmse: 0.0906565	valid_1's rmse: 0.264342
# [1660]	training's rmse: 0.090313	valid_1's rmse: 0.264277
# [1670]	training's rmse: 0.0900291	valid_1's rmse: 0.264315
# [1680]	training's rmse: 0.0898683	valid_1's rmse: 0.264258
# [1690]	training's rmse: 0.0895567	valid_1's rmse: 0.26422
# [1700]	training's rmse: 0.0892928	valid_1's rmse: 0.264108
# [1710]	training's rmse: 0.0890443	valid_1's rmse: 0.264066
# [1720]	training's rmse: 0.0887964	valid_1's rmse: 0.264005
# [1730]	training's rmse: 0.0884916	valid_1's rmse: 0.263924
# [1740]	training's rmse: 0.0880736	valid_1's rmse: 0.263842
# [1750]	training's rmse: 0.0876443	valid_1's rmse: 0.263689
# [1760]	training's rmse: 0.0874033	valid_1's rmse: 0.263598
# [1770]	training's rmse: 0.0870822	valid_1's rmse: 0.263556
# [1780]	training's rmse: 0.0868085	valid_1's rmse: 0.263492
# [1790]	training's rmse: 0.0865983	valid_1's rmse: 0.263401
# [1800]	training's rmse: 0.0861685	valid_1's rmse: 0.263301
# [1810]	training's rmse: 0.085781	valid_1's rmse: 0.263194
# [1820]	training's rmse: 0.0854614	valid_1's rmse: 0.263141
# [1830]	training's rmse: 0.0851468	valid_1's rmse: 0.26303
# [1840]	training's rmse: 0.0848896	valid_1's rmse: 0.263083
# [1850]	training's rmse: 0.0846101	valid_1's rmse: 0.262968
# [1860]	training's rmse: 0.0843598	valid_1's rmse: 0.262932
# [1870]	training's rmse: 0.0840519	valid_1's rmse: 0.262785
# [1880]	training's rmse: 0.0836546	valid_1's rmse: 0.262638
# [1890]	training's rmse: 0.0834207	valid_1's rmse: 0.262601
# [1900]	training's rmse: 0.0831352	valid_1's rmse: 0.262558
# [1910]	training's rmse: 0.0827667	valid_1's rmse: 0.262213
# [1920]	training's rmse: 0.0825069	valid_1's rmse: 0.262217
# [1930]	training's rmse: 0.0822919	valid_1's rmse: 0.26223
# [1940]	training's rmse: 0.0820452	valid_1's rmse: 0.262167
# [1950]	training's rmse: 0.0818077	valid_1's rmse: 0.262169
# [1960]	training's rmse: 0.081537	valid_1's rmse: 0.262088
# [1970]	training's rmse: 0.0812755	valid_1's rmse: 0.262117
# [1980]	training's rmse: 0.0810155	valid_1's rmse: 0.262105
# [1990]	training's rmse: 0.0808239	valid_1's rmse: 0.262059
# [2000]	training's rmse: 0.0805999	valid_1's rmse: 0.26198
# [2010]	training's rmse: 0.0802809	valid_1's rmse: 0.26193
# [2020]	training's rmse: 0.0800198	valid_1's rmse: 0.261853
# [2030]	training's rmse: 0.0796958	valid_1's rmse: 0.261749
# [2040]	training's rmse: 0.0794195	valid_1's rmse: 0.261677
# [2050]	training's rmse: 0.0791602	valid_1's rmse: 0.261643
# [2060]	training's rmse: 0.0789284	valid_1's rmse: 0.261743
# [2070]	training's rmse: 0.0785979	valid_1's rmse: 0.261724
# [2080]	training's rmse: 0.0783702	valid_1's rmse: 0.261657
# [2090]	training's rmse: 0.0780792	valid_1's rmse: 0.261631
# [2100]	training's rmse: 0.0778925	valid_1's rmse: 0.261621
# [2110]	training's rmse: 0.0775513	valid_1's rmse: 0.261658
# [2120]	training's rmse: 0.0772823	valid_1's rmse: 0.261607
# [2130]	training's rmse: 0.0770039	valid_1's rmse: 0.261532
# [2140]	training's rmse: 0.0767649	valid_1's rmse: 0.26148
# [2150]	training's rmse: 0.0765354	valid_1's rmse: 0.261418
# [2160]	training's rmse: 0.0762885	valid_1's rmse: 0.261349
# [2170]	training's rmse: 0.0760476	valid_1's rmse: 0.261263
# [2180]	training's rmse: 0.0758046	valid_1's rmse: 0.261206
# [2190]	training's rmse: 0.0756117	valid_1's rmse: 0.261124
# [2200]	training's rmse: 0.0753184	valid_1's rmse: 0.261175
# [2210]	training's rmse: 0.075052	valid_1's rmse: 0.261156
# [2220]	training's rmse: 0.0747693	valid_1's rmse: 0.261098
# [2230]	training's rmse: 0.0746201	valid_1's rmse: 0.261111
# [2240]	training's rmse: 0.0744637	valid_1's rmse: 0.261102
# [2250]	training's rmse: 0.0741963	valid_1's rmse: 0.261121
# [2260]	training's rmse: 0.0740111	valid_1's rmse: 0.261069
# [2270]	training's rmse: 0.073843	valid_1's rmse: 0.261171
# [2280]	training's rmse: 0.0736385	valid_1's rmse: 0.261194
# [2290]	training's rmse: 0.0734373	valid_1's rmse: 0.261136
# [2300]	training's rmse: 0.0732397	valid_1's rmse: 0.261182
# [2310]	training's rmse: 0.0730668	valid_1's rmse: 0.261074
# [2320]	training's rmse: 0.0728501	valid_1's rmse: 0.261029
# [2330]	training's rmse: 0.0725841	valid_1's rmse: 0.260958
# [2340]	training's rmse: 0.0723817	valid_1's rmse: 0.26088
# [2350]	training's rmse: 0.07222	valid_1's rmse: 0.260851
# [2360]	training's rmse: 0.072071	valid_1's rmse: 0.260812
# [2370]	training's rmse: 0.0719088	valid_1's rmse: 0.260816
# [2380]	training's rmse: 0.0717275	valid_1's rmse: 0.260799
# [2390]	training's rmse: 0.0715035	valid_1's rmse: 0.260766
# [2400]	training's rmse: 0.0713575	valid_1's rmse: 0.260721
# [2410]	training's rmse: 0.0711434	valid_1's rmse: 0.260683
# [2420]	training's rmse: 0.0710282	valid_1's rmse: 0.260662
# [2430]	training's rmse: 0.0708689	valid_1's rmse: 0.260598
# [2440]	training's rmse: 0.0707263	valid_1's rmse: 0.260537
# [2450]	training's rmse: 0.0705458	valid_1's rmse: 0.260652
# [2460]	training's rmse: 0.0703844	valid_1's rmse: 0.260703
# [2470]	training's rmse: 0.0701427	valid_1's rmse: 0.260691
# [2480]	training's rmse: 0.0699418	valid_1's rmse: 0.260675
# [2490]	training's rmse: 0.0697939	valid_1's rmse: 0.2606
# Early stopping, best iteration is:
# [2439]	training's rmse: 0.0707305	valid_1's rmse: 0.260533
# Training from 2021-07-01 00:00:00 to 2022-01-01 00:00:00 finished.
# Training period: 2007-01 to 2022-07
# Validation period: 2022-07 to 2023-01
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.467912	valid_1's rmse: 0.482659
# [20]	training's rmse: 0.368359	valid_1's rmse: 0.387783
# [30]	training's rmse: 0.337978	valid_1's rmse: 0.368146
# [40]	training's rmse: 0.320487	valid_1's rmse: 0.36016
# [50]	training's rmse: 0.30766	valid_1's rmse: 0.353709
# [60]	training's rmse: 0.298555	valid_1's rmse: 0.349623
# [70]	training's rmse: 0.291337	valid_1's rmse: 0.347859
# [80]	training's rmse: 0.283174	valid_1's rmse: 0.344362
# [90]	training's rmse: 0.277131	valid_1's rmse: 0.342325
# [100]	training's rmse: 0.271217	valid_1's rmse: 0.34017
# [110]	training's rmse: 0.264931	valid_1's rmse: 0.337734
# [120]	training's rmse: 0.259601	valid_1's rmse: 0.336274
# [130]	training's rmse: 0.254	valid_1's rmse: 0.333751
# [140]	training's rmse: 0.248909	valid_1's rmse: 0.331796
# [150]	training's rmse: 0.243996	valid_1's rmse: 0.330131
# [160]	training's rmse: 0.239643	valid_1's rmse: 0.329495
# [170]	training's rmse: 0.234919	valid_1's rmse: 0.328927
# [180]	training's rmse: 0.230439	valid_1's rmse: 0.327499
# [190]	training's rmse: 0.226558	valid_1's rmse: 0.326053
# [200]	training's rmse: 0.222692	valid_1's rmse: 0.32459
# [210]	training's rmse: 0.218895	valid_1's rmse: 0.324282
# [220]	training's rmse: 0.215714	valid_1's rmse: 0.323105
# [230]	training's rmse: 0.211882	valid_1's rmse: 0.321951
# [240]	training's rmse: 0.208713	valid_1's rmse: 0.321404
# [250]	training's rmse: 0.206014	valid_1's rmse: 0.320657
# [260]	training's rmse: 0.203406	valid_1's rmse: 0.32042
# [270]	training's rmse: 0.200726	valid_1's rmse: 0.319426
# [280]	training's rmse: 0.197827	valid_1's rmse: 0.318753
# [290]	training's rmse: 0.195151	valid_1's rmse: 0.318067
# [300]	training's rmse: 0.192505	valid_1's rmse: 0.317035
# [310]	training's rmse: 0.190621	valid_1's rmse: 0.316196
# [320]	training's rmse: 0.1883	valid_1's rmse: 0.316074
# [330]	training's rmse: 0.186393	valid_1's rmse: 0.315647
# [340]	training's rmse: 0.184318	valid_1's rmse: 0.315078
# [350]	training's rmse: 0.182251	valid_1's rmse: 0.31501
# [360]	training's rmse: 0.179409	valid_1's rmse: 0.315179
# [370]	training's rmse: 0.176675	valid_1's rmse: 0.314488
# [380]	training's rmse: 0.174355	valid_1's rmse: 0.314751
# [390]	training's rmse: 0.172333	valid_1's rmse: 0.314768
# [400]	training's rmse: 0.170503	valid_1's rmse: 0.314284
# [410]	training's rmse: 0.168967	valid_1's rmse: 0.313988
# [420]	training's rmse: 0.167323	valid_1's rmse: 0.31358
# [430]	training's rmse: 0.165532	valid_1's rmse: 0.313345
# [440]	training's rmse: 0.163953	valid_1's rmse: 0.312881
# [450]	training's rmse: 0.161905	valid_1's rmse: 0.312932
# [460]	training's rmse: 0.160484	valid_1's rmse: 0.312461
# [470]	training's rmse: 0.158965	valid_1's rmse: 0.312324
# [480]	training's rmse: 0.15749	valid_1's rmse: 0.311952
# [490]	training's rmse: 0.155957	valid_1's rmse: 0.311719
# [500]	training's rmse: 0.154562	valid_1's rmse: 0.311499
# [510]	training's rmse: 0.153016	valid_1's rmse: 0.310913
# [520]	training's rmse: 0.151622	valid_1's rmse: 0.310803
# [530]	training's rmse: 0.149987	valid_1's rmse: 0.310602
# [540]	training's rmse: 0.148779	valid_1's rmse: 0.310722
# [550]	training's rmse: 0.147287	valid_1's rmse: 0.310431
# [560]	training's rmse: 0.145726	valid_1's rmse: 0.309936
# [570]	training's rmse: 0.144544	valid_1's rmse: 0.30993
# [580]	training's rmse: 0.143424	valid_1's rmse: 0.309916
# [590]	training's rmse: 0.142327	valid_1's rmse: 0.30984
# [600]	training's rmse: 0.141214	valid_1's rmse: 0.309841
# [610]	training's rmse: 0.140005	valid_1's rmse: 0.30977
# [620]	training's rmse: 0.138921	valid_1's rmse: 0.309613
# [630]	training's rmse: 0.137694	valid_1's rmse: 0.30936
# [640]	training's rmse: 0.136722	valid_1's rmse: 0.309275
# [650]	training's rmse: 0.135997	valid_1's rmse: 0.309394
# [660]	training's rmse: 0.135103	valid_1's rmse: 0.309289
# [670]	training's rmse: 0.1339	valid_1's rmse: 0.309254
# [680]	training's rmse: 0.132631	valid_1's rmse: 0.309298
# [690]	training's rmse: 0.131882	valid_1's rmse: 0.309355
# [700]	training's rmse: 0.130799	valid_1's rmse: 0.309464
# Early stopping, best iteration is:
# [643]	training's rmse: 0.136592	valid_1's rmse: 0.309231
# Training from 2022-01-01 00:00:00 to 2022-07-01 00:00:00 finished.
# Training period: 2007-01 to 2023-01
# Validation period: 2023-01 to 2023-07
# Training until validation scores don't improve for 60 rounds
# [10]	training's rmse: 0.458457	valid_1's rmse: 0.42975
# [20]	training's rmse: 0.343057	valid_1's rmse: 0.356423
# [30]	training's rmse: 0.308093	valid_1's rmse: 0.340698
# [40]	training's rmse: 0.288136	valid_1's rmse: 0.331294
# [50]	training's rmse: 0.274056	valid_1's rmse: 0.326009
# [60]	training's rmse: 0.264171	valid_1's rmse: 0.323526
# [70]	training's rmse: 0.253976	valid_1's rmse: 0.321204
# [80]	training's rmse: 0.244609	valid_1's rmse: 0.319503
# [90]	training's rmse: 0.237231	valid_1's rmse: 0.31714
# [100]	training's rmse: 0.231105	valid_1's rmse: 0.315754
# [110]	training's rmse: 0.224243	valid_1's rmse: 0.313708
# [120]	training's rmse: 0.218236	valid_1's rmse: 0.31185
# [130]	training's rmse: 0.212222	valid_1's rmse: 0.310475
# [140]	training's rmse: 0.207662	valid_1's rmse: 0.30913
# [150]	training's rmse: 0.202322	valid_1's rmse: 0.308708
# [160]	training's rmse: 0.197799	valid_1's rmse: 0.307721
# [170]	training's rmse: 0.193175	valid_1's rmse: 0.307837
# [180]	training's rmse: 0.188172	valid_1's rmse: 0.307042
# [190]	training's rmse: 0.183432	valid_1's rmse: 0.306495
# [200]	training's rmse: 0.17949	valid_1's rmse: 0.306433
# [210]	training's rmse: 0.175372	valid_1's rmse: 0.305935
# [220]	training's rmse: 0.171435	valid_1's rmse: 0.305766
# [230]	training's rmse: 0.16831	valid_1's rmse: 0.305576
# [240]	training's rmse: 0.165491	valid_1's rmse: 0.304951
# [250]	training's rmse: 0.163172	valid_1's rmse: 0.304987
# [260]	training's rmse: 0.160411	valid_1's rmse: 0.304545
# [270]	training's rmse: 0.157688	valid_1's rmse: 0.304251
# [280]	training's rmse: 0.154807	valid_1's rmse: 0.303954
# [290]	training's rmse: 0.152106	valid_1's rmse: 0.303766
# [300]	training's rmse: 0.149093	valid_1's rmse: 0.303416
# [310]	training's rmse: 0.146345	valid_1's rmse: 0.303241
# [320]	training's rmse: 0.143781	valid_1's rmse: 0.302841
# [330]	training's rmse: 0.141318	valid_1's rmse: 0.302357
# [340]	training's rmse: 0.138666	valid_1's rmse: 0.302121
# [350]	training's rmse: 0.136488	valid_1's rmse: 0.301776
# [360]	training's rmse: 0.134189	valid_1's rmse: 0.301385
# [370]	training's rmse: 0.131939	valid_1's rmse: 0.301209
# [380]	training's rmse: 0.129933	valid_1's rmse: 0.301099
# [390]	training's rmse: 0.127744	valid_1's rmse: 0.30082
# [400]	training's rmse: 0.125495	valid_1's rmse: 0.300682
# [410]	training's rmse: 0.123607	valid_1's rmse: 0.30073
# [420]	training's rmse: 0.122054	valid_1's rmse: 0.300535
# [430]	training's rmse: 0.1202	valid_1's rmse: 0.300476
# [440]	training's rmse: 0.118311	valid_1's rmse: 0.300458
# [450]	training's rmse: 0.116758	valid_1's rmse: 0.300352
# [460]	training's rmse: 0.115045	valid_1's rmse: 0.30014
# [470]	training's rmse: 0.113478	valid_1's rmse: 0.300143
# [480]	training's rmse: 0.111958	valid_1's rmse: 0.29997
# [490]	training's rmse: 0.110499	valid_1's rmse: 0.299841
# [500]	training's rmse: 0.109313	valid_1's rmse: 0.299579
# [510]	training's rmse: 0.108072	valid_1's rmse: 0.299733
# [520]	training's rmse: 0.10646	valid_1's rmse: 0.299879
# [530]	training's rmse: 0.104785	valid_1's rmse: 0.299508
# [540]	training's rmse: 0.103479	valid_1's rmse: 0.299452
# [550]	training's rmse: 0.102228	valid_1's rmse: 0.299404
# [560]	training's rmse: 0.100994	valid_1's rmse: 0.299437
# [570]	training's rmse: 0.0996983	valid_1's rmse: 0.299491
# [580]	training's rmse: 0.0985601	valid_1's rmse: 0.299442
# [590]	training's rmse: 0.0974499	valid_1's rmse: 0.299427
# [600]	training's rmse: 0.0962859	valid_1's rmse: 0.299421
# [610]	training's rmse: 0.095025	valid_1's rmse: 0.299345
# [620]	training's rmse: 0.0939679	valid_1's rmse: 0.299343
# [630]	training's rmse: 0.0928106	valid_1's rmse: 0.299274
# [640]	training's rmse: 0.0916258	valid_1's rmse: 0.299132
# [650]	training's rmse: 0.0904799	valid_1's rmse: 0.299186
# [660]	training's rmse: 0.0893494	valid_1's rmse: 0.299147
# [670]	training's rmse: 0.0882097	valid_1's rmse: 0.299154
# [680]	training's rmse: 0.0872133	valid_1's rmse: 0.299108
# [690]	training's rmse: 0.0860806	valid_1's rmse: 0.299043
# [700]	training's rmse: 0.0851256	valid_1's rmse: 0.29879
# [710]	training's rmse: 0.084278	valid_1's rmse: 0.298789
# [720]	training's rmse: 0.0832175	valid_1's rmse: 0.298775
# [730]	training's rmse: 0.0823465	valid_1's rmse: 0.298726
# [740]	training's rmse: 0.0813794	valid_1's rmse: 0.29862
# [750]	training's rmse: 0.0806251	valid_1's rmse: 0.298712
# [760]	training's rmse: 0.0797948	valid_1's rmse: 0.298792
# [770]	training's rmse: 0.0787714	valid_1's rmse: 0.298656
# [780]	training's rmse: 0.0778923	valid_1's rmse: 0.298575
# [790]	training's rmse: 0.0771026	valid_1's rmse: 0.29857
# [800]	training's rmse: 0.0761669	valid_1's rmse: 0.298698
# [810]	training's rmse: 0.0754913	valid_1's rmse: 0.298606
# [820]	training's rmse: 0.0747737	valid_1's rmse: 0.298395
# [830]	training's rmse: 0.0738487	valid_1's rmse: 0.298402
# [840]	training's rmse: 0.0730107	valid_1's rmse: 0.298373
# [850]	training's rmse: 0.0721834	valid_1's rmse: 0.298367
# [860]	training's rmse: 0.0713425	valid_1's rmse: 0.298307
# [870]	training's rmse: 0.0706125	valid_1's rmse: 0.298275
# [880]	training's rmse: 0.0699332	valid_1's rmse: 0.29827
# [890]	training's rmse: 0.0692499	valid_1's rmse: 0.298283
# [900]	training's rmse: 0.0684989	valid_1's rmse: 0.298271
# [910]	training's rmse: 0.0679059	valid_1's rmse: 0.298191
# [920]	training's rmse: 0.0671928	valid_1's rmse: 0.298286
# [930]	training's rmse: 0.0665444	valid_1's rmse: 0.298249
# [940]	training's rmse: 0.0659779	valid_1's rmse: 0.298367
# [950]	training's rmse: 0.0653851	valid_1's rmse: 0.298339
# [960]	training's rmse: 0.0647741	valid_1's rmse: 0.298334
# Early stopping, best iteration is:
# [909]	training's rmse: 0.0679525	valid_1's rmse: 0.298187
# Training from 2022-07-01 00:00:00 to 2023-01-01 00:00:00 finished.

# %% [markdown]
# ## 누적으로 학습셋의 범위가 확장되는 방식

# %%
# train_df['계약년월'] = pd.to_datetime(train_df['계약년월'], format='%Y%m')

# min_date = train_df['계약년월'].min()
# max_date = train_df['계약년월'].max()
# months_range = pd.date_range(start=min_date, end=max_date, freq='6MS')

# models = []
# for start_date in months_range[:-1]:
#     end_date = start_date + pd.DateOffset(months=6)
    
#     train_period = (train_df['계약년월'] >= min_date) & (train_df['계약년월'] < end_date)
#     X_train = train_X[train_period]
#     y_train = train_y[train_period]
    
#     valid_period = (train_df['계약년월'] >= end_date) & (train_df['계약년월'] < end_date + pd.DateOffset(months=6))
#     X_valid = train_X[valid_period]
#     y_valid = train_y[valid_period]
    
#     if len(X_train) == 0 or len(X_valid) == 0:
#         continue
    
#     print(f"Training period: {min_date.strftime('%Y-%m')} to {end_date.strftime('%Y-%m')}")
#     print(f"Validation period: {end_date.strftime('%Y-%m')} to {(end_date + pd.DateOffset(months=6)).strftime('%Y-%m')}")
    
#     model = lgb.LGBMRegressor(**params)
    
#     model.fit(
#         X_train, y_train,
#         eval_set=[(X_train, y_train), (X_valid, y_valid)],
#         eval_metric='rmse',
#         callbacks=[lgb.early_stopping(stopping_rounds=60), lgb.log_evaluation(period=10, show_stdv=True)]
#     )
    
#     models.append(model)
#     print(f"Training from {min_date} to {end_date} finished. Validation from {end_date} to {end_date + pd.DateOffset(months=6)}")

# %%
test_preds = np.zeros(len(test_df))
for model in models:
    test_preds += model.predict(test_df) / len(models)

# 로그 변환된 예측값을 원래 값으로 변환
test_preds_original = np.expm1(test_preds)
test_preds_original = np.round(test_preds_original).astype(int)

# 예측 결과를 데이터프레임으로 저장
preds_df = pd.DataFrame(test_preds_original, columns=['target'])
print(preds_df.shape)

preds_df.to_csv('../submissions/누적O.csv', index=False)
# Out:
# (9272, 1)

# %%
output = pd.read_csv("../output.csv")

# %%
# 1개
plt.figure(figsize=(10, 6))
plt.plot(preds_df['target'])
plt.xlabel('Index')
plt.ylabel('Target')
plt.grid(True)
plt.show()


# 2개
plt.figure(figsize=(10, 6))
plt.plot(preds_df['target'], label='fs', marker='o')
plt.plot(output['target'], label='xgb', marker='x')
plt.xlabel('Index')
plt.ylabel('Target')
plt.grid(True)
plt.show()
