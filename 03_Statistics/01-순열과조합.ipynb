# %%
import itertools

arr = [x for x in range(1, 11)]

## Permutations
p = list(itertools.permutations(arr, 3)) ## 10 Permutation 3
print(len(p))

## Combinations
c = list(itertools.combinations(arr, 3)) ## 10 Combinations 3
print(len(c))
# Out:
# 720
# 120
