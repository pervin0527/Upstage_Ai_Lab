# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. 평균 mu, 표준편차 sigma
# 2. 1000개의 샘플을 생성
# 3. 히스토그램을 그리기
# 4. 정규분포의 확률밀도함수를 그래프로 그리는 작업
# 5. 출력

# %%
mu, sigma = 0, 0.1 ## 정규분포에 대한 평균과 표춘편차

# %%
s = np.random.normal(mu, sigma, 1000) ## 평균과 표준편차를 적용하고, 정규분포를 따르는 1000개의 무작위 샘플을 생성,

# %%
count, bins, ignored = plt.hist(s, 30, density=True) ## 1000개의 샘플에서 30개의 히스토그램 바를 그린다.
plt.plot(bins, 1/(sigma*np.sqrt(2*np.pi))* np.exp(- (bins - mu)**2 / (2*sigma**2)), linewidth=2, color='r') ## 정규분포의 함수를 계산해 히스토그램 위에 빨간색 선을 그림.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 평균과 표준편차 설정
mu = 0
sigma = 0.1

# 충분히 넓은 범위의 x값 설정
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 1000)

# 정규분포의 확률밀도함수 계산
pdf = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# 선 그래프로 PDF 그리기
plt.plot(x, pdf, linewidth=2, color='r')
plt.title('Normal Distribution PDF')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 이항 분포 데이터 생성
data = np.random.binomial(n=10, p=0.5, size=1000)

# 각 결과값의 빈도 계산
values, counts = np.unique(data, return_counts=True)

# plt.plot을 사용하여 선 그래프 그리기
plt.plot(values, counts, marker='o', linestyle='-')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title('Binomial Distribution (n=10, p=0.5)')
plt.grid(True)
plt.show()
