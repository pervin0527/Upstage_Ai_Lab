# %%
import pandas as pd
from scipy import stats

df = pd.read_csv('/Users/pervin0527/Upstage_Ai_Lab/03_Statistics/data/단일표본 t 검정 실습.csv', sep=',', encoding='CP949')

df
# Out:
#       번호   용량
# 0      1  252
# 1      2  271
# 2      3  282
# 3      4  257
# 4      5  240
# ..   ...  ...
# 295  296  222
# 296  297  263
# 297  298  262
# 298  299  242
# 299  300  258
#
# [300 rows x 2 columns]

# %%
from scipy import stats
print(stats.ttest_1samp(df['용량'], 250)) ## pvalue=4.4766279943188894e-06 인데, 유의수준 0.05보다 훨씬 작은 확률이므로 귀무가설은 기각되고 대립가설을 채택한다.
# Out:
# Ttest_1sampResult(statistic=-4.673894108057419, pvalue=4.4766279943188894e-06)
