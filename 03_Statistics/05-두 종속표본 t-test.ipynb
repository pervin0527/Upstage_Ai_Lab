# %%
import pandas as pd

df = pd.read_csv('/Users/pervin0527/Upstage_Ai_Lab/03_Statistics/data/두_종속표본_t검정_실습.csv', sep=(','), encoding='CP949')
df
# Out:
#     복용 전  복용 후
# 0   37.5  36.3
# 1   36.5  36.5
# 2   38.0  36.7
# 3   37.9  36.1
# 4   36.9  36.4
# 5   36.3  36.5
# 6   38.2  36.8
# 7   36.9  36.2
# 8   36.5  36.6
# 9   36.7  36.5
# 10  37.6  36.7
# 11  36.9  36.5
# 12  37.5  36.2
# 13  37.0  36.3
# 14  37.2  36.8

# %%
from scipy import stats
print(stats.ttest_rel(df['복용 전'], df['복용 후']))
# Out:
# Ttest_relResult(statistic=4.483040960107324, pvalue=0.0005156690572260739)
