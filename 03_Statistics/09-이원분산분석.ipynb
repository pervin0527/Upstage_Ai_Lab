# %%
import pandas as pd
df = pd.read_csv('/Users/pervin0527/Upstage_Ai_Lab/03_Statistics/data/이원분산분석_실습.csv', encoding='CP949')
df
# Out:
# <ipython-input-1-4f2961170124>:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df = pd.read_csv('이원분산분석.csv', ',', encoding='CP949')
#     store  area  satisfaction
# 0       1     1             1
# 1       1     2             5
# 2       1     3             4
# 3       1     1             2
# 4       1     2             3
# 5       1     3             3
# 6       1     1             2
# 7       1     2             4
# 8       1     3             4
# 9       2     1             3
# 10      2     2             5
# 11      2     3             4
# 12      2     1             3
# 13      2     2             5
# 14      2     3             4
# 15      2     1             2
# 16      2     2             4
# 17      2     3             4
# 18      3     1             1
# 19      3     2             3
# 20      3     3             3
# 21      3     1             1
# 22      3     2             2
# ...

# %%
# !pip install pingouin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 2.1 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-posthocs

# %%
import scipy as sp
import numpy as np
import pingouin as pg
import scikit_posthocs
df1= df[['store', 'area', 'satisfaction']]
pd.options.display.float_format='{:3f}'.format
print(pg.anova(dv='satisfaction', between=['store', 'area'], data=df1))
# Out:
#          Source        SS        DF        MS         F    p-unc      np2
# 0         store  8.422222  2.000000  4.211111 12.339535 0.000286 0.540271
# 1          area 20.466667  2.000000 10.233333 29.986047 0.000001 0.740651
# 2  store * area  1.811111  4.000000  0.452778  1.326744 0.292726 0.201733
# 3      Residual  7.166667 21.000000  0.341270       NaN      NaN      NaN

# %%
df1['store'].astype(str)
print(scikit_posthocs.posthoc_scheffe(df1, val_col='satisfaction', group_col='store'))
# Out:
#          1        2        3
# 1 1.000000 0.411815 0.426107
# 2 0.411815 1.000000 0.033807
# 3 0.426107 0.033807 1.000000

# %%
df1['area'].astype(str)
print(scikit_posthocs.posthoc_scheffe(df1, val_col='satisfaction', group_col='area'))
# Out:
#          1        2        3
# 1 1.000000 0.000139 0.000285
# 2 0.000139 1.000000 0.962003
# 3 0.000285 0.962003 1.000000
