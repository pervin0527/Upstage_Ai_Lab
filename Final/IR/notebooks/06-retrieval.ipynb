# %%
import os
import re
import json
import traceback
import huggingface_hub

from tqdm import tqdm
from openai import OpenAI

from kiwipiepy import Kiwi ## 한글 형태소 분석기

from langchain.schema import Document
from langchain.vectorstores import FAISS  ## 벡터 DB
from langchain_openai import OpenAIEmbeddings
from langchain.document_loaders import JSONLoader
from langchain.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

from dotenv import load_dotenv
load_dotenv("../keys.env")

openai_api_key = os.getenv('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = openai_api_key

hf_token = os.getenv("HF_TOKEN")
huggingface_hub.login(hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/pervinco/.cache/huggingface/token
# Login successful

# %%
# 문서 로드 함수
def load_jsonl(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [json.loads(line) for line in f]

# 문서 로드
raw_documents = load_jsonl('../dataset/documents.jsonl')

# 문서에서 docid를 포함한 Document 리스트 생성
documents = []
for doc in raw_documents:
    doc_id = doc['docid']  # JSONL 파일에서 docid 추출
    content = doc['content']  # 문서 내용 추출
    documents.append(Document(page_content=content, metadata={"doc_id": doc_id}))

# %%
# KIWI로 토큰화 함수 정의
kiwi = Kiwi()
def kiwi_tokenize(text):
    return [token.form for token in kiwi.tokenize(text)]

# %%
# BM25와 FAISS 기반 검색기 생성
bm25 = BM25Retriever.from_documents(documents)
kiwi_bm25 = BM25Retriever.from_documents(documents, preprocess_func=kiwi_tokenize)

# FAISS 벡터 DB 생성 및 메타데이터와 함께 저장
faiss = FAISS.from_documents(documents, OpenAIEmbeddings()).as_retriever()

bm25_faiss_73 = EnsembleRetriever(
    retrievers=[bm25, faiss],  # 사용할 검색 모델의 리스트
    weights=[0.7, 0.3],  # 각 검색 모델의 결과에 적용할 가중치
    search_type="mmr",  # 검색 결과의 다양성을 증진시키는 MMR 방식을 사용
)
bm25_faiss_37 = EnsembleRetriever(
    retrievers=[bm25, faiss],
    weights=[0.3, 0.7],
    search_type="mmr",
)
kiwibm25_faiss_73 = EnsembleRetriever(
    retrievers=[kiwi_bm25, faiss],
    weights=[0.7, 0.3],
    search_type="mmr",
)
kiwibm25_faiss_37 = EnsembleRetriever(
    retrievers=[kiwi_bm25, faiss],
    weights=[0.3, 0.7],
    search_type="mmr",
)

# %%
retrievers = {
    "bm25": bm25,
    "kiwi_bm25": kiwi_bm25,
    "faiss": faiss,
    "bm25_faiss_73": bm25_faiss_73,
    "bm25_faiss_37": bm25_faiss_37,
    "kiwi_bm25_faiss_73": kiwibm25_faiss_73,
    "kiwi_bm25_faiss_37": kiwibm25_faiss_37,
}

# %%
# 검색 결과 출력 함수
def print_search_results(retrievers, query):
    print(f"Query : {query}")
    for name, retriever in retrievers.items():
        results = retriever.invoke(query)
        print(f"{name} 결과:")
        for result in results:
            print(f"문서 ID: {result.metadata['doc_id']} 내용: {result.page_content}")
        print("===" * 20)

# %%
print(print_search_results(retrievers, "ktx의 평균 속도는 얼마인가?"))
# Out:
# Query : ktx의 평균 속도는 얼마인가?
# bm25 결과:
# 문서 ID: e8d07278-c590-43e2-b99a-47d5adaf123d 내용: 아르투로는 3,000미터 경주에서 10분이라는 기록으로 결승점에 도달했습니다. 이를 통해 우리는 아르투로의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 걸린 시간으로 나눈 값입니다. 따라서, 아르투로의 평균 속도는 3,000미터를 10분으로 나눈 값인 300미터/분입니다. 이를 미터/초로 변환하면 5 m/s가 됩니다. 따라서, 아르투로의 평균 속도는 5 m/s입니다.
# 문서 ID: 8ca2ebf5-9f0d-4d2f-bfef-92b44c920d2e 내용: 고무 오리 경주에서 우승한 오리는 10분 동안 300미터를 이동했습니다. 이를 통해 우승한 오리의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 소요된 시간으로 나눈 값입니다. 따라서, 이 경우 오리의 평균 속도는 300미터를 10분으로 나눈 값인 30미터/분입니다. 그러나, 문제에서 속도를 미터/초로 표현하라고 하였으므로, 분 단위를 초 단위로 변환해야 합니다. 1분은 60초이므로, 30미터/분은 0.5미터/초입니다. 따라서, 고무 오리 경주에서 우승한 오리의 평균 속도는 0.5미터/초입니다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: fe6a254b-0f86-4025-b867-b35d56273c8d 내용: 안나는 20초 동안 100미터를 달렸습니다. 이는 안나의 평균 속도가 5 m/s라는 것을 의미합니다. 안나는 매 초마다 5미터를 달렸으며, 이는 안나가 얼마나 빠르게 달렸는지를 나타냅니다. 평균 속도는 달린 거리를 시간으로 나눈 값으로 계산됩니다. 따라서 안나는 초당 5미터를 달린 것입니다. 이러한 평균 속도는 안나가 얼마나 빠르게 달렸는지를 측정하는 중요한 지표입니다.
# ============================================================
# kiwi_bm25 결과:
# 문서 ID: 74770db8-9c70-4f2b-a699-b2b63e24f1a8 내용: 두 우주선이 지구에 동일한 속도로 접근하고 있다. 이는 지구에 있는 관찰자가 측정한 것이다. 하지만 두 우주선은 서로 반대 방향에서 접근하고 있다. 한 우주선에 있는 미터자가 다른 우주선의 승객에 의해 60 cm로 측정되었다. 이는 상대성 이론에 따라 두 우주선의 속도가 서로 다르게 측정되는 것을 의미한다. 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산하기 위해서는 상대성 이론의 공식을 사용해야 한다. 상대성 이론에 따르면, 두 우주선의 속도는 다음과 같이 계산할 수 있다. 두 우주선의 속도를 각각 v1, v2라고 하면, v1 + v2 = 2v, v1 - v2 = 60 cm/c. 이를 풀어서 계산하면, v1 = v + 30 cm/c, v2 = v - 30 cm/c이다. 따라서, 두 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산해보면, v1 + v2 = 2v = 60 cm/c, v = 30 cm/c이다. 따라서, 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 0.5c이다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: 14c8ba1a-e650-47bb-b34b-6e81373cf96b 내용: 과학적 연구를 통해 결정될 가능성이 가장 큰 질문은 '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'입니다. 토마토는 식물이므로 광합성을 통해 에너지를 생산하는데, 이를 위해서는 충분한 양의 빛이 필요합니다. 그러나 토마토가 필요로 하는 빛의 양은 다른 식물과 다를 수 있으며, 이를 알아내기 위해서는 과학적 연구가 필요합니다. 과학자들은 토마토의 광합성 작용에 영향을 미치는 다양한 요인들을 연구하고 있으며, 이를 통해 토마토를 최적으로 키우기 위한 빛의 양을 결정하고자 합니다. 이 연구를 통해 농작물 생산성을 향상시키고, 더 많은 사람들에게 안정적인 식량을 공급할 수 있을 것으로 기대됩니다. 따라서, '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'라는 질문은 과학적 연구를 통해 결정될 가능성이 가장 큰 질문 중 하나입니다.
# 문서 ID: 154e2f2e-4731-4aec-ae10-9d9e685cd055 내용: 리카르도는 저울에서 빈 눈금 실린더를 측정했습니다. 그런 다음 눈금 실린더에 50mL의 액체를 채워 다시 측정했습니다. 이 과정에서 리카르도는 액체의 질량을 알고 싶어했습니다. 액체의 질량을 측정하기 위해 리카르도는 저울을 사용했습니다. 저울은 물체의 질량을 측정하는 도구로, 물체의 무게를 알려줍니다. 리카르도는 눈금 실린더에 액체를 채워 측정한 결과를 통해 액체의 질량을 알아낼 수 있었습니다. 이러한 실험을 통해 리카르도는 액체의 질량이 얼마인지 알아낼 수 있었습니다. 따라서 리카르도가 답변을 얻으려는 질문으로 가장 가능성이 높은 것은 '액체의 질량은 얼마인가?'입니다.
# ============================================================
# faiss 결과:
# 문서 ID: e0588d15-873f-4b61-8ca1-994cbacc33bc 내용: 두 사람이 시속 20킬로미터(km/h)로 자전거를 타고 있었습니다. 그들은 30분 동안 속도가 시속 26킬로미터로 증가했다는 것을 관찰했습니다. 이들의 평균 가속도는 12.0km/h^2입니다. 가속도는 속도의 변화량을 시간으로 나눈 값으로 정의됩니다. 이 경우, 속도의 변화량은 26km/h - 20km/h = 6km/h이고, 시간은 30분 = 0.5시간입니다. 따라서, 평균 가속도는 6km/h / 0.5시간 = 12.0km/h^2입니다. 이는 두 사람이 자전거를 타는 동안 속도가 시속 12.0km/h씩 증가했다는 것을 의미합니다.
# 문서 ID: 5d48fa4e-1999-45dc-b768-b15b30a87cc5 내용: 한 대의 버스가 두 도시 간 280 킬로미터를 이동했습니다. 이 버스는 첫 번째 도시를 오후 3시에 출발하여 두 번째 도시에 오후 7시에 도착했습니다. 따라서, 이 버스의 이동에 걸린 시간은 4시간입니다. 이를 토대로 버스의 평균 속도를 계산해보면, 280 킬로미터를 4시간 동안 이동했으므로, 평균 속도는 70 km/h입니다. 따라서, 이 버스의 평균 속도는 70 km/h입니다.
# 문서 ID: c58ab6ec-4b3c-4561-96e7-a32829096032 내용: 존은 한 시간 동안 시속 80킬로미터로 트럭을 운전했습니다. 그 다음 시간에는 시속 100킬로미터로 운전했습니다. 이렇게 두 시간 동안 그의 평균 속도를 계산해보면, (80 + 100) / 2 = 90킬로미터가 됩니다. 따라서, 존의 평균 속도는 시속 90킬로미터입니다.
# 문서 ID: 9ec9317d-7663-4ae2-b5e7-8c38ccfa348e 내용: 가젤은 2 km의 거리를 반 시간 동안 이동했습니다. 이동한 거리를 시간으로 나누면 평균 속도를 구할 수 있습니다. 따라서 가젤의 평균 속도는 4 km/h입니다. 가젤은 빠른 동물 중 하나로 알려져 있으며, 이번에도 그 빠른 속도를 보여주었습니다.
# ============================================================
# bm25_faiss_73 결과:
# 문서 ID: e8d07278-c590-43e2-b99a-47d5adaf123d 내용: 아르투로는 3,000미터 경주에서 10분이라는 기록으로 결승점에 도달했습니다. 이를 통해 우리는 아르투로의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 걸린 시간으로 나눈 값입니다. 따라서, 아르투로의 평균 속도는 3,000미터를 10분으로 나눈 값인 300미터/분입니다. 이를 미터/초로 변환하면 5 m/s가 됩니다. 따라서, 아르투로의 평균 속도는 5 m/s입니다.
# 문서 ID: 8ca2ebf5-9f0d-4d2f-bfef-92b44c920d2e 내용: 고무 오리 경주에서 우승한 오리는 10분 동안 300미터를 이동했습니다. 이를 통해 우승한 오리의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 소요된 시간으로 나눈 값입니다. 따라서, 이 경우 오리의 평균 속도는 300미터를 10분으로 나눈 값인 30미터/분입니다. 그러나, 문제에서 속도를 미터/초로 표현하라고 하였으므로, 분 단위를 초 단위로 변환해야 합니다. 1분은 60초이므로, 30미터/분은 0.5미터/초입니다. 따라서, 고무 오리 경주에서 우승한 오리의 평균 속도는 0.5미터/초입니다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: fe6a254b-0f86-4025-b867-b35d56273c8d 내용: 안나는 20초 동안 100미터를 달렸습니다. 이는 안나의 평균 속도가 5 m/s라는 것을 의미합니다. 안나는 매 초마다 5미터를 달렸으며, 이는 안나가 얼마나 빠르게 달렸는지를 나타냅니다. 평균 속도는 달린 거리를 시간으로 나눈 값으로 계산됩니다. 따라서 안나는 초당 5미터를 달린 것입니다. 이러한 평균 속도는 안나가 얼마나 빠르게 달렸는지를 측정하는 중요한 지표입니다.
# 문서 ID: e0588d15-873f-4b61-8ca1-994cbacc33bc 내용: 두 사람이 시속 20킬로미터(km/h)로 자전거를 타고 있었습니다. 그들은 30분 동안 속도가 시속 26킬로미터로 증가했다는 것을 관찰했습니다. 이들의 평균 가속도는 12.0km/h^2입니다. 가속도는 속도의 변화량을 시간으로 나눈 값으로 정의됩니다. 이 경우, 속도의 변화량은 26km/h - 20km/h = 6km/h이고, 시간은 30분 = 0.5시간입니다. 따라서, 평균 가속도는 6km/h / 0.5시간 = 12.0km/h^2입니다. 이는 두 사람이 자전거를 타는 동안 속도가 시속 12.0km/h씩 증가했다는 것을 의미합니다.
# 문서 ID: 5d48fa4e-1999-45dc-b768-b15b30a87cc5 내용: 한 대의 버스가 두 도시 간 280 킬로미터를 이동했습니다. 이 버스는 첫 번째 도시를 오후 3시에 출발하여 두 번째 도시에 오후 7시에 도착했습니다. 따라서, 이 버스의 이동에 걸린 시간은 4시간입니다. 이를 토대로 버스의 평균 속도를 계산해보면, 280 킬로미터를 4시간 동안 이동했으므로, 평균 속도는 70 km/h입니다. 따라서, 이 버스의 평균 속도는 70 km/h입니다.
# 문서 ID: c58ab6ec-4b3c-4561-96e7-a32829096032 내용: 존은 한 시간 동안 시속 80킬로미터로 트럭을 운전했습니다. 그 다음 시간에는 시속 100킬로미터로 운전했습니다. 이렇게 두 시간 동안 그의 평균 속도를 계산해보면, (80 + 100) / 2 = 90킬로미터가 됩니다. 따라서, 존의 평균 속도는 시속 90킬로미터입니다.
# 문서 ID: 9ec9317d-7663-4ae2-b5e7-8c38ccfa348e 내용: 가젤은 2 km의 거리를 반 시간 동안 이동했습니다. 이동한 거리를 시간으로 나누면 평균 속도를 구할 수 있습니다. 따라서 가젤의 평균 속도는 4 km/h입니다. 가젤은 빠른 동물 중 하나로 알려져 있으며, 이번에도 그 빠른 속도를 보여주었습니다.
# ============================================================
# bm25_faiss_37 결과:
# 문서 ID: e0588d15-873f-4b61-8ca1-994cbacc33bc 내용: 두 사람이 시속 20킬로미터(km/h)로 자전거를 타고 있었습니다. 그들은 30분 동안 속도가 시속 26킬로미터로 증가했다는 것을 관찰했습니다. 이들의 평균 가속도는 12.0km/h^2입니다. 가속도는 속도의 변화량을 시간으로 나눈 값으로 정의됩니다. 이 경우, 속도의 변화량은 26km/h - 20km/h = 6km/h이고, 시간은 30분 = 0.5시간입니다. 따라서, 평균 가속도는 6km/h / 0.5시간 = 12.0km/h^2입니다. 이는 두 사람이 자전거를 타는 동안 속도가 시속 12.0km/h씩 증가했다는 것을 의미합니다.
# 문서 ID: 5d48fa4e-1999-45dc-b768-b15b30a87cc5 내용: 한 대의 버스가 두 도시 간 280 킬로미터를 이동했습니다. 이 버스는 첫 번째 도시를 오후 3시에 출발하여 두 번째 도시에 오후 7시에 도착했습니다. 따라서, 이 버스의 이동에 걸린 시간은 4시간입니다. 이를 토대로 버스의 평균 속도를 계산해보면, 280 킬로미터를 4시간 동안 이동했으므로, 평균 속도는 70 km/h입니다. 따라서, 이 버스의 평균 속도는 70 km/h입니다.
# 문서 ID: c58ab6ec-4b3c-4561-96e7-a32829096032 내용: 존은 한 시간 동안 시속 80킬로미터로 트럭을 운전했습니다. 그 다음 시간에는 시속 100킬로미터로 운전했습니다. 이렇게 두 시간 동안 그의 평균 속도를 계산해보면, (80 + 100) / 2 = 90킬로미터가 됩니다. 따라서, 존의 평균 속도는 시속 90킬로미터입니다.
# 문서 ID: 9ec9317d-7663-4ae2-b5e7-8c38ccfa348e 내용: 가젤은 2 km의 거리를 반 시간 동안 이동했습니다. 이동한 거리를 시간으로 나누면 평균 속도를 구할 수 있습니다. 따라서 가젤의 평균 속도는 4 km/h입니다. 가젤은 빠른 동물 중 하나로 알려져 있으며, 이번에도 그 빠른 속도를 보여주었습니다.
# 문서 ID: e8d07278-c590-43e2-b99a-47d5adaf123d 내용: 아르투로는 3,000미터 경주에서 10분이라는 기록으로 결승점에 도달했습니다. 이를 통해 우리는 아르투로의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 걸린 시간으로 나눈 값입니다. 따라서, 아르투로의 평균 속도는 3,000미터를 10분으로 나눈 값인 300미터/분입니다. 이를 미터/초로 변환하면 5 m/s가 됩니다. 따라서, 아르투로의 평균 속도는 5 m/s입니다.
# 문서 ID: 8ca2ebf5-9f0d-4d2f-bfef-92b44c920d2e 내용: 고무 오리 경주에서 우승한 오리는 10분 동안 300미터를 이동했습니다. 이를 통해 우승한 오리의 평균 속도를 계산할 수 있습니다. 평균 속도는 이동한 거리를 이동에 소요된 시간으로 나눈 값입니다. 따라서, 이 경우 오리의 평균 속도는 300미터를 10분으로 나눈 값인 30미터/분입니다. 그러나, 문제에서 속도를 미터/초로 표현하라고 하였으므로, 분 단위를 초 단위로 변환해야 합니다. 1분은 60초이므로, 30미터/분은 0.5미터/초입니다. 따라서, 고무 오리 경주에서 우승한 오리의 평균 속도는 0.5미터/초입니다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: fe6a254b-0f86-4025-b867-b35d56273c8d 내용: 안나는 20초 동안 100미터를 달렸습니다. 이는 안나의 평균 속도가 5 m/s라는 것을 의미합니다. 안나는 매 초마다 5미터를 달렸으며, 이는 안나가 얼마나 빠르게 달렸는지를 나타냅니다. 평균 속도는 달린 거리를 시간으로 나눈 값으로 계산됩니다. 따라서 안나는 초당 5미터를 달린 것입니다. 이러한 평균 속도는 안나가 얼마나 빠르게 달렸는지를 측정하는 중요한 지표입니다.
# ============================================================
# kiwi_bm25_faiss_73 결과:
# 문서 ID: 74770db8-9c70-4f2b-a699-b2b63e24f1a8 내용: 두 우주선이 지구에 동일한 속도로 접근하고 있다. 이는 지구에 있는 관찰자가 측정한 것이다. 하지만 두 우주선은 서로 반대 방향에서 접근하고 있다. 한 우주선에 있는 미터자가 다른 우주선의 승객에 의해 60 cm로 측정되었다. 이는 상대성 이론에 따라 두 우주선의 속도가 서로 다르게 측정되는 것을 의미한다. 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산하기 위해서는 상대성 이론의 공식을 사용해야 한다. 상대성 이론에 따르면, 두 우주선의 속도는 다음과 같이 계산할 수 있다. 두 우주선의 속도를 각각 v1, v2라고 하면, v1 + v2 = 2v, v1 - v2 = 60 cm/c. 이를 풀어서 계산하면, v1 = v + 30 cm/c, v2 = v - 30 cm/c이다. 따라서, 두 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산해보면, v1 + v2 = 2v = 60 cm/c, v = 30 cm/c이다. 따라서, 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 0.5c이다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: 14c8ba1a-e650-47bb-b34b-6e81373cf96b 내용: 과학적 연구를 통해 결정될 가능성이 가장 큰 질문은 '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'입니다. 토마토는 식물이므로 광합성을 통해 에너지를 생산하는데, 이를 위해서는 충분한 양의 빛이 필요합니다. 그러나 토마토가 필요로 하는 빛의 양은 다른 식물과 다를 수 있으며, 이를 알아내기 위해서는 과학적 연구가 필요합니다. 과학자들은 토마토의 광합성 작용에 영향을 미치는 다양한 요인들을 연구하고 있으며, 이를 통해 토마토를 최적으로 키우기 위한 빛의 양을 결정하고자 합니다. 이 연구를 통해 농작물 생산성을 향상시키고, 더 많은 사람들에게 안정적인 식량을 공급할 수 있을 것으로 기대됩니다. 따라서, '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'라는 질문은 과학적 연구를 통해 결정될 가능성이 가장 큰 질문 중 하나입니다.
# 문서 ID: 154e2f2e-4731-4aec-ae10-9d9e685cd055 내용: 리카르도는 저울에서 빈 눈금 실린더를 측정했습니다. 그런 다음 눈금 실린더에 50mL의 액체를 채워 다시 측정했습니다. 이 과정에서 리카르도는 액체의 질량을 알고 싶어했습니다. 액체의 질량을 측정하기 위해 리카르도는 저울을 사용했습니다. 저울은 물체의 질량을 측정하는 도구로, 물체의 무게를 알려줍니다. 리카르도는 눈금 실린더에 액체를 채워 측정한 결과를 통해 액체의 질량을 알아낼 수 있었습니다. 이러한 실험을 통해 리카르도는 액체의 질량이 얼마인지 알아낼 수 있었습니다. 따라서 리카르도가 답변을 얻으려는 질문으로 가장 가능성이 높은 것은 '액체의 질량은 얼마인가?'입니다.
# 문서 ID: e0588d15-873f-4b61-8ca1-994cbacc33bc 내용: 두 사람이 시속 20킬로미터(km/h)로 자전거를 타고 있었습니다. 그들은 30분 동안 속도가 시속 26킬로미터로 증가했다는 것을 관찰했습니다. 이들의 평균 가속도는 12.0km/h^2입니다. 가속도는 속도의 변화량을 시간으로 나눈 값으로 정의됩니다. 이 경우, 속도의 변화량은 26km/h - 20km/h = 6km/h이고, 시간은 30분 = 0.5시간입니다. 따라서, 평균 가속도는 6km/h / 0.5시간 = 12.0km/h^2입니다. 이는 두 사람이 자전거를 타는 동안 속도가 시속 12.0km/h씩 증가했다는 것을 의미합니다.
# 문서 ID: 5d48fa4e-1999-45dc-b768-b15b30a87cc5 내용: 한 대의 버스가 두 도시 간 280 킬로미터를 이동했습니다. 이 버스는 첫 번째 도시를 오후 3시에 출발하여 두 번째 도시에 오후 7시에 도착했습니다. 따라서, 이 버스의 이동에 걸린 시간은 4시간입니다. 이를 토대로 버스의 평균 속도를 계산해보면, 280 킬로미터를 4시간 동안 이동했으므로, 평균 속도는 70 km/h입니다. 따라서, 이 버스의 평균 속도는 70 km/h입니다.
# 문서 ID: c58ab6ec-4b3c-4561-96e7-a32829096032 내용: 존은 한 시간 동안 시속 80킬로미터로 트럭을 운전했습니다. 그 다음 시간에는 시속 100킬로미터로 운전했습니다. 이렇게 두 시간 동안 그의 평균 속도를 계산해보면, (80 + 100) / 2 = 90킬로미터가 됩니다. 따라서, 존의 평균 속도는 시속 90킬로미터입니다.
# 문서 ID: 9ec9317d-7663-4ae2-b5e7-8c38ccfa348e 내용: 가젤은 2 km의 거리를 반 시간 동안 이동했습니다. 이동한 거리를 시간으로 나누면 평균 속도를 구할 수 있습니다. 따라서 가젤의 평균 속도는 4 km/h입니다. 가젤은 빠른 동물 중 하나로 알려져 있으며, 이번에도 그 빠른 속도를 보여주었습니다.
# ============================================================
# kiwi_bm25_faiss_37 결과:
# 문서 ID: e0588d15-873f-4b61-8ca1-994cbacc33bc 내용: 두 사람이 시속 20킬로미터(km/h)로 자전거를 타고 있었습니다. 그들은 30분 동안 속도가 시속 26킬로미터로 증가했다는 것을 관찰했습니다. 이들의 평균 가속도는 12.0km/h^2입니다. 가속도는 속도의 변화량을 시간으로 나눈 값으로 정의됩니다. 이 경우, 속도의 변화량은 26km/h - 20km/h = 6km/h이고, 시간은 30분 = 0.5시간입니다. 따라서, 평균 가속도는 6km/h / 0.5시간 = 12.0km/h^2입니다. 이는 두 사람이 자전거를 타는 동안 속도가 시속 12.0km/h씩 증가했다는 것을 의미합니다.
# 문서 ID: 5d48fa4e-1999-45dc-b768-b15b30a87cc5 내용: 한 대의 버스가 두 도시 간 280 킬로미터를 이동했습니다. 이 버스는 첫 번째 도시를 오후 3시에 출발하여 두 번째 도시에 오후 7시에 도착했습니다. 따라서, 이 버스의 이동에 걸린 시간은 4시간입니다. 이를 토대로 버스의 평균 속도를 계산해보면, 280 킬로미터를 4시간 동안 이동했으므로, 평균 속도는 70 km/h입니다. 따라서, 이 버스의 평균 속도는 70 km/h입니다.
# 문서 ID: c58ab6ec-4b3c-4561-96e7-a32829096032 내용: 존은 한 시간 동안 시속 80킬로미터로 트럭을 운전했습니다. 그 다음 시간에는 시속 100킬로미터로 운전했습니다. 이렇게 두 시간 동안 그의 평균 속도를 계산해보면, (80 + 100) / 2 = 90킬로미터가 됩니다. 따라서, 존의 평균 속도는 시속 90킬로미터입니다.
# 문서 ID: 9ec9317d-7663-4ae2-b5e7-8c38ccfa348e 내용: 가젤은 2 km의 거리를 반 시간 동안 이동했습니다. 이동한 거리를 시간으로 나누면 평균 속도를 구할 수 있습니다. 따라서 가젤의 평균 속도는 4 km/h입니다. 가젤은 빠른 동물 중 하나로 알려져 있으며, 이번에도 그 빠른 속도를 보여주었습니다.
# 문서 ID: 74770db8-9c70-4f2b-a699-b2b63e24f1a8 내용: 두 우주선이 지구에 동일한 속도로 접근하고 있다. 이는 지구에 있는 관찰자가 측정한 것이다. 하지만 두 우주선은 서로 반대 방향에서 접근하고 있다. 한 우주선에 있는 미터자가 다른 우주선의 승객에 의해 60 cm로 측정되었다. 이는 상대성 이론에 따라 두 우주선의 속도가 서로 다르게 측정되는 것을 의미한다. 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산하기 위해서는 상대성 이론의 공식을 사용해야 한다. 상대성 이론에 따르면, 두 우주선의 속도는 다음과 같이 계산할 수 있다. 두 우주선의 속도를 각각 v1, v2라고 하면, v1 + v2 = 2v, v1 - v2 = 60 cm/c. 이를 풀어서 계산하면, v1 = v + 30 cm/c, v2 = v - 30 cm/c이다. 따라서, 두 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 얼마인가? 이를 계산해보면, v1 + v2 = 2v = 60 cm/c, v = 30 cm/c이다. 따라서, 각 우주선의 속도는 지구에 있는 관찰자가 측정했을 때 0.5c이다.
# 문서 ID: 525f7b96-8422-4e57-b54b-32aff1d42aed 내용: 학생들은 학교 운동장에서 거북이를 관찰하였습니다. 그들은 거북이가 30분 동안 이동한 거리를 측정하였습니다. 거북이가 이 시간 동안 40미터를 걸었다면, 평균 속도는 얼마였을까요? 이 문제를 풀기 위해서는 거리를 시간으로 나누어야 합니다. 따라서, 거북이의 평균 속도는 40미터를 30분으로 나눈 값인 1.33m/min입니다. 그러나, 답안에서는 속도를 시간당 단위로 표기하였습니다. 따라서, 거북이의 평균 속도는 1.33m/min을 시간당 단위로 변환한 80m/h입니다.
# 문서 ID: 14c8ba1a-e650-47bb-b34b-6e81373cf96b 내용: 과학적 연구를 통해 결정될 가능성이 가장 큰 질문은 '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'입니다. 토마토는 식물이므로 광합성을 통해 에너지를 생산하는데, 이를 위해서는 충분한 양의 빛이 필요합니다. 그러나 토마토가 필요로 하는 빛의 양은 다른 식물과 다를 수 있으며, 이를 알아내기 위해서는 과학적 연구가 필요합니다. 과학자들은 토마토의 광합성 작용에 영향을 미치는 다양한 요인들을 연구하고 있으며, 이를 통해 토마토를 최적으로 키우기 위한 빛의 양을 결정하고자 합니다. 이 연구를 통해 농작물 생산성을 향상시키고, 더 많은 사람들에게 안정적인 식량을 공급할 수 있을 것으로 기대됩니다. 따라서, '토마토를 키우는 데 필요한 빛의 양은 얼마인가?'라는 질문은 과학적 연구를 통해 결정될 가능성이 가장 큰 질문 중 하나입니다.
# 문서 ID: 154e2f2e-4731-4aec-ae10-9d9e685cd055 내용: 리카르도는 저울에서 빈 눈금 실린더를 측정했습니다. 그런 다음 눈금 실린더에 50mL의 액체를 채워 다시 측정했습니다. 이 과정에서 리카르도는 액체의 질량을 알고 싶어했습니다. 액체의 질량을 측정하기 위해 리카르도는 저울을 사용했습니다. 저울은 물체의 질량을 측정하는 도구로, 물체의 무게를 알려줍니다. 리카르도는 눈금 실린더에 액체를 채워 측정한 결과를 통해 액체의 질량을 알아낼 수 있었습니다. 이러한 실험을 통해 리카르도는 액체의 질량이 얼마인지 알아낼 수 있었습니다. 따라서 리카르도가 답변을 얻으려는 질문으로 가장 가능성이 높은 것은 '액체의 질량은 얼마인가?'입니다.
# ============================================================
# None
