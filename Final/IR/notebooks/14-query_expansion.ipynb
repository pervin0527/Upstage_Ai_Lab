# %%
import os
import re
import json
import faiss
import warnings
import huggingface_hub

from openai import OpenAI

from langchain.schema import Document
from langchain_community.vectorstores.faiss import FAISS

from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings
from langchain_upstage import UpstageEmbeddings
from langchain.retrievers import ContextualCompressionRetriever
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain.retrievers.document_compressors import CrossEncoderReranker


os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore", category=FutureWarning)

from dotenv import load_dotenv
load_dotenv("../keys.env")

upstage_api_key = os.getenv("UPSTAGE_API_KEY")
os.environ['UPSTAGE_API_KEY'] = upstage_api_key

openai_api_key = os.getenv('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = openai_api_key

hf_token = os.getenv("HF_TOKEN")
huggingface_hub.login(hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/pervinco/.cache/huggingface/token
# Login successful

# %%
client = OpenAI()
model = "gpt-4o"

# client = OpenAI(
#     api_key=upstage_api_key,
#     base_url="https://api.upstage.ai/v1/solar"
# )
# model = "solar-pro"

# %%
def clean_json_response(response):
    # 코드 블록(예: ```json, ```) 제거
    cleaned_response = re.sub(r'```(?:json)?', '', response).strip()
    
    return cleaned_response

def query_expansion(query, model:str, client:OpenAI):
    content = (
        "당신은 한국어 질의를 분석하고, 정보검색에 최적화된 더 구체적이고 자연스러운 질의를 만들어내는 전문가입니다. "
        "사용자의 질문 의도를 명확히 파악하고, 그 의도를 유지하면서 검색 시스템이 관련 문서를 더 잘 찾을 수 있도록 질의를 확장하세요. "
        "확장된 질의는 반드시 사용자의 본래 의도를 반영해야 하며, 새로운 정보나 본래 질의에 포함되지 않은 세부 정보(예: 국가, 인물, 특정 사건 등)를 임의로 추가하지 마세요. "
        "오직 사용자가 제공한 정보만을 바탕으로 질의를 확장하고, 검색에 필수적인 정보만 포함하도록 하세요. "
        "또한, 확장된 질의는 자연스러운 문장 형태로 제공되어야 합니다. "
        "반환하는 형식은 반드시 JSON 포맷이어야 하며, 모든 문자열은 쌍따옴표로 감싸야 합니다. "
        '{ "query": "확장된 자연스러운 질의" }.'
    )


    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role" : "system", "content" : content},
            {"role" : "user", "content" : query}
        ],
    )
    
    response = completion.choices[0].message.content
    response = clean_json_response(response)
    
    try:
        json_response = json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Invalid JSON response", "response": response}
    
    return json_response

# %%
def load_jsonl(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [json.loads(line) for line in f]

def load_query(query_path, model, client, output_path):
    queries = load_jsonl(query_path)
    expanded_queries = []

    for query_data in queries:
        eval_id = query_data['eval_id']
        msg_history = query_data['msg']
        
        conversation_history = " ".join([msg['content'] for msg in msg_history if msg['role'] == 'user'])
        
        expanded_query_result = query_expansion(conversation_history, model, client)
        print(eval_id)
        print(conversation_history)
        print(expanded_query_result['query'], '\n')
        
        expanded_queries.append({
            "eval_id": eval_id,
            "original_conversation": conversation_history,
            "expanded_query": expanded_query_result.get('query', 'Expansion failed')
        })
    
    # Save expanded queries to a jsonl file
    with open(output_path, 'w', encoding='utf-8') as f:
        for query in expanded_queries:
            json.dump(query, f, ensure_ascii=False)
            f.write('\n')

# %%
load_query("../dataset/eval.jsonl", model, client, "../dataset/expanded_query.jsonl")
# Out:
# 78
# 나무의 분류에 대해 조사해 보기 위한 방법은?
# 나무 분류 방법 조사하기 위한 자료나 정보 찾기
#
# 213
# 각 나라에서의 공교육 지출 현황에 대해 알려줘.
# 세계 각국의 공교육 지출 수준과 현황에 대한 정보를 알려주세요.
#
# 107
# 기억 상실증 걸리면 너무 무섭겠다. 어떤 원인 때문에 발생하는지 궁금해.
# 기억 상실증의 발생 원인에는 어떤 것들이 있는지 궁금하다.
#
# 81
# 통학 버스의 가치에 대해 말해줘.
# 통학 버스가 학생들에게 제공하는 가치와 장점에 대해 설명해줘.
#
# 280
# Dmitri Ivanovsky가 누구야?
# 바이러스 연구의 선구자인 Dmitri Ivanovsky에 대한 정보와 그의 업적
#
# 10
# 피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?
# 피임을 위한 방법 중 약물 사용의 효과성과 장점 및 단점은 무엇인가?
#
# 100
# 헬륨이 다른 원소들과 반응을 잘 안하는 이유는?
# 헬륨이 다른 원소들과 반응을 잘 하지 않는 이유, 화학적 성질과 원자 구조를 중심으로 설명
#
# 279
# 문맹 비율이 사회 발전에 미치는 영향은?
# 문맹 비율이 사회 발전에 어떤 영향을 미치는지에 대한 연구와 사례는 무엇인가?
#
# 42
# 이란 콘트라 사건이 뭐야 이 사건이 미국 정치에 미친 영향은?
# 이란 콘트라 사건이란 무엇인지 설명과 이 사건이 미국 정치에 미친 영향은 무엇인지 대한 정보
#
# 308
# 자기장이 얼마나 센지 표현하는 방식은?
# 자기장의 세기를 표현하는 방식과 단위는 무엇인가?
#
# 205
# 피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?
# 피를 맑게 하고 몸 속의 노폐물을 제거하는 역할을 하는 인체 기관은 무엇인가?
#
# 289
# 글리코겐의 분해는 인체에서 왜 필요한가?
# 인체에서 글리코겐의 분해가 필요한 이유와 그 중요성은 무엇인가?
#
# 268
# 빗방울이 점점 커지게 되는 요인은?
# 빗방울이 점점 커지는 이유와 관련된 요인에는 어떤 것들이 있을까?
#
# 18
# 기체의 부피나 형태가 왜 일정하지 않을까?
# 왜 기체의 부피나 형태가 일정하지 않은지에 대한 이유와 원리에 대해 설명해주세요.
#
# 9
# 식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘.
# 식물이 광합성을 통해 빛을 에너지로 변환하는 과정은 어떻게 이루어지나요?
#
# 101
# 직류와 교류 전류의 차이에 대해 알려줘.
# 직류 전류와 교류 전류의 차이점, 예시와 특징 비교
#
# 236
# 기름과 물이 섞여 있을 수 있나?
# 기름과 물이 혼합될 수 있는지와 그 이유에 대한 설명
#
# 59
# 인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘.
# 인간이 2세를 생산할 때 생식세포 형성과 수정 과정에서 DNA의 결합 과정 및 그 메커니즘에 대해 설명해줘.
#
# 25
# 금성에서 달이 어떻게 보일까?
# 금성에서 바라본 달의 모습과 위치는 어떻게 보일까?
#
# 5
# 차량의 연비가 좋아질때 나타나는 긍정적인 효과는?
# 차량 연비 개선으로 인한 긍정적인 효과는 무엇인가요?
#
# 104
# 혼합물의 특성에 대해 알려줘.
# 혼합물의 특성에 대한 자세한 설명과 특징
#
# 276
# 요새 너무 힘들다.
# 요즘 많이 힘든데 어떻게 하면 스트레스를 관리할 수 있는지에 대한 방법을 알고 싶습니다.
#
# 14
# 세제의 거품이 만들어지는 원리는?
# 세제가 거품을 형성하는 화학적 원리 및 메커니즘은 무엇인가?
#
# 270
# 나무가 생태계에서 하는 역할에 대해 설명해줘.
# 나무가 생태계 내에서 수행하는 다양한 역할에 대해 설명해줘, 예를 들어 공기 정화, 서식지 제공, 토양 보호 등의 기능을 포함해서
#
# 238
# 전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?
# 전류의 흐름을 극대화하기 위한 배터리와 저항의 연결 방법을 설명해주세요.
#
# 269
# 식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해.
# 식물이 높이 자라는 메커니즘과 관련된 과학적 원리나 과정은 무엇인지 알려줘. 예를 들어, 식물의 호르몬 작용, 빛과의 관계, 물의 역할 등이 포함될 수 있다.
#
# 43
# 달을 보면 항상 같은 면만 보이더라구 그 이유가 뭐야?
# 달의 같은 면만 지구에서 보이는 이유는 무엇인가?
#
# 65
# 식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?
# 식초와 베이킹 소다를 섞을 때 발생하는 화학 반응과 그로 인한 결과는 무엇인가?
#
# 97
# 세균이 나쁜줄말 알았는데 그게 아니야? 그럼 순기능에 대해 알려줄래?
# 세균의 유익한 기능과 순기능에 대해 알려주세요.
#
# 206
# 오토마톤의 특징에 대해 알려줘.
# 오토마톤의 주요 특징과 특성에 대해 설명해 주세요.
#
# 21
# 다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘.
# 다양한 책을 카탈로그화하기 위한 파이썬 클래스 정의 방법과 코드 작성 방법에 대해 알아보세요.
#
# 221
# 전구가 병렬로 연결될 때 전류가 줄어드는 원인은?
# 전구가 병렬로 연결될 때 전체 전류는 어떻게 되며, 전류가 개별 전구를 통해 흐르는 방식과 줄어드는 원인을 이해하려면 어떻게 해야 하나요?
#
# 71
# 물속에서 침전이 발생하는 원리에 대해 알려줘.
# 물속에서 침전이 발생하는 원리와 그 과정에 대해 설명해주세요.
#
# 254
# 화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?
# 화산 폭발 후 새로운 생물 군집 형성을 의미하는 용어는 무엇인가?
#
# 226
# 축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?
# 축전기를 병렬로 연결하면 전체 전기 용량은 어떻게 변하는가?
#
# 241
# 정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?
# 정육면체가 물에 뜰 때 수면 위에 노출된 부피를 계산하는 방법
#
# 261
# 니가 대답을 잘해줘서 너무 신나!
# 대답을 잘해줘서 기분이 좋을 때의 감정 표현 방법
#
# 45
# 건설 현장에서 망치로 벽을 치는 이유는?
# 건설 현장에서 작업자가 벽을 망치로 치는 이유와 그 목적은 무엇인가?
#
# 19
# 차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?
# 차량에서 매연이 발생하지 않도록 하는 장치의 이름은 무엇입니까?
#
# 210
# python에서 lambda 함수를 언제 사용할 수 있어?
# Python에서 lambda 함수를 사용해야 하는 경우와 그 용도는 무엇인가요?
#
# 231
# 강이나 바다의 물이 증발하는 가장 중요한 원인은?
# 강이나 바다의 물이 증발하는 주요한 원인은 무엇인가요?
#
# 233
# 남녀 관계에서 정서적인 행동이 왜 중요해?
# 남녀 관계에서 정서적인 행동의 중요성에 대한 이유와 역할
#
# 263
# DNA 조각들이 서로 결합되도록 돕는 것은?
# DNA 조각들이 서로 결합되도록 돕는 효소는 무엇인가?
#
# 201
# 해가 뜨는 현상이 지구의 자전과 관련있어?
# 해가 뜨는 현상이 지구의 자전과 어떻게 관련이 있는지 설명
#
# 293
# 두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?
# 두 물질이 다른 분자 구조나 화학적 성분으로 구성되어 있는지 확인하는 방법은 무엇인가요?
#
# 208
# 수성이 뜨거운 이유는?
# 수성이 뜨거운 이유와 관련된 과학적 원인에 대해 설명해주세요.
#
# 282
# 하구 퇴적지의 기능에 대해 알려줘.
# 하구 퇴적지의 기능과 역할은 무엇인가요?
#
# 62
# 디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?
# 디엔에이에서 퓨린과 피리미딘의 비율은 어떻게 되는가?
#
# 55
# interferon의 역할에 대해 알려줘.
# interferon의 생물학적 역할과 기능에 대해 설명해줘.
#
# 257
# 하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?
# 하나의 유전자에서 왜 여러 가지 단백질이 생성될 수 있는지에 대한 원인과 기전
#
# 58
# 질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?
# 질산을 사용하여 염화물에서 염소를 침전시킬 때, 염소의 비율을 계산하는 방법은 무엇인가요?
#
# 283
# 이제 그만 얘기해!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 load_query("../dataset/eval.jsonl", model, client, "../dataset/expanded_query.jsonl")
#
# Cell In[4], line 18, in load_query(query_path, model, client, output_path)
#      16     print(eval_id)
#      17     print(conversation_history)
# ---> 18     print(expanded_query_result['query'], '\n')
#      20     expanded_queries.append({
#      21         "eval_id": eval_id,
#      22         "original_conversation": conversation_history,
#      23         "expanded_query": expanded_query_result.get('query', 'Expansion failed')
#      24     })
#      26 # Save expanded queries to a jsonl file
#
# KeyError: 'query'
