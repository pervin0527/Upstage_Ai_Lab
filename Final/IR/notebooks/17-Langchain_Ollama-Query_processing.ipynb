# %% [markdown]
# ## Reference
#
# [https://python.langchain.com/docs/integrations/chat/ollama/](https://python.langchain.com/docs/integrations/chat/ollama/)

# %%
import json

from langchain_community.chat_models import ChatOllama

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.callbacks.manager import CallbackManager
from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
def load_jsonl(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [json.loads(line) for line in f]
    
def get_chat_history(eval_data):
    str_chat_history = []
    for msg in eval_data['msg']:
        str_chat_history.append(f"{msg['role']} : {msg['content']}")

    return '\n'.join(str_chat_history)

# %%
eval_file = "../dataset/eval.jsonl"
eval_dataset = load_jsonl(eval_file)

# %%
model = ChatOllama(model="eeve-10.8b-q8:latest")

# %%
prompt_context1 = (
    "주어진 '대화내용'을 정리해서 '하나의 질문을 생성'해주세요.\n"

    "예제 입력\n"
    "'user : 기억 상실증 걸리면 너무 무섭겠다.\n' 'assistant : 네 맞습니다.\n' 'user : 어떤 원인 때문에 발생하는지 궁금해.\n'"
    "예제 출력\n"
    "'기억 상실증에 걸리는 원인은 무엇인가요?'"

    "대화내용 : {chat_history}\n\n"

    "답변:"
)

prompt1 = ChatPromptTemplate.from_template(prompt_context1)
chain1 = prompt1 | model | StrOutputParser()

# %%
prompt_context2 = (
    # "주어진 질문이 '상식'을 물어보는 것인지 판단하세요.\n"
    "주어진 질문이 일반적인 지식이나 사실에 대한 질문인지 판단하세요.\n"

    "만약 개인적인 감정, 의견, 일상 대화처럼 질문이 상식을 묻는 질문이 아닌 경우 False를, 상식을 묻는 질문이 맞다면 True를 반환하세요.\n"
    "당신의 답변은 반드시 True 또는 False로만 구성되어야 하며, 다른 문장은 생성하지 않아야 합니다.\n"

    "예제 입력1\n"
    "평형분극비율이 뭐야?\n"
    "예제 출력1\n"
    "True\n"

    "예제 입력2\n"
    "다음 세대의 꽃 색깔은 무엇인가요?\n"
    "예제 출력2\n"
    "True\n"

    "예제 입력3\n"
    "요새 너무 힘드네..\n"
    "예제 출력3\n"
    "False\n"

    "예제 입력4\n"
    "너 모르는 것도 있어?\n"
    "예제 출력4\n"
    "False\n"

    "예제 입력5\n"
    "니가 대답을 잘해줘서 너무 신나!\n"
    "예제 출력5\n"
    "False\n"


    "예제 입력6\n"
    "우울한데 신나는 얘기 좀 해줘!\n"
    "예제 출력6\n"
    "False\n"

    "예제 입력7\n"
    "너는 누구야?\n"
    "예제 출력7\n"
    "False\n"

    "예제 입력8\n"
    "너 잘하는게 뭐야?\n"
    "예제 출력8\n"
    "False\n"

    "질문 : {query}\n\n"

    "답변:"
)

prompt2 = ChatPromptTemplate.from_template(prompt_context2)
chain2 = prompt2 | model | StrOutputParser()

# %%
data1 = eval_dataset[0]
print(data1['msg'])

sample1 = get_chat_history(data1)
print(sample1)
# Out:
# [{'role': 'user', 'content': '나무의 분류에 대해 조사해 보기 위한 방법은?'}]
# user : 나무의 분류에 대해 조사해 보기 위한 방법은?

# %%
data2 = eval_dataset[8]
print(data2['msg'])

sample2 = get_chat_history(data2)
print(sample2)
# Out:
# [{'role': 'user', 'content': '이란 콘트라 사건이 뭐야'}, {'role': 'assistant', 'content': '이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.'}, {'role': 'user', 'content': '이 사건이 미국 정치에 미친 영향은?'}]
# user : 이란 콘트라 사건이 뭐야
# assistant : 이란-콘트라 사건은 로널드 레이건 집권기인 1986년에 레이건 행정부와 CIA가 적성국이었던 이란에게 무기를 몰래 수출한 대금으로 니카라과의 우익 성향 반군 콘트라를 지원하면서 동시에 반군으로부터 마약을 사들인 후 미국에 판매하다가 발각되어 큰 파장을 일으킨 사건입니다.
# user : 이 사건이 미국 정치에 미친 영향은?

# %%
gen_result1 = chain1.invoke({"chat_history" : sample1})

print()
print(gen_result1)
# Out:
# 나무의 분류를 연구하기 위해 사용할 수 있는 방법에는 어떤 것들이 있나요?
# 나무의 분류를 연구하기 위해 사용할 수 있는 방법에는 어떤 것들이 있나요?

# %%
gen_result2 = chain1.invoke({"chat_history" : sample2})

print()
print(gen_result2)
# Out:
# 이란-콘트라 사건이 미국 정치에 어떤 영향을 미쳤습니까?
# 이란-콘트라 사건이 미국 정치에 어떤 영향을 미쳤습니까?

# %%
# 초기화
num_correct = 0  # 모델이 정답으로 판단한 횟수
total = 0        # 전체 데이터 수
false_count = 0  # 모델이 False로 판단한 횟수
incorrect_examples = []  # 모델이 틀린 예시를 저장할 리스트

out_query_list = [276, 261, 283, 32, 94, 90, 220, 245, 229, 247, 67, 57, 2, 227, 301, 222, 83, 64, 103, 218]

for idx, eval_data in enumerate(eval_dataset):
    eval_id = eval_data['eval_id']
    chat_len = len(eval_data['msg'])
    chats = get_chat_history(eval_data)
    
    if chat_len > 1:
        query = chain1.invoke({"chat_history": chats})
        _ = query
    else:
        query = chats.split(':')[1].strip()
    
    check = chain2.invoke({"query": query})
    print(f"eval_id: {eval_id}, query: {query}, model_output: {check}\n")
    
    # 기대되는 정답 설정
    expected_check = 'False' if eval_id in out_query_list else 'True'
    
    # 모델의 출력과 기대되는 정답 비교
    if check == expected_check:
        num_correct += 1
    else:
        # 틀린 예시 저장
        incorrect_examples.append({
            'eval_id': eval_id,
            'query': query,
            'expected': expected_check,
            'model_output': check
        })
    
    # 모델이 False로 판단한 경우 카운트 증가
    if check == 'False':
        false_count += 1
    
    total += 1  # 총 데이터 수 증가

# 정답률 계산 및 출력
accuracy = (num_correct / total) * 100
print(f"모델의 정답률: {accuracy:.2f}%")
print(f"모델이 False로 판단한 횟수: {false_count}회\n")

# 모델이 틀린 예시 출력
if incorrect_examples:
    print("모델이 틀린 예시:")
    for example in incorrect_examples:
        print(f"eval_id: {example['eval_id']}, query: {example['query']}")
        print(f"예상 답변: {example['expected']}, 모델의 답변: {example['model_output']}\n")
else:
    print("모델이 모든 예시를 맞췄습니다.")
# Out:
# Trueeval_id: 78, query: 나무의 분류에 대해 조사해 보기 위한 방법은?, model_output: True
#
# Trueeval_id: 213, query: 각 나라에서의 공교육 지출 현황에 대해 알려줘., model_output: True
#
# 기억 상실증의 가능한 원인에 대해 설명해 주실 수 있나요?Trueeval_id: 107, query: 기억 상실증의 가능한 원인에 대해 설명해 주실 수 있나요?, model_output: True
#
# Trueeval_id: 81, query: 통학 버스의 가치에 대해 말해줘., model_output: True
#
# Trueeval_id: 280, query: Dmitri Ivanovsky가 누구야?, model_output: True
#
# Trueeval_id: 10, query: 피임을 하기 위한 방법중 약으로 처리하는 방법은 쓸만한가?, model_output: True
#
# Trueeval_id: 100, query: 헬륨이 다른 원소들과 반응을 잘 안하는 이유는?, model_output: True
#
# Trueeval_id: 279, query: 문맹 비율이 사회 발전에 미치는 영향은?, model_output: True
#
# 이란-콘트라 사건이 미국 정치에 어떤 영향을 미쳤습니까?Trueeval_id: 42, query: 이란-콘트라 사건이 미국 정치에 어떤 영향을 미쳤습니까?, model_output: True
#
# Trueeval_id: 308, query: 자기장이 얼마나 센지 표현하는 방식은?, model_output: True
#
# Trueeval_id: 205, query: 피를 맑게 하고 몸 속의 노폐물을 없애는 역할을 하는 기관은?, model_output: True
#
# Trueeval_id: 289, query: 글리코겐의 분해는 인체에서 왜 필요한가?, model_output: True
#
# Trueeval_id: 268, query: 빗방울이 점점 커지게 되는 요인은?, model_output: True
#
# Trueeval_id: 18, query: 기체의 부피나 형태가 왜 일정하지 않을까?, model_output: True
#
# Trueeval_id: 9, query: 식물이 빛을 에너지로 변환하는 과정에 대해 설명해줘., model_output: True
#
# Trueeval_id: 101, query: 직류와 교류 전류의 차이에 대해 알려줘., model_output: True
#
# Trueeval_id: 236, query: 기름과 물이 섞여 있을 수 있나?, model_output: True
#
# Trueeval_id: 59, query: 인간이 2세를 생산할 때 DNA의 결합 과정에 대히 설명해줘., model_output: True
#
# Trueeval_id: 25, query: 금성에서 달이 어떻게 보일까?, model_output: True
#
# Trueeval_id: 5, query: 차량의 연비가 좋아질때 나타나는 긍정적인 효과는?, model_output: True
#
# Trueeval_id: 104, query: 혼합물의 특성에 대해 알려줘., model_output: True
#
# Falseeval_id: 276, query: 요새 너무 힘들다., model_output: False
#
# Trueeval_id: 14, query: 세제의 거품이 만들어지는 원리는?, model_output: True
#
# Trueeval_id: 270, query: 나무가 생태계에서 하는 역할에 대해 설명해줘., model_output: True
#
# Trueeval_id: 238, query: 전류의 흐름을 극대화 하려면 배터리와 저항을 어떻게 연결해야 하나?, model_output: True
#
# Trueeval_id: 269, query: 식물이 높이 자랄 수 있게 하는 메커니즘이 궁금해., model_output: True
#
# 달이 항상 같은 면만을 보이는 이유는 무엇인가요?Trueeval_id: 43, query: 달이 항상 같은 면만을 보이는 이유는 무엇인가요?, model_output: True
#
# Trueeval_id: 65, query: 식초와 베이킹 소다를 섞어주면 어떤 일이 일어나?, model_output: True
#
# 세균은 우리 몸에서 어떤 역할을 하나요?Trueeval_id: 97, query: 세균은 우리 몸에서 어떤 역할을 하나요?, model_output: True
#
# Trueeval_id: 206, query: 오토마톤의 특징에 대해 알려줘., model_output: True
#
# Trueeval_id: 21, query: 다양한 책을 catalog화 하는 코드에서 class 정의 방법 알려줘., model_output: True
#
# Trueeval_id: 221, query: 전구가 병렬로 연결될 때 전류가 줄어드는 원인은?, model_output: True
#
# Trueeval_id: 71, query: 물속에서 침전이 발생하는 원리에 대해 알려줘., model_output: True
#
# Trueeval_id: 254, query: 화산 폭발이 발생한 후 새로운 생물 군집이 생겨나는 것을 무엇이라 부르나?, model_output: True
#
# Trueeval_id: 226, query: 축전기를 병렬로 이어주면 전체 용량이 어떻게 되는가?, model_output: True
#
# Trueeval_id: 241, query: 정육면체가 가라앉지 않고 물 위에 떠 있을 때 수면 윗부분에 해당하는 부피를 구하는 방법은?, model_output: True
#
# Falseeval_id: 261, query: 니가 대답을 잘해줘서 너무 신나!, model_output: False
#
# Trueeval_id: 45, query: 건설 현장에서 망치로 벽을 치는 이유는?, model_output: True
#
# Trueeval_id: 19, query: 차량의 매연이 발생하지 않게 만드는 장치가 무엇인가?, model_output: True
#
# Trueeval_id: 210, query: python에서 lambda 함수를 언제 사용할 수 있어?, model_output: True
#
# Trueeval_id: 231, query: 강이나 바다의 물이 증발하는 가장 중요한 원인은?, model_output: True
#
# Trueeval_id: 233, query: 남녀 관계에서 정서적인 행동이 왜 중요해?, model_output: True
#
# Trueeval_id: 263, query: DNA 조각들이 서로 결합되도록 돕는 것은?, model_output: True
#
# Trueeval_id: 201, query: 해가 뜨는 현상이 지구의 자전과 관련있어?, model_output: True
#
# Trueeval_id: 293, query: 두 물질이 다른 분자구조나 화학적인 성분으로 이루어져 있다는 것을 어떻게 알 수 있나요?, model_output: True
#
# Trueeval_id: 208, query: 수성이 뜨거운 이유는?, model_output: True
#
# Trueeval_id: 282, query: 하구 퇴적지의 기능에 대해 알려줘., model_output: True
#
# Trueeval_id: 62, query: 디엔에이에서 퓨린과 피리미딘은 어떤 비율로 존재하는가?, model_output: True
#
# Trueeval_id: 55, query: interferon의 역할에 대해 알려줘., model_output: True
#
# Trueeval_id: 257, query: 하나의 유전자에서 여러가지 단백질이 만들어질 수 있는 원인은?, model_output: True
#
# Trueeval_id: 58, query: 질산을 통한 염화물 침전시 염소의 비율을 구하는 방법은?, model_output: True
#
# Falseeval_id: 283, query: 이제 그만 얘기해!, model_output: False
#
# Falseeval_id: 32, query: 오늘 너무 즐거웠다!, model_output: False
#
# Falseeval_id: 94, query: 우울한데 신나는 얘기 좀 해줘!, model_output: False
#
# Trueeval_id: 15, query: 연구자가 갖추어야 할 태도와 자세가 뭘까?, model_output: True
#
# Trueeval_id: 4, query: 나이가 들수록 시간이 더 빨리 가는 것 처럼 느끼게 되는 원인은?, model_output: True
#
# Trueeval_id: 300, query: 퇴직한 사람들에게 사회 보장은 어떤 의미인가?, model_output: True
#
# 사람이나 물체가 지구 표면에서 땅속으로 가라앉거나 우주로 튀어나가지 않고 왜 가만히 설 수 있는지에 대한 이유는 무엇이며, 이 현상을 설명하는 힘의 원리는 무엇인가요?Trueeval_id: 243, query: 사람이나 물체가 지구 표면에서 땅속으로 가라앉거나 우주로 튀어나가지 않고 왜 가만히 설 수 있는지에 대한 이유는 무엇이며, 이 현상을 설명하는 힘의 원리는 무엇인가요?, model_output: True
#
# Trueeval_id: 34, query: 씨앗의 기능에 대해 자세히 알려줘?, model_output: True
#
# Trueeval_id: 246, query: 친환경 재생 가능 재료가 어떤것들이 있나?, model_output: True
#
# Trueeval_id: 212, query: 남미의 라틴 역사에 대해 알려줘., model_output: True
#
# Trueeval_id: 214, query: 원자의 내부 구조에 대해 설명해줘., model_output: True
#
# Trueeval_id: 259, query: 난관의 기능에 대해 알려줘., model_output: True
#
# Trueeval_id: 267, query: 공기의 온도가 기후에 미치는 영향은?, model_output: True
#
# Falseeval_id: 90, query: 안녕 반갑다, model_output: False
#
# 평균을 계산할 때 예외처리가 필요한 경우는 언제인가요?Trueeval_id: 66, query: 평균을 계산할 때 예외처리가 필요한 경우는 언제인가요?, model_output: True
#
# Trueeval_id: 20, query: 소프트웨어 개발이 사람의 편향없이 이루어질 수 있나?, model_output: True
#
# Trueeval_id: 24, query: 전체 인구에서 특정 유전자의 비율이 변하지 않고 유지되는 상태를 뭐라고 해?, model_output: True
#
# Trueeval_id: 281, query: 지구가 생겨난지 얼마나 오래 되었는지 확인하는 방법은?, model_output: True
#
# Trueeval_id: 264, query: 성적인 자극이 발생하는 과정에 대해 알려줘., model_output: True
#
# Trueeval_id: 79, query: 전선 주위로 흐르는 자기장의 모습은 어떻게 보이나?, model_output: True
#
# Trueeval_id: 304, query: 간헐적으로 높은 강도의 운동을 하면 어떤 효과가 있나요?, model_output: True
#
# Trueeval_id: 292, query: 아세틸 콜린의 역할이 뭐야?, model_output: True
#
# Trueeval_id: 215, query: 디엔에이와 단백질의 관계와 역할에 대해 설명해줘., model_output: True
#
# Trueeval_id: 225, query: 자전축이 기후에 미치는 영향은?, model_output: True
#
# Trueeval_id: 108, query: 여행을 통해 얻을 수 있는 좋은 점들이 뭐가 있어?, model_output: True
#
# 은하들이 서로 멀어지는 현상을 어떻게 관측할 수 있나요?Trueeval_id: 98, query: 은하들이 서로 멀어지는 현상을 어떻게 관측할 수 있나요?, model_output: True
#
# Trueeval_id: 38, query: 목성 trojan의 특징에 대해 알려줘., model_output: True
#
# Trueeval_id: 287, query: 슈퍼옥시드 디스무타아제 라는 효소에 대해 설명해줘., model_output: True
#
# 네바다주에서 강수량이 적은 이유는 무엇인가요?Trueeval_id: 295, query: 네바다주에서 강수량이 적은 이유는 무엇인가요?, model_output: True
#
# Trueeval_id: 255, query: 어떤 물체를 매우 크게 확대해서 볼수 있는 기계는?, model_output: True
#
# Trueeval_id: 76, query: merge sort 알고리즘에 대해 설명해줘., model_output: True
#
# Trueeval_id: 248, query: 심해가 생태계에 미치는 영향은?, model_output: True
#
# Trueeval_id: 85, query: 저항이 2배로 증가하면 전력은 어떻게 되나?, model_output: True
#
# 산에서 발생한 화재 후 자연의 회복 과정은 무엇인가요?Trueeval_id: 290, query: 산에서 발생한 화재 후 자연의 회복 과정은 무엇인가요?, model_output: True
#
# Trueeval_id: 73, query: DNA 분해 효소의 역할에 대해 알려줘., model_output: True
#
# Trueeval_id: 309, query: 특정 농도의 황산 sample을 만드는 방법?, model_output: True
#
# Trueeval_id: 239, query: 달은 1년 동안 지구를 몇바퀴 도는가?, model_output: True
#
# Trueeval_id: 284, query: 개인의 생물학적, 사회적인 특성 형성에 영향을 미치는 요소에 대해 설명해줘., model_output: True
#
# Falseeval_id: 220, query: 너는 누구야?, model_output: False
#
# Trueeval_id: 96, query: 지각은 주로 무엇으로 이루어져 있어?, model_output: True
#
# Trueeval_id: 217, query: 오세아니아 섬나라에 광견병이 있어?, model_output: True
#
# Trueeval_id: 6, query: 추울때 폭이 넓은 회색의 구름이 끼면 어떤 날씨가 예상되나?, model_output: True
#
# Trueeval_id: 237, query: 안정성이 높은 PRP를 만드는 방법에 대해 알려줘., model_output: True
#
# Falseeval_id: 245, query: 너 모르는 것도 있니?, model_output: False
#
# Trueeval_id: 35, query: 중성자의 특징에 대해 설명해줘., model_output: True
#
# Trueeval_id: 242, query: 플랑크톤의 역할에 대해 알려줘., model_output: True
#
# Trueeval_id: 296, query: 기생과 공생의 차이에 대해 알려줘., model_output: True
#
# Trueeval_id: 307, query: 강아지가 사회화되는 행동의 사례는 뭐가 있을까?, model_output: True
#
# Falseeval_id: 229, query: 너 잘하는게 뭐야?, model_output: False
#
# Trueeval_id: 30, query: 지구에서 새로운 땅이 생겨나는 메커니즘은?, model_output: True
#
# Trueeval_id: 16, query: 더러워진 엔진오일을 잘 처리하는 방법에 대해 알려줘., model_output: True
#
# Falseeval_id: 247, query: 너 정말 똑똑하다!, model_output: False
#
# Trueeval_id: 285, query: 다람쥐가 열매를 땅에 묻는 행동이 나무에 미치는 영향은?, model_output: True
#
# Trueeval_id: 77, query: 새로운 생명체의 발생에 대한 오래된 믿음을 깨기 위해 어떤 방법이 사용되었나?, model_output: True
#
# Trueeval_id: 250, query: 협곡이 형성되는 과정은?, model_output: True
#
# 파이썬에서 숫자 계산을 위한 operator 우선순위는 무엇인가요?Trueeval_id: 68, query: 파이썬에서 숫자 계산을 위한 operator 우선순위는 무엇인가요?, model_output: True
#
# 바닷물 이외에 지구상에서 가장 많은 담수는 어디에 있나요?Trueeval_id: 86, query: 바닷물 이외에 지구상에서 가장 많은 담수는 어디에 있나요?, model_output: True
#
# Trueeval_id: 232, query: 폭풍을 쫓는 사람들이 누구야?, model_output: True
#
# Trueeval_id: 109, query: 우라늄을 사용한 원자력 발전의 단점에 대해 알려줘., model_output: True
#
# Trueeval_id: 1, query: 고체에서 액체로 변할 때 엔트로피는 어떻게 되나?, model_output: True
#
# Trueeval_id: 28, query: 사회로부터의 감정적인 지원이 어떤 형태로 나타날 수 있어?, model_output: True
#
# Trueeval_id: 203, query: 석탄을 에너지원으로 사용할 때의 장단점이 뭐야?, model_output: True
#
# Trueeval_id: 91, query: 탄소의 내부 구조를 알아낼 수 있는 방법은?, model_output: True
#
# Trueeval_id: 105, query: 연구의 과정과 결과를 잘 기록해야 하는 이유?, model_output: True
#
# Falseeval_id: 67, query: 니가 대답을 잘해줘서 기분이 좋아!, model_output: False
#
# Trueeval_id: 13, query: 밀물과 썰물의 강도에 영향을 주는 요소들에 대해 알려줘., model_output: True
#
# Falseeval_id: 57, query: 우울한데 신나는 얘기 좀 해줄래?, model_output: False
#
# Falseeval_id: 2, query: 이제 그만 얘기하자., model_output: False
#
# Trueeval_id: 253, query: 유전 교차에서 복잡형질과 관련된 염색체 영역 식별 방법은?, model_output: True
#
# Trueeval_id: 49, query: 척추 동물이 영역을 가지고 다투는 이유는?, model_output: True
#
# Trueeval_id: 294, query: 어린 새들이 생존에서 살아남기 위해 진화한 기능들이 뭐가 있어?, model_output: True
#
# Trueeval_id: 17, query: 입자가 같은 속력으로 원운동을 할 때 속도와 가속도 벡터 사이의 각도는 얼마인가?, model_output: True
#
# Trueeval_id: 207, query: 곤충 눈의 구조에 대해 설명해줘., model_output: True
#
# Falseeval_id: 227, query: 너는 누구니?, model_output: False
#
# Trueeval_id: 204, query: 물고기는 어떻게 숨을 쉬는가?, model_output: True
#
# 하천을 모델링할 때 고려해야 할 주요 요소들은 무엇인가요?Trueeval_id: 89, query: 하천을 모델링할 때 고려해야 할 주요 요소들은 무엇인가요?, model_output: True
#
# Trueeval_id: 256, query: 체질량 지수의 한계에 대해 알려줘., model_output: True
#
# Trueeval_id: 291, query: 행성의 내부 구조를 이해하기 위한 방법은?, model_output: True
#
# Trueeval_id: 8, query: 식물의 잎이 다수 떨어지거나 구멍이 생기는 현상을 어떻게 해석해야 해?, model_output: True
#
# Trueeval_id: 106, query: 일식이 발생하는 원리는?, model_output: True
#
# Trueeval_id: 84, query: 광합성이 무엇인지 그리고 효과에 대해 알려줘., model_output: True
#
# Trueeval_id: 70, query: 리보오솜의 역할이 뭐야?, model_output: True
#
# Falseeval_id: 301, query: 오늘 너무 즐거웠어!, model_output: False
#
# Trueeval_id: 230, query: 바람이 부는 이유는?, model_output: True
#
# Trueeval_id: 92, query: 메릴랜드의 대표적인 천연 자원은?, model_output: True
#
# Trueeval_id: 72, query: 디엔에이 리가아제의 주요 기능이 뭐야?, model_output: True
#
# Trueeval_id: 211, query: 신체 변화의 정도나 속도가 사람들마다 다른 점으로부터 고려 할 수 있는 사항은?, model_output: True
#
# Trueeval_id: 258, query: 머클-담고르 해시 함수를 사용한 MAC 보안 취약점은?, model_output: True
#
# Trueeval_id: 51, query: 초코렛이 녹는 물리적인 원리는?, model_output: True
#
# Trueeval_id: 200, query: 배터리가 완구를 움직이게 하는 원리는?, model_output: True
#
# Trueeval_id: 274, query: 궤양성 대장염이 있는 사람들이 조심해야 할 사항들은 뭐가 있어?, model_output: True
#
# Trueeval_id: 41, query: 음파의 주파수와 속도의 관계가 어떻게 돼?, model_output: True
#
# Trueeval_id: 87, query: 목성 내부에서 온도가 높아지는 원리가 뭐야?, model_output: True
#
# Trueeval_id: 235, query: 결혼 전에 성관계를 가지는 것이 괜찮다고 생각하는 사람들의 주된 특징은?, model_output: True
#
# Trueeval_id: 262, query: 나이와 코호트 차이를 다 고려하는 디자인 방식은?, model_output: True
#
# Trueeval_id: 288, query: 건강한 입을 가지고 있는지 판단할 수 있는 방법에 대해 알려줘., model_output: True
#
# Trueeval_id: 60, query: 성대 주름이 긴장했는지 어떻게 알 수 있나?, model_output: True
#
# Falseeval_id: 222, query: 안녕 반가워, model_output: False
#
# Trueeval_id: 46, query: B-형 간염에 대해 알려줘., model_output: True
#
# Trueeval_id: 234, query: 노인 학대를 막기 위한 방안이 뭐가 있을까?, model_output: True
#
# Falseeval_id: 83, query: 너 정말 똑똑하구나?, model_output: False
#
# Trueeval_id: 23, query: 식물과 동물중 누가 번식력이 높다고 할 수 있어?, model_output: True
#
# Trueeval_id: 82, query: 엽록체의 역할에 대해 설명해줘., model_output: True
#
# Trueeval_id: 61, query: 특정 물질이 금속으로 되어 있는지 확인 하는 방법은?, model_output: True
#
# Trueeval_id: 56, query: 파리가 생태계에 미치는 영향에 대해 알려줘., model_output: True
#
# Trueeval_id: 99, query: 칼리시 바이러스는 어떻게 생존을 이어나가는가?, model_output: True
#
# Trueeval_id: 75, query: 옥수수 수확에 어류를 활용하는 방법은?, model_output: True
#
# Trueeval_id: 299, query: 이태리에서 언론의 자유는 어떤 편이야?, model_output: True
#
# 은하 내의 별들이 어떻게 그렇게 밀집되어 있는 상태로 유지될 수 있나요?Trueeval_id: 306, query: 은하 내의 별들이 어떻게 그렇게 밀집되어 있는 상태로 유지될 수 있나요?, model_output: True
#
# Trueeval_id: 80, query: 네트웍 통신시에 주소를 속이는 공격 방법이 뭐야?, model_output: True
#
# Falseeval_id: 64, query: 너 모르는 것도 있어?, model_output: False
#
# Trueeval_id: 271, query: 과일 샐러드의 특징에 대해 알려줘., model_output: True
#
# 새로 개발된 항생제의 효과를 확인하기 위해 어떤 단계를 거쳐야 하나요?Trueeval_id: 39, query: 새로 개발된 항생제의 효과를 확인하기 위해 어떤 단계를 거쳐야 하나요?, model_output: True
#
# Trueeval_id: 219, query: 인간의 침 속에 포함되어 있는 효소는 어떤 역할을 하는가?, model_output: True
#
# Trueeval_id: 273, query: 바다가 육지의 날씨에 미치는 영향은?, model_output: True
#
# Trueeval_id: 224, query: 네트워크 분석을 위한 traffic sniffing이 뭐야?, model_output: True
#
# Trueeval_id: 12, query: 많은 사람들에게 선한 영향력을 준 벽돌공의 일대기에 대해 알려줘., model_output: True
#
# 리스트에서 가장 작은 요소를 찾는 파이썬 함수는 무엇인가요?Trueeval_id: 33, query: 리스트에서 가장 작은 요소를 찾는 파이썬 함수는 무엇인가요?, model_output: True
#
# Trueeval_id: 240, query: 글루텐이 에너지 흡수에 미치는 영향은?, model_output: True
#
# Trueeval_id: 252, query: 해구가 생겨나는 원리는?, model_output: True
#
# Trueeval_id: 69, query: 비만도를 어떻게 측정할 수 있나?, model_output: True
#
# Trueeval_id: 47, query: 원자번호는 원자내의 어떤 소립자와 관계 있는가?, model_output: True
#
# Trueeval_id: 0, query: 바이러스가 원핵 세포와 서로 작용할 때 사용하는 것은?, model_output: True
#
# Trueeval_id: 52, query: 연기 열수공의 특성에 대해 설명해줘., model_output: True
#
# Falseeval_id: 103, query: 너 뭘 잘해?, model_output: False
#
# Trueeval_id: 209, query: bridge inverter의 역할에 대해 알려줘?, model_output: True
#
# Trueeval_id: 251, query: 캠핑의 선기능에 대해 알려줘., model_output: True
#
# Trueeval_id: 275, query: 지구 온난화 때문에 문제가 발생할 수 있는 지역은?, model_output: True
#
# Trueeval_id: 48, query: 염소 원자에 빛을 방출했을 때 발생할 수 있는 시나리오에 대해 알려줘., model_output: True
#
# Trueeval_id: 36, query: 후두가 안정성을 유지할 수 있는 이유는?, model_output: True
#
# Falseeval_id: 218, query: 요새 너무 힘드네.., model_output: False
#
# Trueeval_id: 298, query: 연구실에서 무엇인지 파악이 안된 가루를 저울로 옮기는 좋은 방법은?, model_output: True
#
# Trueeval_id: 40, query: 금성이 행성중 가장 밝게 보이는 이유는?, model_output: True
#
# Trueeval_id: 260, query: 자석의 세기에 가장 큰 영향을 주는 불순물은?, model_output: True
#
# Trueeval_id: 11, query: 솔레노이드가 뭐야?, model_output: True
#
# 여러 개의 약물을 동시에 복용할 때 발생할 수 있는 잠재적 위험이나 상호작용은 무엇인가요?Trueeval_id: 249, query: 여러 개의 약물을 동시에 복용할 때 발생할 수 있는 잠재적 위험이나 상호작용은 무엇인가요?, model_output: True
#
# Trueeval_id: 22, query: 진폭 변조와 주파수 변조의 차이에 대해 알려줘., model_output: True
#
# Trueeval_id: 93, query: 잠을 잘 잤을 때 이로운 점을 나열해줘., model_output: True
#
# Trueeval_id: 31, query: 음파는 어떻게 이동하는가?, model_output: True
#
# Trueeval_id: 50, query: 테러로 인한 이슈와 대응책에 대해 알려줘., model_output: True
#
# Trueeval_id: 277, query: 바닥의 마찰이 없는 곳에서 두 사람이 서로 밀어낼때 무게가 덜 나가는 사람이 더 나가는 사람이 더 빨리 움직이게 되는 이유는?, model_output: True
#
# Trueeval_id: 27, query: 세포간에 갭결합이 생기는 것을 규명한 실험에 대해 알려줘., model_output: True
#
# Trueeval_id: 272, query: 행성의 크기와 화산이 얼마나 자주 폭발하는지가 관련이 있어?, model_output: True
#
# 다음 세대의 꽃 색깔은 무엇인가요?Trueeval_id: 54, query: 다음 세대의 꽃 색깔은 무엇인가요?, model_output: True
#
# Trueeval_id: 302, query: 기계가 연료를 태울 때 어떤 형태로 에너지가 낭비되는가?, model_output: True
#
# 동물들이 집단으로 이주하는 이유는 무엇이며, 이러한 현상을 유발하는 요인들은 무엇인가요?Trueeval_id: 3, query: 동물들이 집단으로 이주하는 이유는 무엇이며, 이러한 현상을 유발하는 요인들은 무엇인가요?, model_output: True
#
# Trueeval_id: 202, query: 남미 여러 나라들이 중고등학교 취학률을 높이기 위해 어떤 일들을 하고 있어?, model_output: True
#
# Trueeval_id: 74, query: 네트웍 계층 중 IP에 대해 설명해줘., model_output: True
#
# 같은 독감에 두 번 걸릴 때 면역 반응이 더 빠르게 나타나는 이유는 무엇인가요?Trueeval_id: 44, query: 같은 독감에 두 번 걸릴 때 면역 반응이 더 빠르게 나타나는 이유는 무엇인가요?, model_output: True
#
# Trueeval_id: 63, query: 시소에서 균형을 잡기 위해 양쪽에서 가하는 힘의 크기에 대해 설명해줘., model_output: True
#
# Trueeval_id: 37, query: 두개의 소스로부터 발생한 사건중 어떤 쪽에서 기인한 것인지 확률 계산하는 예시 알려줘., model_output: True
#
# Trueeval_id: 29, query: 곤충의 생태를 관찰할 때 사용할 수 있는 방법은?, model_output: True
#
# Trueeval_id: 102, query: 작은 기체 하나의 질량을 어떻게 구할 수 있어?, model_output: True
#
# Trueeval_id: 228, query: 평형분극비율이 뭐야?, model_output: True
#
# Trueeval_id: 297, query: 근친간의 성행위가 금해지는 이유는?, model_output: True
#
# 노인들이 후각을 상실하게 될 때, 일상 생활에 어떤 영향을 미치게 되나요?Trueeval_id: 278, query: 노인들이 후각을 상실하게 될 때, 일상 생활에 어떤 영향을 미치게 되나요?, model_output: True
#
# Trueeval_id: 53, query: 하늘이 파란 이유는?, model_output: True
#
# Trueeval_id: 26, query: 짚신 벌레의 번식은 어떻게 이루어지나?, model_output: True
#
# Trueeval_id: 265, query: 온난 전선이 발생하면 이후 날씨는 어떻게 되나?, model_output: True
#
# Trueeval_id: 216, query: 전기가 흐르는 회로에서 전선과 전구의 전류는 동일한가?, model_output: True
#
# Trueeval_id: 95, query: 플로리다에서 친환경 에너지를 가장 효과적으로 활용할 수 있는 시기는?, model_output: True
#
# Trueeval_id: 305, query: 농장이 해안가 환경에 나쁜 영향을 미칠 수 있는 원인이 뭐가 있어?, model_output: True
#
# Trueeval_id: 7, query: 자성을 띄지 않는 유전체 내부에서 빛의 속도는 어떻게 되나?, model_output: True
#
# Trueeval_id: 88, query: 자연보호구역이 필요한 이유는?, model_output: True
#
# Trueeval_id: 244, query: 정상파가 뭐야?, model_output: True
#
# Trueeval_id: 223, query: 공에 힘이 주어졌을 때 공이 어떻게 움직이는지 과학적으로 설명해줘., model_output: True
#
# Trueeval_id: 303, query: 동물들이 피부나 털의 색깔을 통해 생존의 확률을 높이는 방식에 대해 설명해줘., model_output: True
#
# Trueeval_id: 286, query: 메탄과 산소의 화학 반응에 대해 알려줘., model_output: True
#
# Trueeval_id: 266, query: 복숭아 키우는 노하우좀?, model_output: True
#
# 모델의 정답률: 100.00%
# 모델이 False로 판단한 횟수: 20회
#
# 모델이 모든 예시를 맞췄습니다.
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
