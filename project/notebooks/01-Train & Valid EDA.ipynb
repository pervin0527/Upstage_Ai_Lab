# %%
import os
import re
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

from scipy import stats
from mecab import MeCab
from konlpy.tag import Okt
from collections import Counter

# %%
data_path = "../dataset"

train_df = pd.read_csv(f"{data_path}/train.csv")
valid_df = pd.read_csv(f"{data_path}/dev.csv")
test_df = pd.read_csv(f"{data_path}/test.csv")

# %%
print("Train DataFrame")
print(train_df.shape)
print(train_df.columns)

print("\nValid DataFrame")
print(valid_df.shape)
print(valid_df.columns)

print("\nTest DataFrame")
print(test_df.shape)
print(test_df.columns)
# Out:
# Train DataFrame
# (12457, 4)
# Index(['fname', 'dialogue', 'summary', 'topic'], dtype='object')
#
# Valid DataFrame
# (499, 4)
# Index(['fname', 'dialogue', 'summary', 'topic'], dtype='object')
#
# Test DataFrame
# (499, 2)
# Index(['fname', 'dialogue'], dtype='object')

# %%
sample = train_df.sample(10)
sample.to_csv("../dataset/sample.csv", index=False)

# %% [markdown]
# # 1.Sample Row 확인

# %%
idx = random.randint(0, train_df.shape[0]-1)
sample = train_df.iloc[idx]
print(sample, "\n")

print(f"전체 대화 :\n{sample['dialogue']} \n")
print(f"요약 내용 :\n{sample['summary']}, \n")
print(f"대화 주제 :\n {sample['topic']}, \n")
# Out:
# fname                                              train_3604
# dialogue    #Person1#: 길 끝에 있는 빨간 집에 살고 있나요?\n#Person2#: 네...
# summary     #Person2#는 #Person1#에게 부모님과 여동생과 함께 살고 있으며, 고양...
# topic                                                   일상 대화
# Name: 3604, dtype: object
#
# 전체 대화 :
# #Person1#: 길 끝에 있는 빨간 집에 살고 있나요?
# #Person2#: 네, 저는 부모님과 여동생과 함께 그 집에 살고 있습니다. 우리는 고양이와 개도 키우고 있어요.
# #Person1#: 매일 개를 산책시키나요?
# #Person2#: 아니요. 아버지와 제가 함께 산책을 시켜요. 아버지는 월요일, 화요일, 일요일에 개를 산책시키고, 저는 수요일, 목요일, 금요일에 산책시킵니다.
# #Person1#: 토요일에는 누가 개를 산책시키나요?
# #Person2#: 토요일에는 다같이 공원에 가는데 개도 함께 데려가요.
# #Person1#: 집안일을 도우시나요?
# #Person2#: 엄마와 여동생이 집안일과 요리를 하지만 저는 제 방을 청소합니다.
#
# 요약 내용 :
# #Person2#는 #Person1#에게 부모님과 여동생과 함께 살고 있으며, 고양이와 개를 키우고 있다고 말합니다. #Person2#는 집안일 분담에 대해서도 이야기합니다.,
#
# 대화 주제 :
#  일상 대화,

# %% [markdown]
# # 2.데이터 길이

# %%
# dialogue와 summary의 길이를 계산
train_df['dialogue_length'] = train_df['dialogue'].apply(len)
train_df['summary_length'] = train_df['summary'].apply(len)

# 시각화
plt.figure(figsize=(14, 6))

# Dialogue 길이 시각화
plt.subplot(1, 2, 1)
plt.hist(train_df['dialogue_length'], bins=30, color='skyblue', edgecolor='black')
plt.title('Dialogue Length Distribution')
plt.xlabel('Length of Dialogue')
plt.ylabel('Frequency')

# Summary 길이 시각화
plt.subplot(1, 2, 2)
plt.hist(train_df['summary_length'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Summary Length Distribution')
plt.xlabel('Length of Summary')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# min, max, mode 길이를 계산하는 함수 정의
def get_length_stats(column):
    min_length = column.min()
    max_length = column.max()
    mode_length = column.mode()[0]
    return min_length, max_length, mode_length

# dialogue와 summary의 길이에 대한 통계 계산
dialogue_min, dialogue_max, dialogue_mode = get_length_stats(train_df['dialogue_length'])
summary_min, summary_max, summary_mode = get_length_stats(train_df['summary_length'])

dialogue_stats = {
    'Dialogue': {
        'Min Length': dialogue_min,
        'Max Length': dialogue_max,
        'Mode Length': dialogue_mode
    },
    'Summary': {
        'Min Length': summary_min,
        'Max Length': summary_max,
        'Mode Length': summary_mode
    }
}

print(dialogue_stats)
# Out:
# {'Dialogue': {'Min Length': 99, 'Max Length': 2546, 'Mode Length': 350}, 'Summary': {'Min Length': 19, 'Max Length': 478, 'Mode Length': 63}}

# %%
long_dialogue_df = train_df[train_df['dialogue_length'] >= 800]
print(long_dialogue_df.shape)
print(long_dialogue_df.head())
long_dialogue_df.to_csv("../dataset/long.csv", index=False)
# Out:
# (682, 6)
#        fname                                           dialogue  \
# 7    train_7  #Person1#: 도와드릴 일이 있나요?\n#Person2#: 네. 저는 지난 주...
# 14  train_14  #Person1#: 어떤 종류의 음악을 듣는 것을 좋아하시나요?\n#Person2#...
# 35  train_35  #Person1#: 나는 텔레비전 보는 것이 지겨워. 오늘 밤에 영화관에 가자.\n...
# 58  train_58  #Person1#: 우리 어떻게 할까?  차를 이 웅덩이에서 빼낼 수가 없어. 나는...
# 63  train_63  #Person1#: 또 다른 Premier Movie Review에 오신 영화 애호...
#
#                                               summary  topic  dialogue_length  \
# 7   주디 리아오는 회계 보조 자리에 지원하고 있습니다. 그녀는 #Person1#에게 이...  직장 지원              806
# 14  #Person2#는 댄스 음악을 좋아하고, #Person1#은 클래식 음악을 선호합...     음악              912
# 35  #Person1#은 텔레비전 보는 것이 지겨워서, #Person1#과 #Person...  영화 보기              886
# 58  톰과 #Person2#의 차는 큰 눈보라 속에서 웅덩이에 갇혀 있다. 처음에는 불안...     갇힘             1036
# 63  리처드 클라크와 데이비드 왓슨이 Premier Movie Review에서 '라이온 ...  영화 토론             1103
#
#     summary_length
# 7              166
# 14             211
# 35             152
# 58             127
# 63             164

# %%
def calculate_lengths(df):
    df['dialogue_length'] = df['dialogue'].str.len()
    df['summary_length'] = df['summary'].str.len()
    return df

def analyze_correlation(df):
    x = df['dialogue_length']
    y = df['summary_length']
    
    # Calculate Pearson correlation coefficient
    r, p_value = stats.pearsonr(x, y)
    
    # Perform linear regression
    slope, intercept, r_value, _, _ = stats.linregress(x, y)
    
    print(f"Pearson correlation coefficient (r): {r:.4f}")
    print(f"p-value: {p_value:.4f}")
    print(f"Slope: {slope:.4f}")
    print(f"Intercept: {intercept:.4f}")
    print(f"R-squared: {r_value**2:.4f}")
    
    return r, slope, intercept, r_value**2

def plot_correlation(df, slope, intercept):
    plt.figure(figsize=(10, 6))
    plt.scatter(df['dialogue_length'], df['summary_length'], alpha=0.5)
    plt.xlabel('Dialogue Length')
    plt.ylabel('Summary Length')
    plt.title('Dialogue Length vs Summary Length')
    
    # Add regression line
    x = np.array([df['dialogue_length'].min(), df['dialogue_length'].max()])
    y = slope * x + intercept
    plt.plot(x, y, color='red', label=f'y = {slope:.4f}x + {intercept:.4f}')
    
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
r, slope, intercept, r_squared = analyze_correlation(train_df)
plot_correlation(train_df, slope, intercept)
# Out:
# Pearson correlation coefficient (r): 0.7886
# p-value: 0.0000
# Slope: 0.1348
# Intercept: 28.2363
# R-squared: 0.6218

# %%
train_df['is_train'] = 1
valid_df['is_train'] = 0
total_df = pd.concat([train_df, valid_df], ignore_index=True)

# %%
## 총 6773개의 주제가 있다.
topic_counts = total_df['topic'].value_counts()
for topic, counts in topic_counts.items():
    print(topic, counts)
# Out:
# 일상 대화 240
# 쇼핑 195
# 직업 면접 101
# 전화 통화 100
# 음식 주문 87
# 인터뷰 76
# 길 묻기 73
# 영화 48
# 체크인 47
# 사회적 만남 47
# 날씨 45
# 면접 45
# 여행 43
# 초대 38
# 주말 계획 37
# 휴가 36
# 길 안내 34
# 정보 요청 34
# 쇼핑 가기 32
# 비즈니스 대화 31
# 약속 잡기 31
# 체중 감량 29
# 은행 서비스 29
# 아파트 임대 29
# 취미 29
# 도움 요청 28
# 직업 28
# 이별 28
# 택시 타기 27
# 객실 예약 27
# 파티 26
# 머리 자르기 26
# 결혼 26
# 사무실 대화 26
# 약속 25
# 저녁 식사 초대 24
# 여행 계획 24
# 일자리 찾기 24
# 영화 보기 23
# 미래 계획 22
# 호텔 서비스 22
# 운동 22
# 휴가 계획 22
# 음식 주문하기 22
# 계좌 개설 22
# 일 21
# 레스토랑 서비스 21
# 사과 20
# 생일 선물 20
# 의사에게 상담하기 20
# 취업 면접 20
# 요리 20
# 방 예약하기 19
# 사회적 대화 19
# 티켓 예약 19
# 인사 18
# 레스토랑에서 18
# 스포츠 18
# 저녁 식사 18
# 티켓 구매 18
# 흥정 18
# 체크아웃 18
# 옷 구매 17
# 사고 17
# 구직 면접 17
# 버스 타기 17
# 학교 생활 17
# 생일 16
# 사회적인 캐주얼 대화 16
# 직장 면접 16
# 룸 서비스 16
# 메시지 남기기 16
# 불평 16
# 출장 16
# 아파트 16
# 아파트 찾기 16
# 가족 15
# 예약 15
# 음악 15
# 교통 15
# 집 임대 15
# 주문 15
# 주문 받기 15
# 파티 초대 14
# 온라인 쇼핑 14
# 가족 대화 14
# 레스토랑 14
# 일정 14
# 친구들 사이의 대화 14
# 환전 14
# 컴퓨터 14
# 투표 14
# 작별 14
# 운동하기 13
# 생일 파티 13
# 호텔 13
# 책 빌리기 13
# 축구 경기 13
# 예약하기 13
# 중국 음식 13
# 회의 13
# 선물 12
# 새 차 12
# TV 시청 12
# 구직 활동 12
# 데이트 12
# 수다 12
# 식당 12
# 계획 11
# 돈 인출 11
# 자동차 사고 11
# 새로운 직장 11
# 영화 토론 11
# 축하 11
# 사진 찍기 11
# 환불 11
# 음료 주문 11
# 방문 11
# 건강 유지 11
# 비행기 예약 11
# 질병 11
# 주말 활동 11
# 시험 11
# 승진 10
# 집 구매 10
# 독서 10
# 책 10
# 지각 10
# 도움 10
# 칭찬 10
# 결혼식 10
# 책 구매 10
# 제안 10
# 학교 10
# 주차 10
# 언어 10
# 흡연 10
# 직업 인터뷰 10
# 비즈니스 토크 10
# 생일 축하 10
# 급여 10
# 이혼 9
# 회사 9
# 새 집 9
# 운전 9
# 영화 초대 9
# 직장 변경 9
# 점심 9
# 편지 보내기 9
# 이사 9
# 예약 취소 9
# 비즈니스 협상 9
# 도서관 9
# 강도 9
# 음료 9
# 대출 9
# 불만 9
# 집 9
# 싸움 9
# 좋은 소식 9
# 새 아파트 9
# 계산하기 9
# 온라인 채팅 9
# 게임 9
# 선물 사기 9
# 집 보기 8
# 신용카드 8
# 소포 보내기 8
# 초대장 8
# 자전거 8
# 휴대폰 8
# 여름 휴가 8
# 면접 준비 8
# 호텔 예약 8
# 저녁식사 8
# 비행 8
# 사내 연애 8
# 동료들 사이의 대화 8
# 비즈니스 8
# 주말 8
# 초과근무 8
# 아르바이트 8
# 전화 걸기 8
# 크리스마스 8
# 지각하다 8
# 책 찾기 8
# 수업 8
# 돈 빌리기 8
# TV 프로그램 8
# 테이블 예약 8
# 여가 활동 8
# 걱정 8
# 저녁 계획 8
# 기차 7
# 저녁 준비 7
# 임대 7
# 등산 7
# 차 렌트 7
# 전시회 7
# 시험 준비 7
# 돈 7
# 일상 사교 대화 7
# 광고 7
# 이웃 7
# 날씨에 대해 이야기하기 7
# 구직 7
# 사업상 대화 7
# 작별 인사 7
# 배송 7
# 명함 7
# 외출 7
# 담배 끊기 7
# 영어 학습 7
# 결혼 기념일 7
# 투자 7
# 애완동물 키우기 7
# 차 구매 7
# 여름 계획 7
# 아파트 보기 7
# 사진 7
# 사랑에 빠지다 7
# 냉장고 구매 7
# 콘서트 7
# 질문하기 7
# 소개 7
# 세탁 7
# 결혼 준비 7
# 방 바꾸기 7
# 꿈 7
# 현장 학습 7
# 버스 패스 7
# 비 7
# 농구 경기 7
# 망고 7
# 새로운 일자리 7
# 자기소개 7
# 논쟁 6
# 감사 6
# 교육 6
# 만우절 6
# 파티 준비 6
# 신문 6
# 이력서 6
# 컴퓨터 수리 6
# 그림 6
# 대학 생활 6
# 도서관 서비스 6
# 발표 6
# 탑승 6
# 가십 6
# 교통사고 6
# 저녁 식사하기 6
# 차량 사고 6
# 댄스 6
# 도움 제공 6
# 관광 6
# 공항 6
# 레스토랑 예약 6
# 수표 현금화 6
# 스키 6
# 드레스 6
# 신발 구매 6
# 의사를 찾아가다 6
# 체포 6
# 프로젝트 6
# 비행기 안에서 6
# 시간 6
# 관계 6
# 커피 6
# 차 6
# 공부 6
# 차 빌리기 6
# 복통 6
# 신발 6
# 여자친구 6
# 환경 보호 6
# 대중교통 6
# 전화 6
# 인터넷 6
# 급여 인상 6
# 감기 6
# 크리스마스 선물 6
# 전화 대화 6
# 비행기 지연 6
# 대화 6
# 호텔 체크인 6
# 집 꾸미기 6
# 식사 주문하기 6
# 외식 6
# 직장 6
# 숙제 6
# 조언 구하기 6
# 버스 6
# 캠핑 6
# 팩스 기계 6
# 친구 6
# 결혼하기 6
# 음식 6
# 비행기 타기 6
# 모자 구매 6
# 새해 5
# 애완동물 5
# 차량 수리 5
# 일어나기 5
# 직업 찾기 5
# 입금 5
# 운전 시험 5
# 가장 좋아하는 계절 5
# 방 5
# 계절 5
# 수영 5
# 새 컴퓨터 5
# 검사 결과 5
# 출산 5
# 교통 체증 5
# 계약서 서명 5
# 점심 식사 5
# 대학 5
# 비행기 표 예약 5
# 세탁기 5
# 풍문 5
# 비자 신청 5
# 직장 그만두기 5
# 발렌타인 데이 5
# 룸메이트 5
# 성격 5
# 휴일 5
# 항공권 예약 5
# 환경 문제 5
# 회의 준비 5
# 소풍 5
# 소문 5
# 선물 고르기 5
# 팬 구매 5
# 도서관에서 5
# 시차 5
# 문화 차이 5
# 집 판매 5
# 주차 허가증 5
# 언어 학습 5
# 모닝콜 5
# 택시 5
# 휴가 청구 5
# 결정 5
# 범죄 5
# 휴가 요청 5
# 아파트 렌트 5
# 대학 선택 5
# 교육 배경 5
# 사회적인 캐주얼한 대화 5
# 사무실에서 5
# 옷차림 5
# 해외 유학 5
# 첫 만남 5
# 가격 협상 5
# 여행 준비 5
# 예약 변경 5
# 누군가를 배웅하다 5
# 편지 5
# 스웨터 구매 5
# 아침식사 5
# 도둑질 5
# 건강한 식단 5
# 약속 취소 5
# 휴식 5
# 치통 5
# 격려 5
# 프로포즈 5
# 식습관 5
# 시계 구매 5
# 사랑 5
# 입찰 4
# 분실물 찾기 4
# 등록 4
# 협상 4
# 자동차 구매 4
# 출근 지각 4
# 공항 픽업 4
# 거래 4
# 아침 식사 4
# 화폐 교환 4
# 티켓 4
# 철도 서비스 4
# 미래의 직업 4
# 전학 4
# 복장 규정 4
# 현금 인출 4
# 영어 공부 4
# 옷 세탁 4
# 가방 분실 4
# 캠핑 가기 4
# 아픔 4
# 놀람 4
# 집안일 하기 4
# ATM 사용법 4
# 역사 4
# 방 예약 4
# 토요일 계획 4
# 전쟁 4
# 세관 검사 4
# 휴가 여행 4
# 아이들 4
# 사교 모임 4
# 다이어트 4
# 목걸이 4
# 길을 묻다 4
# 미용실 4
# 팁 4
# 과일 구매 4
# 은행 4
# 휴가 신청 4
# 방 변경 4
# 소음 4
# 드레스 구매 4
# 컴퓨터 구매 4
# 의사 4
# 박물관 4
# 이사 가기 4
# 식사 주문 4
# 청소 4
# 코트 구매 4
# 호텔 방 예약 4
# 책 구입 4
# 가구 4
# 은행 강도 4
# 계산서 지불 4
# 수업 등록 4
# 공연 4
# 개인 경험 4
# 컴퓨터 문제 4
# 도박 4
# 비행기 티켓 4
# 여름 휴가 계획 4
# 사무실 4
# 서비스 4
# 사랑 고백 4
# 돈 저축 4
# ATM 4
# 개인 정보 4
# 중국어 학습 4
# 나쁜 소식 4
# 할로윈 4
# 노래 부르기 4
# 교통 수단 4
# 성형 수술 4
# 세관에서 4
# 두통 4
# 시험 결과 4
# 연설 4
# 택시를 타다 4
# 직업 선택 4
# 사랑 이야기 4
# 여행 예약 4
# 야근 4
# 여행자 수표 4
# 관광 가기 4
# 학교 가기 4
# 수면 문제 4
# 직무 인터뷰 4
# 고양이 4
# 정원 가꾸기 4
# 커피숍 4
# 시계 4
# 낚시 4
# 레스토랑 대화 4
# 영어 4
# 파리 여행 4
# 차 수리 4
# 세관 통과 4
# 초대 거절 4
# 식사하기 4
# 의사 진료 4
# 학교 선택 4
# 생일 파티 준비 4
# A/S 서비스 4
# 여자 4
# 위로 4
# 길 물어보기 4
# 방 임대 4
# 수영 스테이션 4
# 택시 서비스 4
# 컨퍼런스 4
# 집 팔기 4
# 집들이 파티 4
# 약혼 4
# 낚시 가기 4
# 식사 4
# 춤 4
# 몇 가지 질문하기 4
# 체크 아웃 4
# 수업에 늦음 4
# 콘서트 초대 4
# 비난 4
# 여행 경험 4
# 학교 지원 4
# 가게 4
# 패션 4
# 책 읽기 4
# 지갑 잃어버림 4
# 바 4
# 이직 4
# 다른 의견 4
# 아이스크림 4
# 사직 4
# 점심 회의 4
# 아들 4
# 직장 지원 4
# 언어 교환 4
# 상사 4
# 고객 서비스 3
# 가족 소개 3
# 물건 구매 3
# 청소부 3
# 주문하기 3
# 주문 확인 3
# 파티 초대장 3
# 다치다 3
# 잘못된 번호 3
# 월드컵 3
# 점심 초대 3
# 결정 내리기 3
# 교통수단 3
# 새로운 이웃 3
# 부탁하기 3
# 계산서 확인 3
# 직장 찾기 3
# 작가 인터뷰 3
# 외국어 3
# 저녁 식사 준비 3
# 고기 쇼핑 3
# 잃어버린 지갑 3
# 은퇴 계획 3
# 오늘 밤의 계획 3
# 정원 3
# 길을 안내하다  3
# 넥타이 3
# 처음 만남 3
# 크리스마스 파티 3
# 우편 3
# 손금술 3
# 겨울 3
# 옷 3
# 인생 경험 3
# 운전 배우기 3
# 헤어스타일 3
# 주차 위반 티켓 3
# 기후 3
# 불만 제기하기 3
# 지각의 이유 3
# 의사에게 진찰받기 3
# 운동 수업 3
# 기념품 3
# 감기에 걸리다 3
# 의사와의 대화 3
# 정장 3
# 제품 3
# 중국 여행 3
# 자동차 대출 3
# 여권 3
# 항공권 구매 3
# 농구 경기 보기 3
# 몸이 안 좋음 3
# 차 구매하기 3
# 아침식사 주문 3
# 여름 3
# 공장 방문 3
# 누군가에 대해 이야기하기 3
# 사무용품 3
# 숙박 3
# 요청 3
# 누군가를 해고하다 3
# 약속 변경 3
# 돈 송금 3
# 과목 선택 3
# 심문 3
# 경기 3
# 산 등반 3
# 의사 만나기 3
# 공연 초대 3
# 공부 계획 3
# 계약 3
# 영어 연습 3
# 텔레비전 3
# 더치 페이 3
# 비행기 멀미 3
# 경찰 3
# 수술 3
# 벼룩시장 3
# 새 프로젝트 3
# 할머니 3
# 투어 3
# 프로그램 3
# 회사 규정 3
# 시장 3
# 관계에 대한 토론 3
# 인상 3
# 컴퓨터 바이러스 3
# 삶 3
# 영어 배우기 3
# 근무 시간 3
# 도서관 카드 3
# 바쁜 하루 3
# 서로 인사하기 3
# 공항 보안 3
# 길 안내 제공 3
# 피크닉 3
# 버스 기다리기 3
# 직장 이동 3
# 벼룩 시장 3
# 가구 구입 3
# 근무 3
# 요가 3
# 의사 찾아가기 3
# 담배 3
# 대기 오염 3
# 짐 보관 3
# 의사 방문 3
# 발표 준비 3
# 파티 계획하기 3
# 옷 빨래 3
# 베이비시터 찾기 3
# 컴퓨터 사용하기 3
# 길을 잃다 3
# 긴급 전화 3
# 식료품점 3
# 복도 통행증 3
# 인상 받기 3
# 언어 배우기 3
# 지진 3
# 영어 선생님 3
# 의사를 만나다 3
# 버스 투어 3
# 결혼 선물 3
# 소변 검사 3
# 세탁소 3
# 병원에 가기 3
# 날씨 예보 3
# 엔터테인먼트 3
# 늦음 3
# 오해 3
# 옷 입기 3
# 면접 조언 3
# 선물 주기 3
# 아기 3
# 등산 가기 3
# 배웅 3
# 여행 가기 3
# 영화 리뷰 3
# 지하철 타기 3
# 우체국 3
# 영어 말하기 3
# 의사 진찰 3
# 카드 신청 3
# 외모 설명 3
# 직업 계획 3
# 성희롱 3
# 수업 추가 3
# 회사 규칙 3
# 시계 수리 3
# 자리 찾기 3
# 게임을 하다 3
# 과목 조언 3
# 고백 3
# 잘못된 주문 3
# 모블로깅 3
# 매운 음식 3
# 컴퓨터 사용 3
# 청구서 결제 3
# 집 청소하기 3
# 디저트 3
# 프로젝트 논의 3
# 근무 일정 3
# 기계 3
# 동창회 3
# 악기 연주 3
# 꽃 사기 3
# 꽃병 3
# 결혼 생활 3
# 술 3
# 건강 3
# 거짓말 3
# 직장 경험 3
# 열심히 공부하기 3
# 환자 방문 3
# 장례식 3
# 결제 3
# 병가 3
# 수업 선택 3
# 차량 구매 3
# 연결 항공편 3
# 선물 구매 3
# 계좌 개설하기 3
# 오스카 시상식 3
# 전화번호 3
# 정전 3
# 병원에서 3
# 돈 입금 3
# 고용 3
# 패션 잡지 3
# 연극 3
# 강의 3
# 비행 지연 3
# 에어컨 3
# 협력 3
# 코트 3
# 여권 신청 3
# 해외 여행 3
# 야구 경기 3
# 음악 취향 3
# 항공편 티켓 예약 3
# 바쁜 일정 3
# 한담 3
# 꿈의 집 3
# 아버지의 날 선물 3
# 경험 공유 3
# 실험 3
# 차량 렌트 3
# 자판기 3
# 피자 주문 3
# 가장 좋아하는 영화 3
# 월급 인상 3
# 실업 3
# 경로 확인 3
# 요금 3
# 택시 공유 3
# 식료품 쇼핑 3
# 수표 취소 3
# 식당 선택 3
# 골프 치기 3
# 책 대출하기 3
# 이상적인 집 3
# 건강 검진 3
# 나라 3
# 주유소 3
# 실직 3
# 축하 파티 3
# 지출 3
# 저녁 파티 3
# 펜팔 친구 3
# 직업 지원 3
# 경매 3
# 케이블 3
# 휴가를 가다 3
# 치과 방문 3
# 행복 3
# 휴가 경험 3
# 결제 방식 3
# 차 사고 3
# 대가족 3
# 전자상거래 3
# 음식 선택 3
# 공항으로 3
# 과목 3
# 보험 3
# 음악 듣기 3
# 자동차 수리 3
# 도둑 3
# 붐비는 버스 3
# 필름 현상 3
# 보고서 3
# 성과 평가 3
# 더운 날씨 3
# 식탁 차리기 3
# 사업 이야기 3
# 맞춤 정장 3
# 비행기 3
# 영업 시간 3
# 약 3
# 음식 서비스 3
# 잡지 3
# 크리스마스 계획 3
# 체크 인 3
# 대출 신청 3
# 논문 제출 3
# 사회 문제 3
# 세관 신고 3
# 쇼핑하러 가기 3
# 교통 규칙 위반 3
# 영어 능력 3
# 동물 3
# 아울렛 3
# 화장품 구매 3
# 화재 3
# TV 구매 3
# 자리 바꾸기 3
# 연례 건강검진 3
# 입사 지원 3
# 교통 규정 3
# 아내 3
# 부모님과 함께 살기 3
# 유학 3
# 카메라 3
# 중고차 3
# 바쁘다 3
# 뉴욕 3
# 기말고사 3
# 자전거 대여 3
# 이발소에서 3
# 죽음 2
# 승진하다 2
# 데크 건설 2
# 스케줄 2
# 소설 2
# 향수병 2
# 영국 여행 2
# 온라인 데이트 2
# 책 서비스 2
# 실수를 저지르다 2
# 관광 추천 2
# 이상한 소리 2
# 배구 경기 2
# 겨울 코트 구매 2
# 고기 구매 2
# 새 이웃 2
# 안티바이러스 프로그램 2
# 방 빌리기 2
# 의사 찾기 2
# 선생님에 대한 이야기 2
# 통근 수단 2
# 길 찾기 요청 2
# 시간 묻기 2
# 저녁 식사 예약 2
# 면접 기술 2
# 홍수 2
# 사회적 인사 대화 2
# 인사 변동 2
# 작별 인사 전화 2
# 당근 먹기 2
# 설득 2
# 강아지 2
# 기록적인 판매 2
# 음악 상자 2
# 공장 투어 2
# 호출기 2
# 중국 차 구매 2
# 핫팟 먹기 2
# 면접 결과 2
# 외화 환전 2
# 점심 잡담 2
# 음료 구매 2
# 소설 구매 2
# 언어 능력 2
# 우편 서비스 2
# 경기 해설 2
# 은행 업무 2
# 생일 서프라이즈 2
# 보증 2
# 앨범 구매 2
# 새 학교 2
# 테이블 2
# 추수감사절 2
# 스포츠에 대한 이야기 2
# 졸업식 2
# 해변 2
# 점심 주문 2
# 캐나다 2
# 첫 단어 2
# 사생활 2
# 지갑 분실 2
# 태국 음식 2
# 추수감사절 계획 2
# 일과 휴식 2
# 돈 관리 2
# 택시 호출 2
# 파트타임 일자리 2
# 가족 식사 2
# 대학에서의 처벌 2
# 내면의 아름다움 2
# 사교 대화 2
# 공부 또는 일 2
# 정보 확인 2
# 환경 2
# 교향악 콘서트 2
# 사업 거래 2
# 레코드 플레이어 2
# 판매 2
# 금융 서비스 2
# 메시지 2
# 끔찍한 하루 2
# 스케이팅 초대 2
# 경고 2
# 옷 사기 2
# 차량 문제 2
# 책 보내기 2
# 스웨터 2
# 설명 2
# 소포 2
# 스카프 구매 2
# 빈 방 2
# 심한 감기 2
# 매트리스 배송 2
# 대인관계 2
# 절도 2
# 바비큐 준비 2
# 빵집 2
# 일상대화 2
# 객실 등록 2
# 독감 걸리다 2
# 교통 수단에 대해 논의 2
# 의사소통 기술 2
# 뉴욕의 별명 1
# 결혼 상태 1
# 우울증 1
# 게임 보이 1
# 이상한 조합 1
# 충분한 수면 취하기 1
# 대략적인 가격 1
# 새차 1
# 재고정리 세일 1
# 포커 게임하기 1
# 병원에 가다 1
# 펀드 서비스 1
# 공포 영화 1
# 장비 1
# 삼촌 방문 1
# 노트 빌리기 1
# 파티 장소 1
# 업무 문제 1
# 수업 중 논쟁 1
# 늦게 집에 가다 1
# 친구들의 방문 1
# 사업 구조 1
# 새 차  1
# 비행기 놓치기 1
# 여행에 대해 논의 1
# 핸드백 쇼핑 1
# 사람에 대해 논의하기 1
# 휴가 즐기기 1
# 결혼에 대한 토론 1
# 해외 포로그램 1
# 이웃간의 분쟁 1
# 일의 가치 1
# 광고 싣기 1
# 건강에 신경쓰다 1
# 아파트에 대한 논의 1
# 누군가를 방문하다 1
# 정치 시스템 1
# 부엌의 신 1
# 시합에 지다 1
# 미인 대회 1
# 침대 구매 1
# 재단사 1
# 항공편 지연 1
# 떠나야 할 시간 1
# 시계에 대한 토론 1
# 생각 말하기 1
# 글쓰기 능력 1
# 산책 초대 1
# 쥐 잡기 1
# 식사와 요리 1
# 최종 후보 인터뷰 1
# 보결 1
# 잘못된 계산서 1
# 직장을 옮기다 1
# 베이징  1
# 엘리베이터에 갇힘 1
# 일요일 계획 1
# 청바지 금지 1
# 수리 요청 1
# 새 카메라 구입하기 1
# 가방 드는 것 돕기 1
# 급여 인출 1
# 매표기 1
# 피자 나눠 먹기 1
# 팀 빌딩 세션 1
# 재킷의 가격 1
# 수업 시간표 1
# 관리직원 1
# 매매 1
# 병가 신청 1
# 직장 승진 1
# 구매 및 판매 1
# 최종 성적 계산 1
# 손님 수 1
# 인력 1
# 자질 1
# 바가지 1
# 일회용 콘택트 렌즈 1
# 송금 통지서 1
# 기차 연착 1
# 거리 주차 1
# 연봉 1
# 멋진 게임 1
# 나쁜 영화 1
# 꽃 심기 1
# 수업 찾기 1
# 정부 1
# 잃어버린 샌드위치 1
# 휴가 끝 1
# 웨딩드레스 입어보기  1
# 나타샤는 #Person1#에게 그녀의 가족이 그녀를 보러 왔다고 말한다. 그 후 그들은 각자의 가족에 대해 이야기한다. 나타샤의 직계 가족은 매우 크다. #Person1#의 가족은 작고, 12살인 동생이 있다. 1
# 아내에 대한 대화 1
# 버스에서의 대화 1
# 미술 용품 구매 1
# 린다와의 대화 1
# 친구들 사이의 식사 1
# 정기예금 1
# 도둑맞은 차 1
# 치아 발치 1
# 출퇴근 시간 1
# 우수한 학생 1
# 작은 마을 1
# 여행 시장 1
# 면접 복장 1
# 급여 협상하기 1
# 아빠와의 대화 1
# 아이 키우기 1
# 외식 준비 1
# 버스 서비스 설문조사 1
# 부부 간의 논쟁 1
# 흉부 X-선 1
# 컨버터블 소파 1
# 채소 훔치기 1
# 준비 운동 1
# 도시의 전설 1
# 개미 왕국 1
# 할부 결제 1
# 옷의 색상 1
# 결혼식 준비 1
# 알리바이 필요 1
# 엄마와의 대화 1
# 에이즈 1
# 스포츠 경기 1
# 새 집 방문 1
# 누락된 CD 플레이어 1
# 구내식당의 음식 1
# 예술에 대한 관심 1
# 예상치 못한 승진 1
# 소소한 대화 1
# 인터넷   1
# 디지털 TV 1
# 탑슬 절차 1
# 지구 온난화 1
# 배터리 1
# 거주 위치 1
# 중국 시장 1
# 나노미터 1
# 수업 토론 1
# 정상에서의 경치 1
# 담소 1
# 직업 기회 1
# 돈 출금 1
# 회사에서의 논쟁 1
# 돈 아끼기 1
# 호텔 추천 1
# 다른 식사 예절 1
# 편지에 대한 제안 1
# 도둑 맞음 1
# 사이즈 교환 1
# 어메니티 요청 1
# 직급 승진 공유 1
# 마약상 체포 1
# 수공예품 구매 1
# 짐꾼 찾기 1
# 수업 성적 1
# 더 좋은 일자리 1
# 집으로 돌아가기 1
# 서커스 표 1
# 의상 매칭 1
# 컴퓨터 소프트웨어 1
# 필요한 책 1
# 지각  1
# 혼인 여부 1
# 올바른 버스 1
# 몸매 관리 1
# 새로운 직업 1
# 아파트 관리 1
# 미니바 재고 채우기 1
# 아름다운 드레스 1
# 늙음 1
# 누구의 잘못인가 1
# 사회적인 일상 대화 1
# 누군가를 꾸짖다 1
# 연애에 대한 토론 1
# 보험 논의 1
# 근무 허가에 대한 논의 1
# 채용 계약서 서명 1
# 휴대폰 서비스 1
# 사람 실종 신고 1
# 여행자 수표 구매 1
# 강도에 시달리다 1
# 개인적인 이야기 1
# 시험 걱정 1
# 재밌는 경험 공유 1
# 여자에게 대시하기 1
# 대인관계 위기   1
# 일기 예보 1
# 돌고래에 대한 토론 1
# 가족에 대한 이야기 1
# 뉴스 토론 1
# 욕조 파손 1
# 룸 서비스 주문 1
# 환경 토론 1
# 남자 친구 불평 1
# 역할 바꾸기 1
# 단어 가르치기 1
# 브레이크 수리 1
# 발신자 1
# 우편 주소 1
# 사교 기술 1
# 건망증 1
# 서프라이즈 생일 1
# 수출업자 1
# 미용실 활동 1
# 기차 놓침 1
# 포도 1
# 옥 1
# 주택 1
# 골프 1
# 이야기 1
# 이사하기 1
# 새 스케이트 1
# 양식 1
# 회사 일에 관한 토의
#  1
# 훌륭한 보고서 1
# 과정 수강 1
# 브랜디 1
# 사회보장 1
# 꽃에 물 주기 1
# 호스트 가족 1
# 무료 음료 제공 1
# 결석 1
# 시험 근무 1
# 재생 가능한 자원 1
# 마을에서의 생활 1
# 열성 팬 1
# 중국어 대회 1
# 서커스 1
# 클럽 활동 1
# 이웃에 대한 토론 1
# 비즈니스 서비스 1
# 직업 선호 1
# 음악 준비 1
# 로마인의 생활 스타일 1
# 출장 준비 1
# 교회 가기 1
# 반대 제안 1
# 좌석 선호 1
# 음주 문제 1
# 문제점 1
# 찻주전자 구매 1
# 돈 보내기 1
# 잘못된 결제 1
# 모험적인 투어  1
# 열쇠를 두고 나오다 1
# 정류장 놓침 1
# 경제법 1
# 필름 추천 1
# 채권 왕 1
# 타이타닉 1
# 찐 게 1
# 에너지 소비 줄이기 1
# 방 찾기 1
# 링크드인 1
# 음악가 토론 1
# 이야기하기 1
# 흡연 금지 1
# 폐암 1
# 내과 의사 찾기 1
# 요금을 사용하다  1
# 항공편 티켓 구매하기 1
# 결제 진행하다 1
# 보석 구매하기 1
# 주문을 배송하다 1
# 오래된 안티바이러스 소프트웨어 1
# 자전거의 이점 1
# 컴퓨터 연구실 1
# 클럽 회원권 1
# 쿠키를 먹다 1
# 존에 대해 이야기하기 1
# 사고를 목격하다 1
# 태국에서의 휴가 1
# 축하와 생일 1
# 사무실 생활 1
# 전시품 가격 1
# 시내로 가다 1
# 피 뽑기 1
# 구매 실패 1
# 업무에 대해 토론하다 1
# 동물 조건에 대해 토론하다 1
# 스카이다이빙 1
# 사냥 여행 1
# 방 열쇠 1
# 인터넷 연결 1
# 여유로운 사람들 1
# 습관 1
# 비건 1
# 쇼핑에 대한 대화 1
# 의사 인터뷰 1
# 나노미터의 설명 1
# 체검 1
# 영화를 보다 1
# 바지를 사다  1
# 다가오는 비 1
# 남편과 말다툼 1
# 거지 1
# 택시를 이용하다  1
# 디자이너 1
# 프랑스에서 머무르다 1
# 이탈리아로 가다 1
# 점심을 주문하다  1
# 항공 정보 1
# 교재 구매 1
# 책을 읽다 1
# 그림 그리기에 대한 격려 1
# 학교 성적 1
# 드레스 선택 1
# 부모의 재량 1
# 기사 1
# 웃긴 강도 1
# 점검 비용 1
# 애완동물의 습성 1
# 그릇 건네기 1
# 클라이드의 꿈 1
# 인생 원칙에 대해 논의하다 1
# 스커트 제작 1
# 손님 맞이 1
# 버스 정류장 1
# 맛있는 저녁 식사 1
# 패션 어워즈 1
# 행선지 1
# 지시 1
# 사회보장세 1
# 집 마련하기 1
# 인터뷰 알림 1
# 부가가치가 높은 서비스 1
# 파티 시간 1
# 풀오버 1
# 사람들에 대해 이야기하기 1
# 스카프를 구매하다 1
# 비만에 대해 논의하다. 1
# 리노베이션 대출 1
# 사적인 대화 1
# 자동차에 대해 논의 1
# 임대차 정보 1
# 옷 카탈로그 1
# 건강보험에 대해 논의 1
# 오늘의 활동 1
# 항공편 변경 1
# 기분 변화 1
# 새로운 지사 1
# 차에 대해 이야기하기 1
# 보험에 대해 논의하기 1
# 방과 후 계획 1
# 대기 1
# 성가신 일 1
# 급격하게 변한 기분 1
# 저녁 데이트 1
# 잉글리쉬 코너 1
# 라벨 변경 1
# 몇 가지 제안 1
# 새 가구 1
# 주식 시장 1
# 추모일 1
# 주근깨 사라지게 하기 1
# 동아리 가입 1
# 중국 부동산 가격 1
# 멕시코 식당 1
# 훌륭한 콘서트 1
# 스무 번 1
# 계산 서비스 1
# 다시 전화를 걸다 1
# 아름다운 날 1
# 과일 몇 가지 사가기 1
# 블로거 1
# 회의 주재 1
# 세 개의 방 예약 1
# 저녁 파티 매너 1
# 여행용 옷 1
# 라이브 음악 콘서트 1
# 학교에 대한 대화 1
# 금고 1
# 식단 1
# 사무용 장비 1
# 고장난 펜 1
# 언어 센터 1
# 정보 1
# 대학 가기 1
# 오만과 편견 1
# 체육관 1
# 발명품 1
# 차 타기 1
# 영화를 놓치다 1
# 양식 샘플 1
# 가슴 X-선 1
# 누군가를 걱정하는 것 1
# 정책 변화 1
# 도움 제안 1
# 장소 소개 1
# 주차 위반 딱지 1
# 급여 서비스 1
# 차 있는 화장실 1
# 의사 상담 1
# 여행 경험에 대한 토론 1
# 크리스마스 트리 준비 1
# 파티 복장에 대한 토론 1
# TV 쇼 토론 1
# 음식점 1
# 스킨케어 1
# 교육 시스템 1
# 졸업 논문 1
# 바닥선에 대한 논의 1
# 정부 법률 1
# 창고에서의 대화, 1
# 식물 확장 프로젝트 1
# 머리 염색 1
# 여권 검사 1
# 축구 스타 1
# 가족 배경 1
# 손님 문제 1
# 신용 한도 1
# 먹을 음식 1
# 자동차 여행 1
# 패션 아이디어 1
# 에스크로 서류 1
# 학교 떠나기 1
# 신문의 광고 1
# 춤 스텝 1
# 직원 혜택 1
# 시스템 업그레이드 1
# 남자 칭찬하기 1
# 송장 1
# 멀미약 1
# 날씨와 소풍 1
# 옷차림과 세일 1
# 보안 심문 1
# 수학 문제 1
# 빅뱅 이론 1
# 스노보딩 1
# 실업 수당 1
# 양식 도움 1
# 모델 디자인 1
# 패키지 추적 1
# 대학 공부에 대한 토론 1
# 귀신에 대한 토론 1
# 여가 시간 활동 1
# 보안 검사 1
# 헤어짐 1
# 농업과 산업 1
# 좋아하는 잡지 1
# 롤러장 1
# 미용 1
# 대나무 숲 1
# 인터뷰 스타일 1
# 수주로의 여행 1
# 커튼 1
# 토지 구매 1
# 기사 읽기 1
# 은행으로 가는 길 1
# 장갑 1
# 취미와 오락 1
# 환영회 1
# 서두름 1
# 항해 1
# VCR 또는 DVD 1
# 바에 가기 1
# 상품 선택 1
# 멜버른 동물원 1
# 경주 1
# 축제 1
# 집으로 가기 1
# 관계 구축 1
# 기차 표 1
# 사회 모임 1
# 택시기사와 대화 1
# 환승 1
# 크리스마스 이브의 음주운전 1
# 오후의 계획 1
# 브라질의 축구 1
# 풍경 묘사 1
# 해리 포터 1
# 향림 1
# 연예인 1
# 세관 1
# 관용구 1
# 돌보다 1
# 도난당한 돈 1
# 커리어 1
# 컴퓨팅 시스템 1
# 쿠션 구매 1
# 지하철역 1
# 하차 1
# 계산 내기 1
# 후식 1
# 조깅 활동 1
# 음악 유형 1
# 음악 토론 1
# 공부와 일 1
# 여자를 좇다 1
# 마장 1
# 천둥과 번개 1
# 과학 시험 1
# 엉망으로 만들다 1
# 하드 록 카페 1
# 컴팩트 카메라 1
# 새 드레스 1
# 배달 1
# 화재에 대한 반응 1
# 경로 찾기 1
#
#
# 기타 구입 1
# 안경 1
# 컨설팅 서비스 1
# 카메라 대여 1
# 임신 1
# 장식 스타일 1
#
# 특허 토론 1
# 진료 1
# 평균 수명 1
# 고민 1
# 오픈 하우스 파티 1
# 노래 1
# 엘리베이터의 대화 1
# 은행 입금 1
# 외화 구매 1
# 침입 사건 신고 1
# 보너스 계획 1
# 고객의 불만 1
# 영화 후기 1
# 도난 1
# 약물 부정행위 1
# 임대 서비스 1
# 학비 마련 1
# 투어 가이드 1
# 컴퓨터 실력 1
# 다툼 1
# 가격 경쟁 1
# 운전 서비스 1
# 기대하는 급여 1
# 에세이 쓰기 1
# 방송 1
# 교통 규정 위반 1
# 파티 음료 1
# 호화로운 생활 1
# 형제 자매 간의 관계 1
# 지각에 대한 설명 1
# 언어와 문화 1
# 사과와 해결책 1
# 검토 1
# 질문 게임 1
# 투어 안내 1
# 차를 치다 1
# 여행에 대한 불만 1
# 날씨와 계절 1
# 결혼했다 1
# 스테레오 보증 1
# 이웃의 이사 1
# 거울 구매 1
#
#  데려다 주기 1
# 장미 죽이기 1
# 침실 세트 구매 1
# 가족 사진 1
# 투표소 확인 제안 1
# 직장 제안 1
# 비즈니스 저녁 식사 변경 1
# 생활 경험 교환 1
# 만족스러운 머리 1
# 늦은 도착 1
# 재혼을 두려워하는 1
# 냉각기간 1
# 기술에 대한 감탄 1
# 인포매니아 1
# 같은 이유로 거절 1
# 핫팟 1
# 소풍 결정 1
# 잘못된 기억 1
# 캠핑 조언 1
# 생활에 대한 이야기 1
# 정의 요구 1
# 직위 지원 1
# 전공에 대해 묻기 1
# 표 구매 안내 1
# 휴일 여행 1
# 친구를 위한 걱정 1
# 함께 식사 1
# 생일 계획 1
# 폭염 1
# 매력적인 방 1
# 투어 소개 1
# 오래된 영화 1
# 옛 친구들 1
# 강의실 찾기 1
# 영화 놓치기 1
# 그림 인쇄하기 1
# 부모님의 사랑 이야기 1
# 멀미 1
# 식사 포장 1
# 이발 1
# 향수병에 걸림 1
# 물에 빠지다 1
# 다운된 컴퓨터 1
# 방문자 환영 1
# 진부한 영화 1
# 역사적인 커피하우스 1
# 수영하는 법 1
# 어머니 1
# 잃어버리고 찾기 1
# 짧은 발표 1
# 구내식당 1
# 운동을 하다 1
# 매니저 만나기 1
# 우연 1
# 핸드백 대여 1
# 과거 회상 1
# 사전 가져가기 1
# 사회적인 잡담 1
# 셔츠 구매 1
# 기타 1
# 넥타이 교환 1
# 전기 1
# 유럽 투어 1
# 유전학 1
# 비밀을 유지하기 1
# 좋은 조언 1
# 아침 조깅 1
# 해부학 수업 1
# 가르치다 1
# 기업 계약 저축 1
# 입원 1
# 추가 수업 1
# 퀴즈 1
# 새로운 스웨터 1
# 자전거 횡단 여행 1
# 할아버지의 생일 1
# 서점에서 1
# 개인 특성 1
# 작업대 측정 1
# 배고픔 1
# 뼈에 대해 1
# 브라질에 가기 1
# 오션 파크 1
# 여행 교통 수단 1
# 운전 과정 1
# 연설 대회 1
# 알레르기 반응 1
# 공원 산책 1
# 휴가 내용 1
# 전화번호 변경 1
# 커피 그라인더 1
# L/C 1
# 근육질 몸 1
# 성적 상담 1
# 기차 타기 1
# 북 빌딩 1
# 생일축하 1
# 가장 좋아하는 음악 1
# 추첨 1
# 작업 전 대화 1
# 스텔라의 가족 1
# 아침 식사 구매 1
# 태양 매트 구입 1
# 여자친구와의 이별 1
# 동료들 간의 대화 1
# 식사 중 1
# 새 재킷 구매 1
# 밴 빌리기 1
# 런던 방문 1
# 사회적인 캐주얼 대회 1
#
# 병원에서 1
# 첫 출근날 1
# 대학원 참석 1
# 음식 사업 1
# 훈련 일정 1
# 런던 여행 1
# 책 돌려주기 1
# 텔레비전 구매 1
# 정보 제공 1
# 일정 검토하기 1
# 쇼핑 영수증 1
# 논문 논의 1
# 인터넷 문제 1
# 귀중품 맡기기 1
# 달러, 통화 투자 1
# 호텔 서비스, 편의시설 1
# 흥정, 임대 1
# 수하물 찾기, 세관 통과 1
# 자녀 교육 1
# 공부 선호도 1
# 혼혈/국제 결혼 1
# 편지 답장 1
# 파티에 가는 중 1
# TV 프로그램, 노인들 1
# 나쁜 성적 1
# 인터뷰 일정 1
# 직장 스트레스 1
# 체중 감량, 식습관 1
# 찬 물 1
# 고기 먹기 1
# 마이크에 대해 이야기하는 중 1
# 방 칠하기 1
# 고장난 차 1
# 더블 데커 버스 1
# 치마 시착 1
# 해고당하다 1
# 영어 수업, 문학 1
# 주문 포장하기 1
# 월간 계획 1
# 주차 위치 1
# 백팩 1
# 체중 감량 팁 1
# 영수증 분실 1
# 정장 만들기 1
# 전화를 놓친 상황 1
# 카드 게임, 추억 1
# 휴대폰 사용 1
# 차 문화 1
# 인터뷰, 졸업, 구직 활동 1
# 레스토랑에서 주문하기 1
# 쇼핑, 일상 대화 1
# 컴퓨터 광고 차단 1
# 잡담 1
# 조언, 학습 1
# 싸움과 우정 1
# 활동, 콘서트 1
# 박사학위, 현실, 꿈 1
# 술에 취한 사람의 이야기 1
# 작업 1
# 자연 재해 뉴스 1
# 영감을 주는 아이디어 1
# 시간과 날짜 1
# 공원에 가기 1
# 재능 있는 소년 1
# 수익과 위험 1
# 누군가를 기다리다 1
# 플로리다로 이사하기 1
# 착신자 부담 전화 1
# 남자 배구 세계 선수권 대회 1
# 자선 활동 초대 1
# 노인들과 함께 살기 1
# 인터넷 검색 1
# 러브 버그 1
# 좋아하는 꽃 1
# 인터넷 연결하기 1
# 박물관 방문 1
# 아이들과 놀기 1
# 이중 언어가 가능한 비서 1
# 항주 요리 1
# 메리의 집에 가다 1
# 음반 구매 1
# 배우에 대해 토론하기 1
# 대기 오염물질 1
# 인생에 대해 토론하기 1
# 항공권 예약 서비스 1
# 전화 상담 서비스 1
# 부서 둘러보기 1
# 록 페스티벌 1
# 경계심 1
# 음식 재조리 1
# 튀긴 음식 1
# 해로즈 백화점 1
# 해러게이트 소개 1
# 시끄러운 이웃 1
# 변명을 만들다 1
# 몸 상태가 좋지 않음 1
# 차 만들기 1
# 일반석 항공권 1
# 유창한 영어 1
# 학교 규칙 1
# 편집증 1
# 정보 전달 1
# 오랜 친구들 1
# 항공편 잡기 1
# 인생 1
# 럭키 파티 1
# 건강에 관한 테스트 1
# 집 상태 1
# 수업 복습하기 1
# 출혈 1
# 해변 즐기기 1
# 재미있는 것을 하다재미있는 것을 하다 1
# 물건 잃어버리기 1
# 비밀 계획 1
# 연락처 정보 1
# 탑승권 1
# 일상 업무 1
# 제품 판매 문제 1
# 두 후보자 1
# 선생님의 행동 1
# 새로운 식당 1
# 학교 물품 구입 1
# 연인들의 달콤한 말들 1
# 점심과 저녁 1
# 장소 찾기 1
# 겨울 날씨 1
# 먼지 닦기 돕기 1
# 하와이 여행 1
# 항공 여행 1
# 시리얼 사기 1
# 문서 확인 1
# 약속 어기기 1
# 댄스 연습 1
# 호텔 체육관 1
# 근무 중 1
# 크리스마스 축하 1
# 영어 실력 향상 1
# 문신 재고 1
# 합의에 이르다 1
# 미리 주문하기 1
# 이름 선택 1
# 시험 시간 1
# 스웨덴의 날씨 1
# 세부 사항 확인 1
# 전화 걸다 1
# 모기지 1
# IQ 또는 EQ 1
# 휴가 준비 1
# 음악 산업 1
# 전쟁과 처벌 1
# 스키 초대 1
# 저녁 활동 1
# 불면증에 대한 조언 1
# 중국어에 대한 조언 1
# 특이하게 큰 신발 1
# 발표 녹화 1
# 학교 클럽 만들기 1
# 상사에게 칭찬받음 1
# 피곤한 아침 1
# 이사 정보 1
# 좌석 예약 1
# 블루워터 월드 1
# 청소 세일 1
# 바다 1
#
# 뮤즈 콘서트 1
# 스페인어 1
# 캔들 라이트 디너 1
# 메인 요리 1
#
# 자동차 1
# 무역 1
# 지인 만남 1
# 요병 샘플 1
# 지갑 구매 1
# 바쁨 1
# 역사학자 1
# 실망 1
# 보너스 1
# 학교 외부의 아파트 1
# 산책 가기 1
# 고립된 생활 1
# 검사 샘플링 1
# 늦은 체크아웃 1
# 역사 박물관 1
# 포터 교수의 강의 1
# 라이트 형제 1
# 신문 기사 1
# TV 세트 1
# 손수건 1
# 유료 전화기 1
# 심장마비 1
# 점수 1
# 새우 롤 1
# 화를 내다 1
# 귀여운 인형 1
# 언어 차이 1
# 비즈니스 거래 1
# 인체공학 1
# 비공개 번호 1
# 손상된 선물 1
# 친구 관계 퀴즈 1
# 목요일의 역사 1
# 온라인 광고 1
# 열 1
# 호빗 1
# 대여 1
# 공양 거짓말 1
# 포장 주문하기 1
# 부모를 위한 조언 1
# 분실 신고 1
# 이루어지지 않은 계획 1
# 모자 선택하기 1
# 대기 시간 1
# 메인 코스 전 1
# 이자율 1
# 사건 보고 1
# 좌석 선택 1
# 정보 수집 1
# 푸시업 1
# 논문 찾기 1
# 무관심 1
# 건강에 무관심 1
# 과대평가된 드레스 1
# 미용과 뷰티 1
# 가방 포장 1
# 평화단체 1
# 수입 품목 1
# 원단 선택 1
# 디저트와 음료 주문하기 1
# 집 구입 1
# 양복 구매 1
# 범인에 대한 질문 1
# 흑인 학생들 1
# 통화 전달 1
# 택시를 이용하는 상황. 1
# 해외 유학 계획 1
# 아파트에 대해 문의하기 1
# 흡연 중단 1
# 의사 찾아보기 1
# 세계 여행자 1
# 음식 낭비 줄이기 1
# 시스템 다운 1
# 급여 정책 1
# 근무 변경 1
# 스폰서 이벤트 1
# 인출 1
# 직무 정보 1
# 간단한 대화 1
# 결혼 기념일 축하 1
# 음악 클럽 1
# 냄새 1
# 이집트 여행 1
# 방문객 맞이하기 1
# 고블랭 구매 1
# 규칙을 어기다 1
# 강의 준비하기 1
# 야망 1
# 보습제 구매 1
# 패션 청바지 1
# 놀라운 책 1
# 자랑스러운 엄마 1
# 선물 장미 1
# 제품 변경 1
# 컴퓨터 빌리기 1
# 영화 티켓 예약 1
# 영국의 교통 1
# 성공적인 면접 1
# 손상된 상품 1
# 글 완성하기 1
# 계획 보내기 1
# 언어 공부 1
# 극한 스포츠 1
# 중국 스타일의 옷 1
# 어제 저녁 1
# 커플의 다툼 1
# 제인에 대한 이야기 1
# 새로운 여자 1
# 상품 포장 1
# 핫라인 1
# 남자친구의 엄마 만나기 1
# 런던에 대한 감정 1
# 숙제를 잃어버림 1
# 비타민 알약 복용 1
# 교통수단 형태 1
# 집 리모델링 1
# 잡지 찾기 1
# 상담 서비스 1
# 집 돌보기 1
# 공격을 만나다 1
# 도자기 1
# 만화 1
# 논문 작업 1
# 비오는 날의 대화 1
# 우주에 대한 인터뷰 1
# 21번째 생일 1
# 캐나다 국가 1
# 꿈의 직업 1
# 담배 끊기 실패 1
# 부엌에서의 아이들 1
# 변경된 정책 1
# 카메라 성능 1
# 인스턴트 음식 1
# 맞지 않는 수트 1
# 토끼 키우기 1
# 강도 뉴스 토론 1
# 편안한 여행 1
# 은행 용품 분실 1
# 약속 접수 1
# 차량용 텔레비전 1
# 컴퓨터 충돌 1
# 술에 대한 대화 1
# 출발 준비 1
# 문구류 구매 1
# 대만에서의 가르치기 1
# 시험 전에 휴식하기 1
# 코비 브라이언트 1
# 자동차 보험 1
# 모터사이클 사고 1
# 무역 센터 1
# 전공 선택 1
# 학교 문제 1
# 다이어트와 유혹 1
# 유지보수 중단 1
# 현지 특색 과자 1
# 고기 판매대 1
# 집에 있는 쥐 1
# 의사 예약 1
# 종이 만들기 1
# 회사 복지 1
# 여성용품 1
# 학교 교복 1
# 불운한 초대 1
# 도시 인상 1
# 계산 정산 1
# 교재 1
# 음식점의 전화번호 1
# 네일 하기 1
# 가족에 대한 대화 1
# 셔츠 1
# 길찾기 1
# 모자 1
# 출근 방법 1
# 돈 지불하기 1
# 파이프 파손 1
# CPR 1
# 수습생 1
# 오토바이에 대해 문의하기 1
# 커피와 케이크 구매 1
# 가장 좋아하는 TV 프로그램 1
# 슈퍼마켓과 작은 가게들 1
# 전자레인지 구매 1
# 음식 추천 1
# 에스크로 서류 서명 1
# 분실된 책 1
# 장단점 1
# 땡땡이 치다 1
# 지치다 1
# 언어를 구사하다 1
# 추가 작업 1
# 번호 주기 1
# 프로젝트 진행 1
# 남극 1
# 러닝 그룹 1
# 여자친구의 차 빌리기 1
# 401k 1
# 나쁜 머리 자르기 1
# 거스름돈 요청 1
# 중국의 핑퐁 1
# 지하철 역 1
# 소문에 대한 이야기 1
# 신문의 기사들 1
# 방에 있는 바퀴벌레 1
# 집에 대한 대화 1
# 자금 변환 1
# 예약 시간 변경 1
# 새로운 사무실 1
# 조각상 1
# 하이킹 계획하기 1
# 놀이공원에서 1
# 룸메이트 찾기 1
# 꽃 구매 1
# 사내정치 1
# 바에 가다 1
# 생활 문제 1
# 봄 축제의 믿음 1
# 과일과 채소 1
# 구애 1
# 세일 1
# 1등 상 1
# 요리학교 다니기 1
# 찜 게 1
# 수축률 1
# 결혼한 사람들 1
# 화산재 1
# 그룹 조직하기 1
# 새로운 장난감 1
# 사이클링 1
# 기부금 모집 1
# 동료 대화 1
# 네일 폴리시 구입 1
# 생일 선물 사기 1
# 파리에 대한 이야기 1
# 좋은 소식 공유 1
# 맥주 주문 1
# 여름 과정 1
# 쓰레기 처리 1
# 애완견 1
# 무료 커피 1
# 은행털이 1
# 올림픽 세일링 1
# 중국 전통 오페라 1
# 전화 사용 1
# 수출 L/C 1
# 쇼핑몰 1
# 퀼트 판매 1
# 세미나 참석 1
# 알바 웹 디자이너 1
# 학생 여행 카드 1
# 과목 변경 1
# 여가 활동에 대해 논의 1
# 상품 구매 1
# 쇼핑 조언 1
# 머리빗 1
# 샌디에고 1
# 공지사항 1
# 영문학 수업 1
# 누군가를 기분 나쁘게 하다 1
# 전통 중국 의학 1
# 원격 학습 과정 1
# 여행 연기 1
# 지하철 이용하기 1
# 개요 작성 1
# 면접 요청 1
# 자유의 여신상 1
# 원피스 구매 1
# 새 자전거 1
# 옷차림과 신발 1
# 재고 부족 1
# 동전 정리하기 1
# 테이블 서빙 1
# 엘리베이터 문제 1
# 질문과 답변 1
# 경매에 대해 이야기하기 1
# 소설에 대해 이야기하기 1
# 대중교통 이용 1
# 호텔 객실 전화 1
# 운전 규칙 1
# 선생님-학생 대화 1
# 소개팅 전 1
# 파티 준비하기 1
# 병원 검사 1
# 식당에서 식사하기 1
# 운전 가르치기 1
# 레스토랑에서 식사하기 1
# 방문에 대한 조언 1
#
# 호텔 객실 예약 1
# 사랑에 관한 주제 1
# 축구 토론 1
# 직장에서의 자기소개 1
# 결혼 일정 1
# 관광 정보 1
# 직장 내 여성 1
# 하루 보내기 1
# 그린씨는 #Person1#에게 미국에서 대부분의 학생들이 공립학교에 다니며 특정 유형의 학생들이 사립학교에 다닌다고 말합니다. 공립학교는 모두에게 무료이며 제한이 없지만 매우 다를 수 있다고 말합니다.미국의 학교 1
# 건물들 1
# 포인트 벽지 구매 1
# 수출 조사 1
# 찢어진 상처를 입다 1
# 이사벨스에 가다 1
# 잡지 읽기 1
# 수리 서비스 1
# 화가 나 보임 1
# 배가 아픔 1
# 물건 사기 1
# 수도꼭지 1
# MRT 타기 1
# 전화기 사용법 1
# 의사에게 진찰 받기 1
# 원피스 입어보기 1
# 에그타르트 1
# 차 세트 1
# 나라 간의 차이점 1
# 오토바이 1
# 치마 만들기 1
# 흡연 포기 1
# 업데이트 1
# 디스콤구골레이션 1
# 소포 배달 1
# 비자 신청 면접 1
# 정장 찾아오기 1
# 누군가를 찾는다 1
# 항해 이야기 1
# 제인의 결혼식 1
# 토요일의 계획 1
# 무엇을 할 것인가 1
# 항공료 1
# 카드 거절 1
# 보너스 받기 1
# 당선자 1
# 시끄러운 사람들 1
# 차 제공 1
# 브로드밴드 설치 1
# 누군가를 만나러 가다 1
# 티켓 얻기 1
# 에든버러 여행 1
# 착신호 전환 1
# 티켓 서비스 1
# 컴퓨터에 연관된 문제 1
# 과거의 추억 1
# 온라인 쇼핑 관련 토론 1
# 수상 1
# 잠긴 차 키 1
# 여행 계획 짜기 1
# 필기 노트 빌리기 1
# 수영 가기 1
# 검색 엔진 1
# 사람 추천 1
# 돈 입금하기 1
# 지역 뉴스 1
# 해변 휴가 1
# 함께 식사하기 1
# 다양한 사과 종류 1
# 영화에 대한 의견 1
# 역사에 대해 이야기하기 1
# 계좌 유형 선택 1
# 모임에 불참하기 1
# 비행 팁 1
# 런던으로 떠나다 1
# 저녁 식사 약속에 지각 1
# 수학 공부 1
# 병의 원인 1
# 드레스 고르기 1
# 평판 조회 1
# 이성관계 문제 1
# UFO 토론 1
# 아침 대담 프로 1
# 교통 안전 1
# 여행 경험담 공유 1
# 사전 구매 1
# 지저분한 아파트 1
# 흥미로운 기사들 1
# 은행 수표 1
# 컴퓨터 조작 1
# 주차증 1
# 컴퓨터 교체 1
# 스승의 날 1
# 신청서 1
# 구직 인터뷰 1
# 학창 시절 성적 1
# 고령화 인구 1
# 수강 과목 조언 1
# 이직 기회 1
# 옷 준비 1
# 채용 응모 1
# 채용 면접 1
# 등록 서비스 1
# 새로운 선생님들 1
# 약국에서 1
# 벌 받은 경험 1
# 원피스 토론 1
# 배송 일정 변경 1
# 뒤처지다 1
# 표 찾기 1
# 100주년 행사 1
# 복제에 대한 토론 1
# 기름값 부담 1
# 사회적 예절 1
# 컴퓨터의 주요 부분 1
# 안전 금고 대여 1
# 항공편 티켓 구매 1
# 전기 발전기 판매 1
# 버스 여행 1
# 장식품 찾기 1
# 픽업 1
# 소통하는 방법 1
# 예산 1
# 개봉 첫날 1
# MP4 플레이어 1
# 불법 출국 1
# 도난 사고 1
# 장학금 1
# 마크 트웨인 1
# 주택 검사 1
# 골치 아픈 사람 1
# 우편 발송 1
# 중국어 배우기 1
# 범행은 탄로가 나는 법 1
# 첫눈에 반한 사랑 1
# 점쟁이 1
# 기자가 되는 것 1
# 경찰 조사 1
# 영리한 범죄자들 1
# 광고료 1
# 수업 지시 1
# 상하이 날씨 1
# 손금보기 1
# 기다림 1
# 세일 쇼핑 1
# 점심 약속 잡기 1
# 파란색 통 옮기기 1
# 분실 수하물의 상황 1
# 컴팩트 카 1
# 사업상 약속 1
# 이메일 발송 1
# 게임하기 1
# 비행 확인 1
# 컴퓨터 게임하기 1
# 레오에 대한 소문 1
# 학생들 사이의 대화 1
# 사라진 스웨터 1
# 공연 관람 1
# 빠른 세탁 1
# 팔 부상 1
# 범죄를 저지르다 1
# 아이 돌보기 1
# 반항아 아들 1
# 냄비 구매 1
# 자기 홍보 1
# 돈 문제 1
# 항공권 변경 1
# 정장 대여 1
# 플라스틱 재활용 1
# 통장 분실 1
# 문서 찾기 1
# 방문 국가들 1
# 배달 서비스 1
# 쉴라에 대해 이야기하기 1
# 함께 요리하기 1
# 젊은 패션 디자이너 1
# 혼동의 외출 1
# 점쟁이에 대한 이야기 1
# 우는 아기 1
# 잡지에 대한 태도 1
# 댓글 1
# 밀러 박사의 강의 1
# 올림픽 표어 1
# 진로 고민 1
# 버키 카드 1
# 남은 음식 포장하기 1
# 권위 무시 1
# 연극 관람 1
# 장사 1
# 심한 압박감 1
# 교통 법규 1
# 작가 되기 1
# 여름방학 계획 1
# 파티용 의상 1
# 여름방학 알바 1
# 호텔에서 일하기 1
# 음악 강의 1
# 쿵푸 영화 1
# 사무 자동화 1
# 새 명함 1
# 알버트 아인슈타인 1
# 도심 생활 1
# 인터넷 연애 1
# 저녁 약속 취소 1
# 객실 서비스 보고서 1
# 우편 요금 1
# 강습 수강 1
# 서점에 가다 1
# 건강에 해로운 식습관 1
# 택배 발송 1
# 실직 후 1
# 콤팩트 카 1
# 소비자 불만 접수 1
# 아이스크림 주문 1
# 은행 강도 사건 1
# 선택과목 1
# 중국의 새해맞이 1
# 휴가 기간 1
# 약속 시간 조정 1
# 초면인 사람 만나기 1
# 핸드백 구매 1
# 애정 생활 1
# 실종된 형님 1
# 부동산 매물 방문 1
# 이국적 음식 1
# 과거의 업무 성과 1
# 교통체증에 대한 토론 1
# 소풍 초대 1
# 유년기 경험 1
# 교환 요청 1
# 스트리트 슈즈 구매 1
# 휴가지 논의 1
# 음악회 1
# CEO에 대한 논의 1
# 팔찌 1
# 바깥 전망 1
# 우산 1
# 휴가 논평 1
# 치과 치료 1
# 객실 변경 1
# 정산 1
# 손해 보상 1
# 보통예금 계좌 1
# 고객 불만 항의 1
# 시험 합격 1
# 영화에 대한 토론 1
# 초면의 만남 1
# 수영장 1
# 새 코트 자랑 1
# 개인 인터넷 뱅킹 1
# 시험 접수 1
# 미술 대회 1
# 토론토 1
# 생활 스타일 1
# 유령을 본 경험 1

# %%
# 상위 5개의 topic을 리스트로 저장
top_topics = ['일상 대화', '쇼핑', '직업 면접', '전화 통화', '음식 주문']

# 각 topic에서 샘플 2개씩 추출
sampled_data = total_df[total_df['topic'].isin(top_topics)].groupby('topic').apply(lambda x: x.sample(2))

# 결과 출력
print(sampled_data)

sampled_data.to_csv("../dataset/top5_samples.csv", index=False)
# Out:
#                    fname                                           dialogue  \
# topic
# 쇼핑    8758    train_8758  #Person1#: 후, 점점 피곤해지네, 제닌, 긴 하루였어.\n#Person2#...
#       296      train_296  #Person1#: 저는 거실에 새로운 가구 세트가 필요해요.\n#Person2#:...
# 음식 주문 4400    train_4400  #Person1#: 실례합니다. 아침식사 되나요? \n#Person2#: 네, 유럽...
#       12447  train_12450  #Person1#: 이제 주문하실 준비가 되셨나요, 선생님? \n#Person2#:...
# 일상 대화 9481    train_9481  #Person1#: 사라야. 너 정말 힘들어 보여. 무슨 일 있었어?\n#Perso...
#       8949    train_8949  #Person1#: 데이비드, 왜 방을 청소하지 않았어?\n#Person2#: 기분...
# 전화 통화 10532  train_10532  #Person1#: 안녕하세요.\n#Person2#: 안녕, 수. 나는 너의 기하학...
#       9306    train_9306  #Person1#: 안녕하세요, 스미스 부인의 비서입니다.\n#Person2#: 안...
# 직업 면접 2298    train_2298  #Person1#: 앉으세요, 존슨 씨. 학교 수업에 대해 좀 더 말씀해 주시겠어요...
#       6782    train_6782  #Person1#: 왜 선생님이 되고 싶으신가요?\n#Person2#: 그것은 제가...
#
#                                                        summary  topic  \
# topic
# 쇼핑    8758   메리는 현금이 부족해서 아이 쇼핑을 하려고 했지만 아름다운 드레스를 발견한다. 제닌...     쇼핑
#       296    #Person1#은 새로운 가구 세트를 원한다. #Person2#는 자신의 것을 이...     쇼핑
# 음식 주문 4400      #Person1#이 #Person2#의 도움을 받아 미국식 아침식사를 주문했습니다.  음식 주문
#       12447  #Person2#는 #Person1#의 도움으로 크랩 칵테일, 계란 수프, 그리고 ...  음식 주문
# 일상 대화 9481   사라는 #Person1#에게 할머니가 돌아가셨고, 할머니가 돌아가실 때 그녀가 그곳...  일상 대화
#       8949   데이비드는 여자친구가 자신을 헐뜯었다는 사실 때문에 우울해한다. #Person1#은...  일상 대화
# 전화 통화 10532  빌 파커가 수에게 전화를 걸어 과제에 대한 도움을 청한다. 그는 그들이 기하학 문제...  전화 통화
#       9306   존슨 씨가 전화를 걸어 #Person1#에게 목요일에 회의가 있다는 것을 스미스 부...  전화 통화
# 직업 면접 2298   #Person1#은 존슨에게 직업 면접을 진행합니다. 존슨은 역사, 지리, 수학에 ...  직업 면접
#       6782   #Person2#는 #Person1#에게 항상 선생님이 되고 싶었다고 말하고 영어 ...  직업 면접
#
#              dialogue_length  summary_length  is_train
# topic
# 쇼핑    8758             416.0            64.0         1
#       296              335.0            72.0         1
# 음식 주문 4400             136.0            46.0         1
#       12447            473.0            66.0         1
# 일상 대화 9481             697.0           109.0         1
#       8949             308.0            75.0         1
# 전화 통화 10532            723.0            94.0         1
#       9306             460.0            90.0         1
# 직업 면접 2298             449.0           115.0         1
#       6782             191.0            63.0         1
# /tmp/ipykernel_700401/263127930.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_data = total_df[total_df['topic'].isin(top_topics)].groupby('topic').apply(lambda x: x.sample(2))

# %% [markdown]
# # 3.특수 문자열

# %%
# 특수 문자열 패턴 찾기 함수
def find_special_strings(text):
    return re.findall(r'#\w+#', text)

total_df['dialogue_special_strings'] = total_df['dialogue'].apply(find_special_strings)
total_df['summary_special_strings'] = total_df['summary'].apply(find_special_strings)

# total_df[['dialogue_special_strings', 'summary_special_strings']].head()
unique_dialogue_strings = set([item for sublist in total_df['dialogue_special_strings'] for item in sublist])
unique_summary_strings = set([item for sublist in total_df['summary_special_strings'] for item in sublist])

print(unique_dialogue_strings)
print(unique_summary_strings)
# Out:
# {'#CardNumber#', '#Person3#', '#Email#', '#PassportNumber#', '#SSN#', '#Address#', '#Person5#', '#CarNumber#', '#Person4#', '#Person2#', '#Person#', '#Person7#', '#DateOfBirth#', '#Person1#', '#Person6#', '#PhoneNumber#'}
# {'#Person3#', '#Person4#', '#Person2#', '#사람1#', '#Person7#', '#Person1#', '#Person6#'}

# %%
# '#Person#'을 포함하고 있는 행을 찾는 함수
def contains_person_string(strings):
    return any('#Person#' in s for s in strings)

df_contains_person = total_df[total_df['dialogue_special_strings'].apply(contains_person_string) | total_df['summary_special_strings'].apply(contains_person_string)]

for idx, dialogue in enumerate(df_contains_person['dialogue']):
    print(f"Row {idx}: {dialogue}\n")
# Out:
# Row 0: #Person1#: 지미의 성적표가 오늘 왔어.
# #Person#: 한번 봐볼까. 이게 뭐야? 성적이 어디에 있지?
# #Person1#: 샘, 지미는 3학년이야! 학교에서 배우는 각 과목 아래에 보면, 지미가 1에서 3까지의 점수를 받은 걸 볼 수 있어. 1은 지미의 성취도나 작업이 우수하다는 뜻이야. 예를 들어 여기 과학에서는 지미가 2를 받았는데, 이건 잘했다는 뜻이야.
# #Person2#: 여기 체육은?
# #Person1#: 체육에서는 3을 받았으니까, 이건 못했다는 뜻이네. 우리가 지미랑 같이 연습해야겠다.
# #Person2#: 너무 헷갈려! 우리 때는 잘하면 A나 B를 받았고, 시험을 못 보면 F를 받았잖아!

# %%
# 대체할 문자열 매핑 딕셔너리
replace_dict = {
    '#Person#': '#Person2#',
    '#사람1#': '#Person1#'
}

def replace_strings(text, replace_dict):
    for old_str, new_str in replace_dict.items():
        text = text.replace(old_str, new_str)
    return text

total_df['dialogue'] = total_df['dialogue'].apply(replace_strings, replace_dict=replace_dict)
total_df['summary'] = total_df['summary'].apply(replace_strings, replace_dict=replace_dict)
total_df[['dialogue', 'summary']].head()
# Out:
#                                             dialogue  \
# 0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
#
#                                              summary
# 0  스미스씨가 건강검진을 받고 있고, 호킨스 의사는 매년 건강검진을 받는 것을 권장합니...
# 1  파커 부인이 리키를 데리고 백신 접종을 하러 갔다. 피터스 박사는 기록을 확인한 후...
# 2  #Person1#은 열쇠 한 묶음을 찾고 있고, 그것을 찾기 위해 #Person2#...
# 3  #Person1#은 #Person2#가 여자친구가 있고 그녀와 결혼할 것이라는 사실...
# 4  말릭이 니키에게 춤을 요청한다. 말릭이 발을 밟는 것을 신경 쓰지 않는다면 니키는 ...

# %%
## 결과 확인
total_df['dialogue_special_strings'] = total_df['dialogue'].apply(find_special_strings)
total_df['summary_special_strings'] = total_df['summary'].apply(find_special_strings)

# total_df[['dialogue_special_strings', 'summary_special_strings']].head()
unique_dialogue_strings = set([item for sublist in total_df['dialogue_special_strings'] for item in sublist])
unique_summary_strings = set([item for sublist in total_df['summary_special_strings'] for item in sublist])

print(unique_dialogue_strings)
print(unique_summary_strings)
# Out:
# {'#CardNumber#', '#Person3#', '#Email#', '#PassportNumber#', '#SSN#', '#Address#', '#Person5#', '#CarNumber#', '#Person4#', '#Person2#', '#Person7#', '#DateOfBirth#', '#Person1#', '#Person6#', '#PhoneNumber#'}
# {'#Person3#', '#Person4#', '#Person2#', '#Person7#', '#Person1#', '#Person6#'}

# %% [markdown]
# # 4.형태소 분석

# %% [markdown]
# ## Sample

# %%
## 분석하기 전에 [#문자열#:]을 제거한다.
def remove_speaker_tags(text):
    return re.sub(r'#\w+#:', '', text)

## 개행 문자 제거.
def remove_newlines(text):
    # 개행 문자를 문장부호 뒤에 공백과 함께 추가
    text = re.sub(r'([.?!])\n', r'\1 ', text)

    # 개행 문자가 남아있는 경우 제거
    return text.replace('\n', ' ')

# %%
cleaned_dialogue_sample = remove_speaker_tags(train_df['dialogue'].iloc[0])
cleaned_dialogue_sample = remove_newlines(cleaned_dialogue_sample)

mecab = MeCab()
morphs = mecab.morphs(cleaned_dialogue_sample)
print(morphs)

# %% [markdown]
# ## Total

# %%
mecab = MeCab()

# Dialogue와 Summary 형태소 분석
total_df['cleaned_dialogue'] = total_df['dialogue'].apply(lambda x: remove_newlines(remove_speaker_tags(x)))
total_df['cleaned_summary'] = total_df['summary'].apply(lambda x: remove_newlines(remove_speaker_tags(x)))

total_df['dialogue_morphs'] = total_df['cleaned_dialogue'].apply(lambda x: mecab.morphs(x))
total_df['summary_morphs'] = total_df['cleaned_summary'].apply(lambda x: mecab.morphs(x))

total_df.head()

# %% [markdown]
# # Cleaning

# %%
SPECIAL_TOKENS = {
    '#Person2#', '#Person3#', '#Person1#', '#PassportNumber#', '#Person6#', 
    '#CardNumber#', '#SSN#', '#Person7#', '#Person4#', '#Address#', '#Person5#', 
    '#PhoneNumber#', '#CarNumber#', '#DateOfBirth#', '#Email#'
}

def clean_text(text):
    pattern = '|'.join(map(re.escape, SPECIAL_TOKENS))
    special_token_occurrences = re.findall(pattern, text)

    for i, token in enumerate(special_token_occurrences):
        text = text.replace(token, f'SPECIALTOKEN{i}')
    
    text = re.sub(r'[^\w\s\.\,\?\!]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    
    for i, token in enumerate(special_token_occurrences):
        text = text.replace(f'SPECIALTOKEN{i}', token)
    
    return text

def preprocess_data(df):
    df['cleaned_dialogue'] = df['dialogue'].apply(clean_text)
    df['cleaned_summary'] = df['summary'].apply(clean_text)
    return df

total_df = preprocess_data(total_df)

# %%
idx = random.randint(0, total_df.shape[0]-1)
sample = total_df.iloc[idx]
print(sample, "\n")

print(f"원본 대화 :\n{sample['dialogue']} \n")
print(f"정제 대화 : \n{sample['cleaned_dialogue']} \n")

print(f"원본 요약 :\n{sample['summary']}, \n")
print(f"정제 요약 :\n{sample['cleaned_summary']}, \n")
# Out:
# fname                                                              train_8003
# dialogue                    #Person1#: 지금 몇 시야? \n#Person2#: 아홉시 10분 전이야. ...
# summary                     지금 아홉시고, 프레드는 또 늦을 것 같다. 디나는 그에게 몇 분 동안 함께 있어 ...
# topic                                                                       일
# dialogue_length                                                         568.0
# summary_length                                                           96.0
# is_train                                                                    1
# dialogue_special_strings    [#Person1#, #Person2#, #Person1#, #Person2#, #...
# summary_special_strings                                                    []
# cleaned_dialogue            #Person1# 지금 몇 시야? #Person2# 아홉시 10분 전이야. #Per...
# cleaned_summary             지금 아홉시고, 프레드는 또 늦을 것 같다. 디나는 그에게 몇 분 동안 함께 있어 ...
# Name: 8003, dtype: object
#
# 원본 대화 :
# #Person1#: 지금 몇 시야?
# #Person2#: 아홉시 10분 전이야.
# #Person1#: 네 시계가 10분 느려. 그러니까 지금 아홉시야. 또 늦겠네. 이번엔 어떤 핑계를 대지? 알람을 일곱시 삼십분에 맞춰야 했는데.
# #Person2#: 이미 엎지러진 물이야, 프레드? 조금만 더 있어줄 수 있어?
# #Person1#: 뭐? 왜? 너 무슨 일 있어?
# #Person2#: 그냥 집에 혼자 있으면서 아무것도 할 수 없이 시계 소리만 듣는 게 너무 외롭고 지루해. 내 병이 더 나빠지게 해. 언제 나아질까?
# #Person1#: 몇 달 안에 괜찮아질 거야, 참을성을 가져. 나는 이제 일어나야 해, 늦겠어.
# #Person2#: 너는 항상 너의 일만 생각하네.
# #Person1#: 미안해, 자기야, 너는 나의 전부야. 내가 하는 모든 건 우리 가족을 위한 거야.
# #Person2#: 조금만 더 있어줄래, 괜찮지?
# #Person1#: 알았어, 아홉시 십오분에 떠날게, 괜찮아?
# #Person2#: 네.
# #Person1#: 앞으로 너와 더 많은 시간을 보낼게, 디나.
# #Person2#: 고마워.
#
# 정제 대화 :
# #Person1# 지금 몇 시야? #Person2# 아홉시 10분 전이야. #Person1# 네 시계가 10분 느려. 그러니까 지금 아홉시야. 또 늦겠네. 이번엔 어떤 핑계를 대지? 알람을 일곱시 삼십분에 맞춰야 했는데. #Person2# 이미 엎지러진 물이야, 프레드? 조금만 더 있어줄 수 있어? #Person1# 뭐? 왜? 너 무슨 일 있어? #Person2# 그냥 집에 혼자 있으면서 아무것도 할 수 없이 시계 소리만 듣는 게 너무 외롭고 지루해. 내 병이 더 나빠지게 해. 언제 나아질까? #Person1# 몇 달 안에 괜찮아질 거야, 참을성을 가져. 나는 이제 일어나야 해, 늦겠어. #Person2# 너는 항상 너의 일만 생각하네. #Person1# 미안해, 자기야, 너는 나의 전부야. 내가 하는 모든 건 우리 가족을 위한 거야. #Person2# 조금만 더 있어줄래, 괜찮지? #Person1# 알았어, 아홉시 십오분에 떠날게, 괜찮아? #Person2# 네. #Person1# 앞으로 너와 더 많은 시간을 보낼게, 디나. #Person2# 고마워.
#
# 원본 요약 :
# 지금 아홉시고, 프레드는 또 늦을 것 같다. 디나는 그에게 몇 분 동안 함께 있어 달라고 요청하지만, 그는 일에 가야 한다. 결국, 그는 아홉시 십오분까지 있기로 동의한다.,
#
# 정제 요약 :
# 지금 아홉시고, 프레드는 또 늦을 것 같다. 디나는 그에게 몇 분 동안 함께 있어 달라고 요청하지만, 그는 일에 가야 한다. 결국, 그는 아홉시 십오분까지 있기로 동의한다.,

# %% [markdown]
# ## 자음만 사용된 경우
# dialogue에는 ㅋㅋ와 같은 단어가 포함되어 있지만 summary에는 아무것도 없다.

# %%
## "ㅋㅋ", "ㅎㅎ"와 같은 구어체에서 벗어나는 형태가 있는지 확인.
def find_special_patterns(morphs):
    consonant_pattern = re.compile(r'^[ㄱ-ㅎ]{2,}$')  # 자음이 최소 2번 이상 반복되는 경우만

    return [morph for morph in morphs if consonant_pattern.match(morph)]

# %%
# 형태소 분석
mecab = MeCab()
total_df['dialogue_morphs'] = total_df['cleaned_dialogue'].apply(lambda x: mecab.morphs(x))
total_df['summary_morphs'] = total_df['cleaned_summary'].apply(lambda x: mecab.morphs(x))

# %%
# 특이 패턴 찾기
total_df['dialogue_special_patterns'] = total_df['dialogue_morphs'].apply(find_special_patterns)
total_df['summary_special_patterns'] = total_df['summary_morphs'].apply(find_special_patterns)

# 특이 패턴이 포함된 Dialogue 행 필터링
dialogue_special_rows = total_df[total_df['dialogue_special_patterns'].apply(lambda x: len(x) > 0)]
summary_special_rows = total_df[total_df['summary_special_patterns'].apply(lambda x: len(x) > 0)]

dialogue_special_rows_info = dialogue_special_rows[['dialogue', 'dialogue_special_patterns']].reset_index()
summary_special_rows_info = summary_special_rows[['summary', 'summary_special_patterns']].reset_index()

# %%
print("Dialogue with Special Patterns:")
print(dialogue_special_rows_info)

print("Summary with Special Patterns:")
print(summary_special_rows_info)
# Out:
# Dialogue with Special Patterns:
#    index                                           dialogue  \
# 0   3154  #Person1#: 짐! 잘 지내? \n#Person2#: 찰리! 저게 너의 차야?...
# 1   5429  #Person1#: 너 남자친구 있어?\n#Person2#: 응, 전에 남자친구 있...
#
#   dialogue_special_patterns
# 0                      [ㅋㅋ]
# 1                      [ㅋㅋ]
# Summary with Special Patterns:
# Empty DataFrame
# Columns: [index, summary, summary_special_patterns]
# Index: []

# %%
print(dialogue_special_rows_info.iloc[0]['dialogue_special_patterns'])
print(dialogue_special_rows_info.iloc[0]['dialogue'])
# Out:
# ['ㅋㅋ']
# #Person1#: 짐! 잘 지내?
# #Person2#: 찰리! 저게 너의 차야? 완전 못생겼네, 친구야!
# #Person1#: 멍청이가 되지마! 이건 1969년형 쉐비 임팔라야! 좀 고쳐야겠지만. 몇 달 안에 이 아기는 완전 멋질 거야!
# #Person2#: 아니야! 이걸 봐! 이게 바로 멋진 차야!
# #Person1#: 아쉽게도 운전자는 완전 바보야. 그런 차를 가질 수 있는 건 아빠가 그만큼 돈이 많아서야.
# #Person2#: 그가 이쪽으로 오고 있어, 차분하게 있어.
# #Person3#: 여러분! 내 차 어때요? 완전 멋지지 않아요?
# #Person1#: 맞아! 여자들이 너를 그 차로 돌아다니는 걸 보면 너에게 줄을 서게 될 거야.
# #Person3#: 정말 그럴까요?
# #Person2#: 확실해!
# #Person3#: 대박!
# #Person1#: 속았어! ㅋㅋ.. 완전 속았어.
# #Person3#: 넌 진짜 나쁜 놈이야, 찰리. 프롬 퀸과 재미있는 시간을 보낼 때, 마지막 웃음은 누가 낼지 봐.
# #Person2#: 친구야, 화내지 마!

# %%
print(dialogue_special_rows_info.iloc[1]['dialogue_special_patterns'])
print(dialogue_special_rows_info.iloc[1]['dialogue'])
# Out:
# ['ㅋㅋ']
# #Person1#: 너 남자친구 있어?
# #Person2#: 응, 전에 남자친구 있었어.
# #Person1#: 왜 전 남자친구야?
# #Person2#: 우리 지난달에 헤어졌어.
# #Person1#: 새로운 남자친구 생겼어?
# #Person2#: 음, 아니. 너는?
# #Person1#: 나는 혼자야, 실제 여자친구는 없고, 너처럼 E-여자친구만 있어.
# #Person2#: 하하, 그럼 나는 너의 E-남자친구야.
# #Person1#: 나 너 좋아해. 나의 여자친구가 되어줄래?
# #Person2#: 음... 그래, 한번 해보자.
# #Person1#: 와! 블라블라블라...
# #Person2#: 야! 그게 뭐야?
# #Person1#: 나는 마치 새처럼 날고 있어.
# #Person2#: ㅋㅋ
# #Person1#: 나 너무 행복해. 샴페인 한 잔 마시고 싶어.
# #Person2#: 지금 샴페인 없어. 이건 어때?
# #Person1#: 괜찮아, 그럼 이걸 너에게 보낼게.
# #Person2#: 이건 초콜릿으로 만든 거야?
# #Person1#: 이건 내 마음이야; 네가 좋아하는 걸로 만들어진 거야.
# #Person2#: 오, 달콤한 꿈 꾸겠네.
# #Person1#: 졸려?
# #Person2#: 좀 있어. 원치 않지만 잠들어야 해.
# #Person1#: 응, 나도 네가 사무실에서 잠드는 건 보고 싶지 않아.
# #Person2#: 고마워. 일단 안녕. 키스스스스스.
# #Person1#: 또 봐, 자기야.

# %% [markdown]
# ## 반복되는 글자가 있는 데이터

# %%
# 반복되는 글자 패턴을 찾는 함수
def find_repeated_patterns(text):
    # 반복되는 글자 패턴을 찾기 위한 정규식 (같은 글자가 3번 이상 반복)
    repeated_pattern = re.compile(r'([가-힣])\1{2,}')  # 동일한 한글 글자가 연속적으로 2번 이상 반복

    return [match.group(0) for match in repeated_pattern.finditer(text)]

# %%
# 반복되는 글자 패턴 찾기
total_df['dialogue_repeated_patterns'] = total_df['cleaned_dialogue'].apply(find_repeated_patterns)
total_df['summary_repeated_patterns'] = total_df['cleaned_summary'].apply(find_repeated_patterns)

# 반복되는 패턴이 포함된 Dialogue 행 필터링
dialogue_repeated_rows = total_df[total_df['dialogue_repeated_patterns'].apply(lambda x: len(x) > 0)]
summary_repeated_rows = total_df[total_df['summary_repeated_patterns'].apply(lambda x: len(x) > 0)]

dialogue_repeated_rows_info = dialogue_repeated_rows[['dialogue', 'dialogue_repeated_patterns']].reset_index()
summary_repeated_rows_info = summary_repeated_rows[['summary', 'summary_repeated_patterns']].reset_index()

# %%
print("Dialogue with Repeated Patterns:")
print(dialogue_repeated_rows_info)

print("Summary with Repeated Patterns:")
print(summary_repeated_rows_info)
# Out:
# Dialogue with Repeated Patterns:
#     index                                           dialogue  \
# 0     276  #Person1#: 안녕하세요. 이곳은 911 긴급 센터입니다.\n#Person2#...
# 1     460  #Person1#: 안녕하세요, 클로이님, 저는 에반스 의사입니다. 어떤 문제가 있...
# 2     901  #Person1#: 음, 안녕하세요. 그 무게들 좀 도와드릴까요? 제가 옮겨 드릴게...
# 3     998  #Person1#: 휴, 제닌, 피곤해. 오늘 하루가 길었어. \n#Person2#...
# 4    1732  #Person1#: 너 무슨 일 있어? 얼굴이 창백해.\n#Person2#: 잘 모...
# 5    1907  #Person1#: 아아아악!\n#Person2#: 아직 만지지도 않았는데, 왜 그...
# 6    2464  #Person1#: 수도꼭지를 틀어도 물이 왜 안 나오나요?\n#Person2#: ...
# 7    2727  #Person1#: 안녕, 폴. 친구야, 어떻게 지내? \n#Person2#: 별로...
# 8    4271  #Person1#: 도나! 어떻게 지내? 목소리 들으니 반가워.\n#Person2#...
# 9    4401  #Person1#: 시간이 너무 늦었지만, 배가 고파 죽겠어요. \n#Person2...
# 10   5429  #Person1#: 너 남자친구 있어?\n#Person2#: 응, 전에 남자친구 있...
# 11   6260  #Person1#: 멈춰. [뭐?] 그리고 돈을 내놔.\n#Person2#: 뭐? ...
# 12   6563  #Person1#: 카탈로그를 봐, 존. 이 빨간 블라우스를 사고 싶어. \n#Pe...
# 13   7662  #Person1#: 안녕. 안녕, 자기야. 나 왔어. 음, 나 왔어!\n#Perso...
# 14   8060  #Person1#: 휴, 제닌, 피곤해. 오늘 하루가 길었어. \n#Person2#...
# 15   8206  #Person1#: 어떻게 지내? \n#Person2#: 별일 없어. 베이징은 추워...
# 16   9608  #Person1#: 이런 것들은 항상 너어어어무 지루해. 아무 소문 들은거 없어? ...
# 17   9982  #Person1#: 안녕하세요, 들어오세요, 기다리고 있었습니다.\n#Person2...
# 18  10295  #Person1#: 너무 더워. 더 이상 걸을 수 있을지 모르겠어.\n#Person...
# 19  11051  #Person1#: 휴! 오늘은 꽤 추운 것 같아요.\r\n#Person2#: 그러...
# 20  11674  #Person1#: 안녕하세요. 오늘 밤 예약이 있어서 체크인하려고 합니다.\n#P...
# 21  12164  #Person1#: 미안해, 제이슨. 수잔도 같이 올 수 있었는데, 사무실에서 급한...
# 22  12295  #Person1#: 이제 2주째 이 일에 매달리고 있는데 아무런 결과도 없어요.\n...
# 23  12791  #Person1#: 안녕. 식료품 좀 도와줄래? 그리고 내가 쇼핑할수도 있댔잖아.\...
# 24  12862  #Person1#: 존, 카탈로그를 봐봐. 이 빨간 블라우스를 사고 싶어\n#Per...
#
#    dialogue_repeated_patterns
# 0                       [아아아]
# 1                    [아아아아아아]
# 2                       [아아아]
# 3                       [하하하]
# 4                [아아아아, 아아아아]
# 5                       [아아아]
# 6                       [똑똑똑]
# 7                       [하하하]
# 8                       [하하하]
# 9                      [아아아아]
# 10                    [스스스스스]
# 11                      [아아아]
# 12                      [허허허]
# 13                      [하하하]
# 14                      [하하하]
# 15                      [하하하]
# 16                      [어어어]
# 17                      [하하하]
# 18                      [하하하]
# 19                      [헤헤헤]
# 20                     [으으으으]
# 21                      [하하하]
# 22                      [하하하]
# 23                      [아아아]
# 24                      [제제제]
# Summary with Repeated Patterns:
# Empty DataFrame
# Columns: [index, summary, summary_repeated_patterns]
# Index: []

# %%
print(dialogue_repeated_rows_info.iloc[0]['dialogue_repeated_patterns'])
print(dialogue_repeated_rows_info.iloc[0]['dialogue'])
# Out:
# ['아아아']
# #Person1#: 안녕하세요. 이곳은 911 긴급 센터입니다.
# #Person2#: 도와주세요. 도와주세요. 제발 도와주세요!
# #Person1#: 네, 신사분. 조금만 진정하시고 정확히 어떤 상황인지 설명해 주세요.
# #Person2#: 차분하다고요! 제 차가 고속도로에서 멈춰버렸고, 여성 승객이 있어요. 그녀가 출산을 시작했어요.
# #Person1#: 이제 차분하게 하세요. 정확히 어디에 계신지 설명해 주세요.
# #Person2#: 저... 저... 남쪽으로 가는 링컨 고속도로에 있어요, 워싱턴 터널에서 약 15마일 떨어진 곳이고, 이 여성은 기다릴 수 없을 것 같아요.
# #Person1#: 좋아요. 당신의 이름과 승객의 이름은 무엇인가요?
# #Person2#: 저... 저... 제 이름은 밥이고, 여성에 대해서는 전혀 모르겠어요. 그녀는 말할 상태가 아니에요.
# #Person1#: 좋아요, 그럼 당신이 있는 위치에서 가장 가까운 랜드마크는 무엇인가요? 주의 깊게 보세요.
# #Person2#: 음, 황금 아치가 보이는데... 맥도날드입니다.
# #Person1#: 좋아요, 당신과 함께 있는 다른 사람이 있나요?
# #Person2#: 아니요, 그리고 다른 사람이 멈춰주도록 시도했어요. [병이 깨지는 소리]
# #Person1#: 헤이, 그게 뭐예요? [아아아!]
# #Person2#: 아, 누군가가 제게 병을 던졌어요. 얼마나 빨리 누군가 올 수 있나요?
# #Person1#: 방금 구급차를 당신의 위치로 보냈습니다. 곧 도착할 것입니다.
# #Person2#: 헤이, 구급차가 오기 전에 제가 할 수 있는 일이 있나요?
# #Person1#: 네, 음, 그녀를 차분하게 하고 따뜻하게 해주세요.
# #Person2#: 좋아요. 빨리 와주세요. 오, 이미 늦었어요. 남자 아이에요!

# %%
print(dialogue_repeated_rows_info.iloc[1]['dialogue_repeated_patterns'])
print(dialogue_repeated_rows_info.iloc[1]['dialogue'])
# Out:
# ['아아아아아아']
# #Person1#: 안녕하세요, 클로이님, 저는 에반스 의사입니다. 어떤 문제가 있으신가요?
# #Person2#: 안녕하세요, 에반스 박사님. 이렇게 급히 뵙게 되어 감사합니다. 오늘 아침에 일어나니 목이 아주 아프고 기침도 심하게 나오더라고요. 제가 독감에 걸린 것 같아요.
# #Person1#: 아, 알겠습니다. 네, 목소리가 좀 쉬어 보이네요. 잠시 살펴보도록 하죠. 입을 크게 벌리고 '아' 하고 말해주실 수 있나요?
# #Person2#: 아아아아아아
# #Person1#: 좋아요, 네, 편도가 조금 부어있고 붉어 보입니다. 귀는 어떠세요, 막혀 있나요?
# #Person2#: 사실 조금 그렇습니다. 제 코도 좀 막힌 것 같아요-정말 기분이 안 좋아요.
# #Person1#: 알겠습니다, 클로이님. 제가 가슴 소리를 들어보려고 하는데, 천천히 숨을 들이마시고 내쉬어 주실 수 있나요? 정말로 많이 막혀 있네요, 상태가 별로 좋지 않아 보입니다. 항생제를 몇 가지 처방해 드릴게요. 이 주황색 알약은 하루에 두 번, 이 파란색 알약은 매일 저녁에 드셔야 합니다. 또한 이 기침약을 식사 후 하루에 세 번 드셔야 합니다. 마지막으로 숨이 찰 때마다 사용할 수 있는 흡입기를 드릴게요. . . 폐를 깨끗하게 해줄 거예요!
# #Person2#: 와! 약이 너무 많네요. . . 알약을 삼키는 걸 정말 싫어해요. 일하러 갈 수 있을까요?
# #Person1#: 절대로 안 돼요! 당신은 매우 전염성이 있어요! 동료들에게 감염시키고 싶지 않으시죠? 적어도 3일 동안은 침대에서 쉬고 충분한 수분을 섭취해 약해지거나 탈수 상태가 되지 않도록 하는 것이 좋습니다. 최신 TV 쇼와 영화를 보면서 시간을 보내세요!
# #Person2#: 알겠어요! 의사 소견서를 써주실 수 있나요? 그렇지 않으면 제가 꾸미는 거라고 생각할 수도 있어요!
# #Person1#: 하하, 물론입니다! 여기 있습니다. 이제 가서 침대에서 쉬세요. 궁금한 점이 있으면 언제든지 전화주세요! 빨리 나아지시길 바라고, 건강하세요.
# #Person2#: 감사합니다, 박사님, 안녕!

# %%
print(dialogue_repeated_rows_info.iloc[4]['dialogue_repeated_patterns'])
print(dialogue_repeated_rows_info.iloc[4]['dialogue'])
# Out:
# ['아아아아', '아아아아']
# #Person1#: 너 무슨 일 있어? 얼굴이 창백해.
# #Person2#: 잘 모르겠어, 몸이 더웠다가 추웠다가 해.
# #Person1#: 언제부터 그랬어?
# #Person2#: 어제 밤 내내 아팠어.
# #Person1#: 독감 걸린 거 같은데. 체온을 재 볼게.
# #Person2#: 고열이야?
# #Person1#: 응, 38.7도. 두통이나 가슴 또는 목에 통증이 있어?
# #Person2#: 응, 있어.
# #Person1#: 자, 좀 볼게. 가슴 소리를 들어볼거야. 이제 숨을 깊게 들이마시고. 그래, 이제 기침해 봐. 목도 살펴볼게. 크게 입을 벌리고, '아 - -' 하고 소리내 봐.
# #Person2#: 아아아아, 아아아아.
# #Person1#: 응, 목이 좀 부었네. 흉부 엑스레이를 찍고 몇 가지 검사를 해볼게.
# #Person2#: 알았어, 고마워.
# #Person1#: 검사 결과 특별한 이상은 없어. 경미한 바이러스성 감염이야.
# #Person2#: 오늘은 어떻게 해야 해?
# #Person1#: 항생제와 아스피린을 처방해줄게. 열이 나면 아스피린을 먹고, 4시간마다 항생제 한 알을 먹어. 그리고 집에 가서 이틀 동안 침대에서 쉬어. 물을 많이 마시면 좀 나아질 거야. 여기 처방전이야.

# %%
print(dialogue_repeated_rows_info.iloc[24]['dialogue_repeated_patterns'])
print(dialogue_repeated_rows_info.iloc[24]['dialogue'])
# Out:
# ['제제제']
# #Person1#: 존, 카탈로그를 봐봐. 이 빨간 블라우스를 사고 싶어
# #Person2#: 파란색으로 이런 거 가지고 있지 않아?
# #Person1#: 응, 근데 빨간색은 없어.
# #Person2#: 무지개 색깔 다 필요해?
# #Person1#: 그래!
# #Person2#: 제제제... 여자들이란!

# %%
# 반복되는 문자를 한 글자만 남기도록 수정하는 함수
def remove_repeated_characters(text):
    return re.sub(r'([가-힣])\1{2,}', r'\1', text)

# dialogue 컬럼에서 반복되는 문자를 한 글자만 남기도록 처리
total_df['dialogue_modified'] = total_df['dialogue'].apply(remove_repeated_characters)
# 처리 전후 비교를 위한 DataFrame 생성
comparison_df = total_df[['dialogue', 'dialogue_modified']].copy()

# 반복되는 패턴이 있었던 행만 필터링
dialogue_repeated_comparison = comparison_df[total_df['dialogue_repeated_patterns'].apply(lambda x: len(x) > 0)]

print(dialogue_repeated_comparison.iloc[0]['dialogue'])
print()
print(dialogue_repeated_comparison.iloc[0]['dialogue_modified'])
# Out:
# #Person1#: 안녕하세요. 이곳은 911 긴급 센터입니다.
# #Person2#: 도와주세요. 도와주세요. 제발 도와주세요!
# #Person1#: 네, 신사분. 조금만 진정하시고 정확히 어떤 상황인지 설명해 주세요.
# #Person2#: 차분하다고요! 제 차가 고속도로에서 멈춰버렸고, 여성 승객이 있어요. 그녀가 출산을 시작했어요.
# #Person1#: 이제 차분하게 하세요. 정확히 어디에 계신지 설명해 주세요.
# #Person2#: 저... 저... 남쪽으로 가는 링컨 고속도로에 있어요, 워싱턴 터널에서 약 15마일 떨어진 곳이고, 이 여성은 기다릴 수 없을 것 같아요.
# #Person1#: 좋아요. 당신의 이름과 승객의 이름은 무엇인가요?
# #Person2#: 저... 저... 제 이름은 밥이고, 여성에 대해서는 전혀 모르겠어요. 그녀는 말할 상태가 아니에요.
# #Person1#: 좋아요, 그럼 당신이 있는 위치에서 가장 가까운 랜드마크는 무엇인가요? 주의 깊게 보세요.
# #Person2#: 음, 황금 아치가 보이는데... 맥도날드입니다.
# #Person1#: 좋아요, 당신과 함께 있는 다른 사람이 있나요?
# #Person2#: 아니요, 그리고 다른 사람이 멈춰주도록 시도했어요. [병이 깨지는 소리]
# #Person1#: 헤이, 그게 뭐예요? [아아아!]
# #Person2#: 아, 누군가가 제게 병을 던졌어요. 얼마나 빨리 누군가 올 수 있나요?
# #Person1#: 방금 구급차를 당신의 위치로 보냈습니다. 곧 도착할 것입니다.
# #Person2#: 헤이, 구급차가 오기 전에 제가 할 수 있는 일이 있나요?
# #Person1#: 네, 음, 그녀를 차분하게 하고 따뜻하게 해주세요.
# #Person2#: 좋아요. 빨리 와주세요. 오, 이미 늦었어요. 남자 아이에요!
#
# #Person1#: 안녕하세요. 이곳은 911 긴급 센터입니다.
# #Person2#: 도와주세요. 도와주세요. 제발 도와주세요!
# #Person1#: 네, 신사분. 조금만 진정하시고 정확히 어떤 상황인지 설명해 주세요.
# #Person2#: 차분하다고요! 제 차가 고속도로에서 멈춰버렸고, 여성 승객이 있어요. 그녀가 출산을 시작했어요.
# #Person1#: 이제 차분하게 하세요. 정확히 어디에 계신지 설명해 주세요.
# #Person2#: 저... 저... 남쪽으로 가는 링컨 고속도로에 있어요, 워싱턴 터널에서 약 15마일 떨어진 곳이고, 이 여성은 기다릴 수 없을 것 같아요.
# #Person1#: 좋아요. 당신의 이름과 승객의 이름은 무엇인가요?
# #Person2#: 저... 저... 제 이름은 밥이고, 여성에 대해서는 전혀 모르겠어요. 그녀는 말할 상태가 아니에요.
# #Person1#: 좋아요, 그럼 당신이 있는 위치에서 가장 가까운 랜드마크는 무엇인가요? 주의 깊게 보세요.
# #Person2#: 음, 황금 아치가 보이는데... 맥도날드입니다.
# #Person1#: 좋아요, 당신과 함께 있는 다른 사람이 있나요?
# #Person2#: 아니요, 그리고 다른 사람이 멈춰주도록 시도했어요. [병이 깨지는 소리]
# #Person1#: 헤이, 그게 뭐예요? [아!]
# #Person2#: 아, 누군가가 제게 병을 던졌어요. 얼마나 빨리 누군가 올 수 있나요?
# #Person1#: 방금 구급차를 당신의 위치로 보냈습니다. 곧 도착할 것입니다.
# #Person2#: 헤이, 구급차가 오기 전에 제가 할 수 있는 일이 있나요?
# #Person1#: 네, 음, 그녀를 차분하게 하고 따뜻하게 해주세요.
# #Person2#: 좋아요. 빨리 와주세요. 오, 이미 늦었어요. 남자 아이에요!

# %%
total_df['cleaned_dialogue'] = total_df['cleaned_dialogue'].apply(remove_repeated_characters)

# %% [markdown]
# # 한글 이외의 문자를 포함

# %%
# 한글이 아닌 다른 문자를 찾는 함수
def find_non_hangul_patterns(text):
    # 특수 토큰(#string#)을 미리 제외
    excluded_pattern = re.compile(r'#.*?#')
    cleaned_text = excluded_pattern.sub('', text)  # 특수 토큰을 빈 문자열로 대체
    
    # 한글, 공백, 기본 구두점(.,?!, 공백)을 제외한 모든 문자 또는 연속된 점(...) 패턴을 찾음
    non_hangul_pattern = re.compile(r'[^가-힣\s.,?!]|(?<!\.)\.\.+')
    return non_hangul_pattern.findall(cleaned_text)

# %%
# 한글 이외의 다른 문자가 포함된 패턴 찾기
total_df['dialogue_non_hangul_patterns'] = total_df['cleaned_dialogue'].apply(find_non_hangul_patterns)
total_df['summary_non_hangul_patterns'] = total_df['cleaned_summary'].apply(find_non_hangul_patterns)

dialogue_non_hangul_rows_info = total_df[total_df['dialogue_non_hangul_patterns'].apply(lambda x: len(x) > 0)][['dialogue', 'dialogue_non_hangul_patterns']]
print(dialogue_non_hangul_rows_info)
# Out:
#                                                 dialogue  \
# 0      #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1      #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2      #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 4      #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
# 6      #Person1#: 여기 도착했습니다.\n#Person2#: 감사합니다. 요금은 얼...
# ...                                                  ...
# 12947  #Person1#: 인터넷에서 빌 게이츠의 집을 본 적이 있나요? \r\n#Pers...
# 12949  #Person1#: 실례합니다, 지금 8인용 테이블이 있나요? \r\n#Person...
# 12950  #Person1#: 나는 완전히 내 상사에게 지쳤어. 그는 그의 성차별적인 발언으로...
# 12951  #Person1#: 이제 새해가 되어서 새로운 시작을 하려고 결심했어. \r\n#P...
# 12954  #Person1#: 안녕하세요, 아마존 고객 서비스입니다. 무엇을 도와드릴까요?\n...
#
#                             dialogue_non_hangul_patterns
# 0                                                    [5]
# 1                                     [B, 1, 4, A, 1, 5]
# 2                                                    [5]
# 4                                                  [...]
# 6                            [1, 0, 2, 2, 2, 0, 0, 2, 0]
# ...                                                  ...
# 12947                                          [2, 0, 0]
# 12949                                                [8]
# 12950                                              [...]
# 12951                                             [1, 6]
# 12954  [5, 3, B, 1, 1, 3, 7, 4, 2, 3, 9, 3, 5, 1, 0, ...
#
# [6829 rows x 2 columns]

# %%
print(dialogue_non_hangul_rows_info.iloc[1]['dialogue_non_hangul_patterns'])
print(dialogue_non_hangul_rows_info.iloc[1]['dialogue'])
# Out:
# ['B', '1', '4', 'A', '1', '5']
# #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?
# #Person2#: 안녕하세요, 피터스 박사님. 잘 지냈습니다, 감사합니다. 리키와 함께 백신 접종을 위해 왔습니다.
# #Person1#: 좋습니다. 백신 접종 기록을 보니, 리키는 이미 소아마비, 디프테리아, B형 간염 백신을 맞았군요. 그는 14개월이므로, 이제 A형 간염, 수두, 홍역 백신을 맞아야 합니다.
# #Person2#: 풍진과 볼거리는 어떻게 되나요?
# #Person1#: 지금은 이 백신들만 접종할 수 있고, 몇 주 후에 나머지를 접종할 수 있습니다.
# #Person2#: 좋습니다. 박사님, 저도 디프테리아 예방접종이 필요할 것 같아요. 마지막으로 맞은 게 아마도 15년 전이었던 것 같아요!
# #Person1#: 저희가 기록을 확인하고 간호사에게 부스터를 접종하도록 하겠습니다. 이제, 리키의 팔을 꽉 잡아주세요, 조금 찌릿할 수 있습니다.

# %%
print(dialogue_non_hangul_rows_info.iloc[-1]['dialogue_non_hangul_patterns'])
print(dialogue_non_hangul_rows_info.iloc[-1]['dialogue'])
# Out:
# ['5', '3', 'B', '1', '1', '3', '7', '4', '2', '3', '9', '3', '5', '1', '0', '1', '0', '1', '3', '2']
# #Person1#: 안녕하세요, 아마존 고객 서비스입니다. 무엇을 도와드릴까요?
# #Person2#: 안녕하세요, 어제 웹사이트에서 받은 책을 읽다가 한 페이지가 빠져있는 것을 발견했습니다, 53페이지에요.
# #Person1#: 알겠습니다. 주문 번호를 알려주실 수 있을까요, 고객님?
# #Person2#: B113-7423935입니다.
# #Person1#: 확인해보겠습니다. 10일 전인 10월 13일에 웹사이트에서 구매하신 라 살바토레의 '헌터의 종이 봉투 밤'이 맞나요?
# #Person2#: 네.
# #Person1#: 그럼, 이 책의 빠진 부분을 사진으로 찍어서 우리 웹사이트의 고객 서비스 페이지에 업로드해주셔야 할 것 같습니다. 문제가 확인되면 2일 내로 새 책을 보내드리겠습니다.
# #Person2#: 알겠습니다. 그럼 이전에 받은 책은 어떻게 해야 하나요? 돌려보내야 하나요?
# #Person1#: 그럴 필요는 없습니다, 고객님. 원하신다면 그냥 가지고 계셔도 됩니다. 다른 도움이 필요한 것이 있으신가요?
# #Person2#: 아니요, 감사합니다.
# #Person1#: 천만에요, 고객님. 좋은 하루 보내세요.

# %%
# 함수: 대화 내에서 (문자열) 또는 [문자열]을 #Reaction#으로 대체
def replace_reaction(dialogue):
    # (문자열) 또는 [문자열] 패턴을 #Reaction#으로 변경
    dialogue = re.sub(r'\(.*?\)|\[.*?\]', '#Reaction#', dialogue)
    return dialogue

# (문자열) 또는 [문자열]을 포함하는 행을 찾음
rows_with_reaction = total_df[total_df['cleaned_dialogue'].str.contains(r'\(.*?\)|\[.*?\]')].index.tolist()

for row in rows_with_reaction:
    original_dialogue = total_df.loc[row, 'cleaned_dialogue']
    updated_dialogue = replace_reaction(original_dialogue)
    print(f"Row {row}:")
    print("Before:", original_dialogue)
    print("After:", updated_dialogue)
    total_df.loc[row, 'cleaned_dialogue'] = updated_dialogue
# Out:
# Empty DataFrame
# Columns: [cleaned_dialogue]
# Index: []

# %%
with open('./train-non_kor.txt', 'w', encoding='utf-8') as file:
    for index in range(dialogue_non_hangul_rows_info.shape[0]):
        patterns = dialogue_non_hangul_rows_info.iloc[index]['dialogue_non_hangul_patterns']
        dialogue = dialogue_non_hangul_rows_info.iloc[index]['dialogue']
        file.write(f"Index {index}:\nPatterns: {patterns}\nDialogue: {dialogue}\n\n")

# %% [markdown]
# - [괄호안에 든 글자]는 어떻게 하지??
# - 숫자, 따옴표는 필요.
# - '-', '\x08', ';', '..', '....', '.....', '…', 'ㅍ', 'ㄷ', '*', 'ㅐ'
# - 'ㅏ' -> '가'

# %% [markdown]
# # 대체 및 삭제

# %%
# 삭제 및 대체 대상
delete_chars = ['-', '\x08', ';', 'ㅍ', 'ㄷ', '*', 'ㅐ']
replace_dict = {'ㅏ': '가', 'ㅇ' : '으', 'ㅋㅋ' : '웃기다.',
                '....' : "...", '.....' : "...", '…' : "...", ".." : "...", "......" : "..."}

def clean_text(text):
    lines = text.splitlines()
    cleaned_lines = []
    
    for line in lines:
        for char in delete_chars:
            line = line.replace(char, '')

        for old_char, new_char in replace_dict.items():
            line = line.replace(old_char, new_char)
        
        cleaned_lines.append(line)
    return '\n'.join(cleaned_lines)

total_df['cleaned_dialogue'] = total_df['cleaned_dialogue'].apply(clean_text)

# %%
total_df['cleaned_dialogue'] = total_df['cleaned_dialogue'].apply(clean_text)
total_df['cleaned_summary'] = total_df['cleaned_summary'].apply(clean_text)

# %%
def compare_texts(original_text, cleaned_text):
    print("Original Text:")
    print(original_text)
    print("\nCleaned Text:")
    print(cleaned_text)
    print("\n" + "="*50 + "\n")

# %%
for i in range(5):
    original_text = total_df['dialogue'].iloc[i]
    cleaned_text = total_df['cleaned_dialogue'].iloc[i]
    compare_texts(original_text, cleaned_text)
# Out:
# Original Text:
# #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
# #Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
# #Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
# #Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
# #Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
# #Person2#: 알겠습니다.
# #Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
# #Person2#: 네.
# #Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다.
# #Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
# #Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
# #Person2#: 알겠습니다, 감사합니다, 의사선생님.
#
# Cleaned Text:
# #Person1# 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요? #Person2# 건강검진을 받는 것이 좋을 것 같아서요. #Person1# 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다. #Person2# 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요? #Person1# 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요. #Person2# 알겠습니다. #Person1# 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요? #Person2# 네. #Person1# 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다. #Person2# 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다. #Person1# 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다. #Person2# 알겠습니다, 감사합니다, 의사선생님.
#
# ==================================================
#
# Original Text:
# #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?
# #Person2#: 안녕하세요, 피터스 박사님. 잘 지냈습니다, 감사합니다. 리키와 함께 백신 접종을 위해 왔습니다.
# #Person1#: 좋습니다. 백신 접종 기록을 보니, 리키는 이미 소아마비, 디프테리아, B형 간염 백신을 맞았군요. 그는 14개월이므로, 이제 A형 간염, 수두, 홍역 백신을 맞아야 합니다.
# #Person2#: 풍진과 볼거리는 어떻게 되나요?
# #Person1#: 지금은 이 백신들만 접종할 수 있고, 몇 주 후에 나머지를 접종할 수 있습니다.
# #Person2#: 좋습니다. 박사님, 저도 디프테리아 예방접종이 필요할 것 같아요. 마지막으로 맞은 게 아마도 15년 전이었던 것 같아요!
# #Person1#: 저희가 기록을 확인하고 간호사에게 부스터를 접종하도록 하겠습니다. 이제, 리키의 팔을 꽉 잡아주세요, 조금 찌릿할 수 있습니다.
#
# Cleaned Text:
# #Person1# 안녕하세요, 파커 부인, 어떻게 지내셨나요? #Person2# 안녕하세요, 피터스 박사님. 잘 지냈습니다, 감사합니다. 리키와 함께 백신 접종을 위해 왔습니다. #Person1# 좋습니다. 백신 접종 기록을 보니, 리키는 이미 소아마비, 디프테리아, B형 간염 백신을 맞았군요. 그는 14개월이므로, 이제 A형 간염, 수두, 홍역 백신을 맞아야 합니다. #Person2# 풍진과 볼거리는 어떻게 되나요? #Person1# 지금은 이 백신들만 접종할 수 있고, 몇 주 후에 나머지를 접종할 수 있습니다. #Person2# 좋습니다. 박사님, 저도 디프테리아 예방접종이 필요할 것 같아요. 마지막으로 맞은 게 아마도 15년 전이었던 것 같아요! #Person1# 저희가 기록을 확인하고 간호사에게 부스터를 접종하도록 하겠습니다. 이제, 리키의 팔을 꽉 잡아주세요, 조금 찌릿할 수 있습니다.
#
# ==================================================
#
# Original Text:
# #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?
# #Person2#: 어떤 종류의 열쇠인가요?
# #Person1#: 5개의 열쇠와 작은 발 장식이 있어요.
# #Person2#: 안타깝네요! 저는 보지 못했습니다.
# #Person1#: 그럼, 찾는 데 도와주실 수 있나요? 제가 여기는 처음이라서요.
# #Person2#: 물론입니다. 기꺼이 도와드리겠습니다. 사라진 열쇠를 찾는 데 도와드리겠습니다.
# #Person1#: 정말 친절하시네요.
# #Person2#: 별 말씀을요. 어, 찾았어요.
# #Person1#: 오, 하느님 감사합니다! 어떻게 감사의 말씀을 드려야 할지 모르겠네요.
# #Person2#: 천만에요.
#
# Cleaned Text:
# #Person1# 실례합니다, 열쇠 한 묶음 보셨나요? #Person2# 어떤 종류의 열쇠인가요? #Person1# 5개의 열쇠와 작은 발 장식이 있어요. #Person2# 안타깝네요! 저는 보지 못했습니다. #Person1# 그럼, 찾는 데 도와주실 수 있나요? 제가 여기는 처음이라서요. #Person2# 물론입니다. 기꺼이 도와드리겠습니다. 사라진 열쇠를 찾는 데 도와드리겠습니다. #Person1# 정말 친절하시네요. #Person2# 별 말씀을요. 어, 찾았어요. #Person1# 오, 하느님 감사합니다! 어떻게 감사의 말씀을 드려야 할지 모르겠네요. #Person2# 천만에요.
#
# ==================================================
#
# Original Text:
# #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?
# #Person2#: 미안해, 너가 이미 알고 있다고 생각했어.
# #Person1#: 하지만 너가 그녀를 사랑한다는 걸 말해줘야 했어.
# #Person2#: 내가 하지 않았어?
# #Person1#: 너도 알고 있잖아, 말하지 않았다고.
# #Person2#: 그래, 지금 말해주고 있잖아.
# #Person1#: 그래, 하지만 너는 나에게 미리 말해줄 수 있었어.
# #Person2#: 네가 관심 있을 줄은 몰랐어.
# #Person1#: 진짜 농담이지. 어떻게 그녀와 결혼할 거라는 걸 말하지 않을 수 있어?
# #Person2#: 미안해, 나는 그게 중요하다고 생각하지 않았어.
# #Person1#: 아, 남자들이란! 다 똑같아.
#
# Cleaned Text:
# #Person1# 왜 너는 여자친구가 있다는 걸 말해주지 않았어? #Person2# 미안해, 너가 이미 알고 있다고 생각했어. #Person1# 하지만 너가 그녀를 사랑한다는 걸 말해줘야 했어. #Person2# 내가 하지 않았어? #Person1# 너도 알고 있잖아, 말하지 않았다고. #Person2# 그래, 지금 말해주고 있잖아. #Person1# 그래, 하지만 너는 나에게 미리 말해줄 수 있었어. #Person2# 네가 관심 있을 줄은 몰랐어. #Person1# 진짜 농담이지. 어떻게 그녀와 결혼할 거라는 걸 말하지 않을 수 있어? #Person2# 미안해, 나는 그게 중요하다고 생각하지 않았어. #Person1# 아, 남자들이란! 다 똑같아.
#
# ==================================================
#
# Original Text:
# #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 나와 함께 해줄래?
# #Person2#: 그는 귀여워! 그는 타이거 우즈 같아 보여! 하지만, 나는 춤을 못 춰...
# #Person1#: 괜찮아. 내가 너에게 모든 올바른 동작을 보여줄게. 내 이름은 말릭이야.
# #Person2#: 만나서 반가워. 나는 웬이고, 이쪽은 니키야.
# #Person1#: 기분 어때, 비스타? 네 친구를 춤추는 곳으로 데려가도 괜찮을까?
# #Person2#: 네 발을 밟아도 상관없다면 그녀는 신경 쓰지 않을 거야.
# #Person1#: 좋아. 멋져! 가자!
#
# Cleaned Text:
# #Person1# 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 나와 함께 해줄래? #Person2# 그는 귀여워! 그는 타이거 우즈 같아 보여! 하지만, 나는 춤을 못 춰.... #Person1# 괜찮아. 내가 너에게 모든 올바른 동작을 보여줄게. 내 이름은 말릭이야. #Person2# 만나서 반가워. 나는 웬이고, 이쪽은 니키야. #Person1# 기분 어때, 비스타? 네 친구를 춤추는 곳으로 데려가도 괜찮을까? #Person2# 네 발을 밟아도 상관없다면 그녀는 신경 쓰지 않을 거야. #Person1# 좋아. 멋져! 가자!
#
# ==================================================

# %%
total_df.columns
# Out:
# Index(['fname', 'dialogue', 'summary', 'topic', 'dialogue_length',
#        'summary_length', 'is_train', 'dialogue_special_strings',
#        'summary_special_strings', 'cleaned_dialogue', 'cleaned_summary',
#        'dialogue_morphs', 'summary_morphs', 'dialogue_special_patterns',
#        'summary_special_patterns', 'dialogue_repeated_patterns',
#        'summary_repeated_patterns', 'dialogue_modified',
#        'dialogue_non_hangul_patterns', 'summary_non_hangul_patterns'],
#       dtype='object')

# %%
total_df['dialogue'] = total_df['cleaned_dialogue']
total_df['summary'] = total_df['cleaned_summary']

total_df = total_df.drop(columns=['dialogue_length', 'summary_length', 'cleaned_dialogue', 'cleaned_summary',
                                  'dialogue_morphs', 'summary_morphs', 'dialogue_special_patterns',
                                  'summary_special_patterns', 'dialogue_repeated_patterns',
                                  'summary_repeated_patterns', 'dialogue_non_hangul_patterns',
                                  'summary_non_hangul_patterns', 'dialogue_special_strings', 'summary_special_strings', 'dialogue_modified'])

print(total_df.columns)
# Out:
# Index(['fname', 'dialogue', 'summary', 'topic', 'is_train'], dtype='object')

# %%
cleaned_train_df = total_df[total_df['is_train'] == 1].reset_index(drop=True)
cleaned_valid_df = total_df[total_df['is_train'] == 0].reset_index(drop=True)

cleaned_train_df = cleaned_train_df.drop(columns=['is_train'])
cleaned_valid_df = cleaned_valid_df.drop(columns=['is_train'])

# %%
print(cleaned_train_df.columns)
print(cleaned_valid_df.columns)
# Out:
# Index(['fname', 'dialogue', 'summary', 'topic'], dtype='object')
# Index(['fname', 'dialogue', 'summary', 'topic'], dtype='object')

# %%
cleaned_train_df.to_csv("../dataset/cleaned_train.csv", index=False)
cleaned_valid_df.to_csv("../dataset/cleaned_dev.csv", index=False)
